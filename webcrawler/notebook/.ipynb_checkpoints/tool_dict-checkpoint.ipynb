# %%
from urllib.request import urlopen,Request 
from bs4 import BeautifulSoup 
import requests
import time
import os
from tqdm import tqdm
import pickle

# %%
def generate_category_dict():
        state = ""
        category_dict = {}
        tool_file = open("../omictool_toollist.txt","r")
        for t in tool_file:
                t_list = t.strip().split()
                for i in range(1,len(t_list)-1,2):
                    category_dict[t_list[i]] = t_list[i+1]
        return category_dict

# %%
def generate_category_lookup():
        state = ""
        category_tree = {}
        tool_file = open("../omictool_toollist.txt","r")
        for t in tool_file:
                t_list = t.strip().split()
                if t_list[-3] not in category_tree:
                    if len(t_list) > 5:
                        category_tree[t_list[-3]] = t_list[-5] 
                    else:
                        category_tree[t_list[-3]] = None
                        
                    
        return category_tree

# %%
def generate_tool_dict(category_lookup,interested_category):
        state = ""
        tool_dict = {}
        try:
                tool_file = open("../omictool_toollist.txt","r")
                for t in tqdm(tool_file):
                        tool = t.strip().split()[-1]
                        state = tool
                        omictool = "https://omictools.com"+tool
                        response = requests.get(omictool)
                        html = BeautifulSoup(response.text,"html5lib")
                        a_list = html.find_all('a')
                        if tool not in tool_dict:
                            tool_dict[tool] = set()
                        print(a_list)
                        for a in a_list:
#                                 print(a.get('href'))
                                if a.get('href') != None:
                                    print(a.get('href')[-8:])
                                    if a.get('href')[-8:] == "category":
                                        print(a)
                                        if a.get('href') in interested_category:
                                            tool_dict[tool].add(a.get('href'))
                                        else:
                                            if a.get('href') in category_lookup:
                                                tool_dict[tool].add(category_lookup[a.get('href')])
                        time.sleep(0.1)
                return tool_dict
        except:
            raise

# %%
def generate_pmid_dict():
    state = ""
    pmid_dict = {}
    try:
            tool_file = open("../omictool_toollist_pmid.txt","r")
            for t in tool_file:
                    pmid = t.strip().split()[-1]
                    tool = t.strip().split()[-2]
                    if pmid not in pmid_dict:
                        pmid_dict[pmid] = set()
                    pmid_dict[pmid].add(tool)
            return pmid_dict
    except:
        raise

# %%
def pmid_mapping(tool_dict,category_dict):
    mapping = {}

# %%
category_dict = generate_category_dict()
category_lookup = generate_category_lookup()

# %%
category_tree = {}
for i in category_lookup:
    if category_lookup[i] != None:
        if category_lookup[i] not in category_tree:
            category_tree[category_lookup[i]] = set()
        category_tree[category_lookup[i]].add(i)
    else:
        category_tree[i] = None

# %%
interested_category = set()
for i in category_tree:
    if category_tree[i] != None:
        number_list = [int(category_dict[j]) for j in category_tree[i]]
        checking = all(j > 100 for j in number_list)
        if checking:
            for child in category_tree[i]:
                interested_category.add(child)
        else:
            interested_category.add(i)

# %%
with open('tool_dict.pickle', 'rb') as f:
    tool_dict = pickle.load(f)
# Out:
# 154

# %%
tool_dict = generate_tool_dict(category_lookup,interested_category)
# Out:
# 0it [00:00, ?it/s]
#
#
# 1it [00:02,  2.01s/it]
#
#
# 2it [00:03,  1.82s/it]
#
#
# 3it [00:04,  1.67s/it]
#
#
# 4it [00:05,  1.54s/it]
#
#
# 5it [00:06,  1.39s/it]
#
#
# 6it [00:08,  1.32s/it]
#
#
# 7it [00:09,  1.26s/it]
#
#
# 8it [00:11,  1.44s/it]
#
#
# 9it [00:12,  1.44s/it]
#
#
# 10it [00:14,  1.64s/it]
#
#
# 11it [00:16,  1.76s/it]
#
#
# 12it [00:18,  1.63s/it]
#
#
# 13it [00:19,  1.52s/it]
#
#
# 14it [00:20,  1.46s/it]
#
#
# 15it [00:21,  1.40s/it]
#
#
# 16it [00:23,  1.35s/it]
#
#
# 17it [00:25,  1.58s/it]
#
#
# 18it [00:26,  1.50s/it]
#
#
# 19it [00:27,  1.45s/it]
#
#
# 20it [00:29,  1.38s/it]
#
#
# 21it [00:30,  1.31s/it]
#
#
# 22it [00:31,  1.26s/it]
#
#
# 23it [00:32,  1.21s/it]
#
#
# 24it [00:33,  1.21s/it]
#
#
# 25it [00:34,  1.23s/it]
#
#
# 26it [00:36,  1.20s/it]
#
#
# 27it [00:37,  1.22s/it]
#
#
# 28it [00:38,  1.21s/it]
#
#
# 29it [00:39,  1.23s/it]
#
#
# 30it [00:41,  1.25s/it]
#
#
# 31it [00:42,  1.22s/it]
#
#
# 32it [00:43,  1.28s/it]
#
#
# 33it [00:45,  1.36s/it]
#
#
# 34it [00:46,  1.32s/it]
#
#
# 35it [00:47,  1.26s/it]
#
#
# 36it [00:48,  1.23s/it]
#
#
# 37it [00:50,  1.25s/it]
#
#
# 38it [00:51,  1.26s/it]
#
#
# 39it [00:52,  1.34s/it]
#
#
# 40it [00:54,  1.33s/it]
#
#
# 41it [00:55,  1.31s/it]
#
#
# 42it [00:56,  1.30s/it]
#
#
# 43it [00:57,  1.24s/it]
#
#
# 44it [00:58,  1.22s/it]
#
#
# 45it [01:00,  1.23s/it]
#
#
# 46it [01:01,  1.17s/it]
#
#
# 47it [01:02,  1.22s/it]
#
#
# 48it [01:03,  1.21s/it]
#
#
# 49it [01:04,  1.22s/it]
#
#
# 50it [01:06,  1.24s/it]
#
#
# 51it [01:07,  1.32s/it]
#
#
# 52it [01:08,  1.26s/it]
#
#
# 53it [01:10,  1.24s/it]
#
#
# 54it [01:11,  1.23s/it]
#
#
# 55it [01:12,  1.20s/it]
#
#
# 56it [01:13,  1.20s/it]
#
#
# 57it [01:14,  1.22s/it]
#
#
# 58it [01:15,  1.17s/it]
#
#
# 59it [01:17,  1.15s/it]
#
#
# 60it [01:18,  1.16s/it]
#
#
# 61it [01:19,  1.21s/it]
#
#
# 62it [01:20,  1.19s/it]
#
#
# 63it [01:21,  1.19s/it]
#
#
# 64it [01:23,  1.17s/it]
#
#
# 65it [01:24,  1.20s/it]
#
#
# 66it [01:25,  1.19s/it]
#
#
# 67it [01:26,  1.26s/it]
#
#
# 68it [01:28,  1.28s/it]
#
#
# 69it [01:29,  1.20s/it]
#
#
# 70it [01:30,  1.18s/it]
#
#
# 71it [01:31,  1.20s/it]
#
#
# 72it [01:32,  1.18s/it]
#
#
# 73it [01:34,  1.21s/it]
#
#
# 74it [01:36,  1.48s/it]
#
#
# 75it [01:38,  1.68s/it]
#
#
# 76it [01:39,  1.58s/it]
#
#
# 77it [01:41,  1.63s/it]
#
#
# 78it [01:42,  1.53s/it]
#
#
# 79it [01:44,  1.47s/it]
#
#
# 80it [01:45,  1.37s/it]
#
#
# 81it [01:46,  1.35s/it]
#
#
# 82it [01:47,  1.33s/it]
#
#
# 83it [01:48,  1.23s/it]
#
#
# 84it [01:50,  1.26s/it]
#
#
# 85it [01:51,  1.22s/it]
#
#
# 86it [01:52,  1.24s/it]
#
#
# 87it [01:53,  1.25s/it]
#
#
# 88it [01:55,  1.26s/it]
#
#
# 89it [01:56,  1.27s/it]
#
#
# 90it [01:57,  1.22s/it]
#
#
# 91it [01:58,  1.19s/it]
#
#
# 92it [01:59,  1.22s/it]
#
#
# 93it [02:00,  1.19s/it]
#
#
# 94it [02:02,  1.18s/it]
#
#
# 95it [02:03,  1.23s/it]
#
#
# 96it [02:04,  1.26s/it]
#
#
# 97it [02:06,  1.27s/it]
#
#
# 98it [02:07,  1.28s/it]
#
#
# 99it [02:08,  1.26s/it]
#
#
# 100it [02:09,  1.26s/it]
#
#
# 101it [02:11,  1.23s/it]
#
#
# 102it [02:12,  1.20s/it]
#
#
# 103it [02:13,  1.18s/it]
#
#
# 104it [02:14,  1.21s/it]
#
#
# 105it [02:15,  1.24s/it]
#
#
# 106it [02:17,  1.25s/it]
#
#
# 107it [02:18,  1.23s/it]
#
#
# 108it [02:19,  1.18s/it]
#
#
# 109it [02:20,  1.24s/it]
#
#
# 110it [02:22,  1.27s/it]
#
#
# 111it [02:23,  1.30s/it]
#
#
# 112it [02:24,  1.26s/it]
#
#
# 113it [02:25,  1.29s/it]
#
#
# 114it [02:27,  1.22s/it]
#
#
# 115it [02:28,  1.21s/it]
#
#
# 116it [02:29,  1.21s/it]
#
#
# 117it [02:30,  1.19s/it]
#
#
# 118it [02:31,  1.23s/it]
#
#
# 119it [02:33,  1.22s/it]
#
#
# 120it [02:34,  1.25s/it]
#
#
# 121it [02:35,  1.24s/it]
#
#
# 122it [02:36,  1.26s/it]
#
#
# 123it [02:38,  1.27s/it]
#
#
# 124it [02:39,  1.28s/it]
#
#
# 125it [02:41,  1.54s/it]
#
#
# 126it [02:44,  1.77s/it]
#
#
# 127it [02:45,  1.64s/it]
#
#
# 128it [02:47,  1.79s/it]
#
#
# 129it [02:48,  1.64s/it]
#
#
# 130it [02:50,  1.54s/it]
#
#
# 131it [02:51,  1.49s/it]
#
#
# 132it [02:52,  1.39s/it]
#
#
# 133it [02:53,  1.38s/it]
#
#
# 134it [02:55,  1.34s/it]
#
#
# 135it [02:56,  1.29s/it]
#
#
# 136it [02:57,  1.29s/it]
#
#
# 137it [02:58,  1.29s/it]
#
#
# 138it [03:00,  1.28s/it]
#
#
# 139it [03:01,  1.25s/it]
#
#
# 140it [03:02,  1.26s/it]
#
#
# 141it [03:04,  1.28s/it]
#
#
# 142it [03:05,  1.21s/it]
#
#
# 143it [03:06,  1.23s/it]
#
#
# 144it [03:07,  1.22s/it]
#
#
# 145it [03:09,  1.43s/it]
#
#
# 146it [03:10,  1.43s/it]
#
#
# 147it [03:12,  1.40s/it]
#
#
# 148it [03:13,  1.36s/it]
#
#
# 149it [03:14,  1.29s/it]
#
#
# 150it [03:16,  1.51s/it]
#
#
# 151it [03:17,  1.41s/it]
#
#
# 152it [03:19,  1.39s/it]
#
#
# 153it [03:20,  1.36s/it]
#
#
# 154it [03:21,  1.34s/it]
#
#
# 155it [03:23,  1.33s/it]
#
#
# 156it [03:24,  1.30s/it]
#
#
# 157it [03:25,  1.25s/it]
#
#
# 158it [03:26,  1.24s/it]
#
#
# 159it [03:27,  1.22s/it]
#
#
# 160it [03:28,  1.19s/it]
#
#
# 161it [03:30,  1.23s/it]
#
#
# 162it [03:31,  1.22s/it]
#
#
# 163it [03:32,  1.19s/it]
#
#
# 164it [03:33,  1.24s/it]
#
#
# 165it [03:35,  1.20s/it]
#
#
# 166it [03:36,  1.23s/it]
#
#
# 167it [03:37,  1.24s/it]
#
#
# 168it [03:38,  1.25s/it]
#
#
# 169it [03:39,  1.21s/it]
#
#
# 170it [03:41,  1.24s/it]
#
#
# 171it [03:42,  1.20s/it]
#
#
# 172it [03:43,  1.18s/it]
#
#
# 173it [03:44,  1.22s/it]
#
#
# 174it [03:45,  1.20s/it]
#
#
# 175it [03:47,  1.21s/it]
#
#
# 176it [03:48,  1.24s/it]
#
#
# 177it [03:49,  1.20s/it]
#
#
# 178it [03:50,  1.21s/it]
#
#
# 179it [03:52,  1.19s/it]
#
#
# 180it [03:53,  1.18s/it]
#
#
# 181it [03:54,  1.27s/it]
#
#
# 182it [03:55,  1.28s/it]
#
#
# 183it [03:57,  1.28s/it]
#
#
# 184it [03:58,  1.31s/it]
#
#
# 185it [04:00,  1.41s/it]
#
#
# 186it [04:01,  1.33s/it]
#
#
# 187it [04:02,  1.27s/it]
#
#
# 188it [04:03,  1.29s/it]
#
#
# 189it [04:05,  1.28s/it]
#
#
# 190it [04:06,  1.27s/it]
#
#
# 191it [04:07,  1.27s/it]
#
#
# 192it [04:08,  1.29s/it]
#
#
# 193it [04:10,  1.25s/it]
#
#
# 194it [04:11,  1.26s/it]
#
#
# 195it [04:12,  1.27s/it]
#
#
# 196it [04:14,  1.50s/it]
#
#
# 197it [04:15,  1.39s/it]
#
#
# 198it [04:17,  1.33s/it]
#
#
# 199it [04:18,  1.25s/it]
#
#
# 200it [04:19,  1.41s/it]
#
#
# 201it [04:21,  1.57s/it]
#
#
# 202it [04:23,  1.49s/it]
#
#
# 203it [04:24,  1.41s/it]
#
#
# 204it [04:25,  1.44s/it]
#
#
# 205it [04:27,  1.37s/it]
#
#
# 206it [04:28,  1.34s/it]
#
#
# 207it [04:30,  1.58s/it]
#
#
# 208it [04:31,  1.51s/it]
#
#
# 209it [04:33,  1.45s/it]
#
#
# 210it [04:34,  1.41s/it]
#
#
# 211it [04:35,  1.33s/it]
#
#
# 212it [04:37,  1.34s/it]
#
#
# 213it [04:39,  1.58s/it]
#
#
# 214it [04:40,  1.50s/it]
#
#
# 215it [04:41,  1.45s/it]
#
#
# 216it [04:43,  1.44s/it]
#
#
# 217it [04:44,  1.37s/it]
#
#
# 218it [04:45,  1.27s/it]
#
#
# 219it [04:46,  1.22s/it]
#
#
# 220it [04:47,  1.21s/it]
#
#
# 221it [04:48,  1.16s/it]
#
#
# 222it [04:50,  1.22s/it]
#
#
# 223it [04:51,  1.25s/it]
#
#
# 224it [04:52,  1.25s/it]
#
#
# 225it [04:53,  1.22s/it]
#
#
# 226it [04:54,  1.19s/it]
#
#
# 227it [04:56,  1.17s/it]
#
#
# 228it [04:57,  1.15s/it]
#
#
# 229it [04:58,  1.12s/it]
#
#
# 230it [04:59,  1.13s/it]
#
#
# 231it [05:00,  1.16s/it]
#
#
# 232it [05:01,  1.14s/it]
#
#
# 233it [05:02,  1.14s/it]
#
#
# 234it [05:04,  1.14s/it]
#
#
# 235it [05:05,  1.13s/it]
#
#
# 236it [05:06,  1.15s/it]
#
#
# 237it [05:07,  1.16s/it]
#
#
# 238it [05:08,  1.19s/it]
#
#
# 239it [05:09,  1.16s/it]
#
#
# 240it [05:11,  1.17s/it]
#
#
# 241it [05:12,  1.20s/it]
#
#
# 242it [05:13,  1.22s/it]
#
#
# 243it [05:14,  1.23s/it]
#
#
# 244it [05:16,  1.50s/it]
#
#
# 245it [05:18,  1.46s/it]
#
#
# 246it [05:20,  1.60s/it]
#
#
# 247it [05:21,  1.48s/it]
#
#
# 248it [05:22,  1.37s/it]
#
#
# 249it [05:23,  1.34s/it]
#
#
# 250it [05:25,  1.35s/it]
#
#
# 251it [05:27,  1.65s/it]
#
#
# 252it [05:28,  1.56s/it]
#
#
# 253it [05:30,  1.43s/it]
#
#
# 254it [05:31,  1.40s/it]
#
#
# 255it [05:32,  1.39s/it]
#
#
# 256it [05:34,  1.35s/it]
#
#
# 257it [05:35,  1.31s/it]
#
#
# 258it [05:36,  1.23s/it]
#
#
# 259it [05:37,  1.25s/it]
#
#
# 260it [05:38,  1.27s/it]
#
#
# 261it [05:40,  1.25s/it]
#
#
# 262it [05:41,  1.27s/it]
#
#
# 263it [05:42,  1.27s/it]
#
#
# 264it [05:43,  1.23s/it]
#
#
# 265it [05:45,  1.26s/it]
#
#
# 266it [05:46,  1.19s/it]
#
#
# 267it [05:47,  1.22s/it]
#
#
# 268it [05:48,  1.20s/it]
#
#
# 269it [05:49,  1.22s/it]
#
#
# 270it [05:51,  1.24s/it]
#
#
# 271it [05:52,  1.25s/it]
#
#
# 272it [05:54,  1.63s/it]
#
#
# 273it [05:56,  1.62s/it]
#
#
# 274it [05:58,  1.77s/it]
#
#
# 275it [06:00,  1.65s/it]
#
#
# 276it [06:01,  1.54s/it]
#
#
# 277it [06:02,  1.43s/it]
#
#
# 278it [06:03,  1.33s/it]
#
#
# 279it [06:05,  1.57s/it]
#
#
# 280it [06:06,  1.47s/it]
#
#
# 281it [06:08,  1.43s/it]
#
#
# 282it [06:09,  1.39s/it]
#
#
# 283it [06:10,  1.33s/it]
#
#
# 284it [06:11,  1.26s/it]
#
#
# 285it [06:13,  1.24s/it]
#
#
# 286it [06:14,  1.19s/it]
#
#
# 287it [06:15,  1.21s/it]
#
#
# 288it [06:16,  1.22s/it]
#
#
# 289it [06:17,  1.18s/it]
#
#
# 290it [06:18,  1.14s/it]
#
#
# 291it [06:19,  1.14s/it]
#
#
# 292it [06:21,  1.14s/it]
#
#
# 293it [06:22,  1.14s/it]
#
#
# 294it [06:23,  1.18s/it]
#
#
# 295it [06:24,  1.20s/it]
#
#
# 296it [06:25,  1.17s/it]
#
#
# 297it [06:26,  1.16s/it]
#
#
# 298it [06:28,  1.19s/it]
#
#
# 299it [06:29,  1.18s/it]
#
#
# 300it [06:30,  1.16s/it]
#
#
# 301it [06:31,  1.13s/it]
#
#
# 302it [06:32,  1.13s/it]
#
#
# 303it [06:33,  1.19s/it]
#
#
# 304it [06:35,  1.23s/it]
#
#
# 305it [06:36,  1.20s/it]
#
#
# 306it [06:37,  1.22s/it]
# 307it [06:38,  1.23s/it]
#
#
# 308it [06:40,  1.23s/it]
#
#
# 309it [06:41,  1.22s/it]
#
#
# 310it [06:42,  1.24s/it]
#
#
# 311it [06:43,  1.25s/it]
#
#
# 312it [06:45,  1.24s/it]
#
#
# 313it [06:46,  1.26s/it]
#
#
# 314it [06:47,  1.29s/it]
#
#
# 315it [06:48,  1.21s/it]
#
#
# 316it [06:51,  1.51s/it]
#
#
# 317it [06:53,  1.71s/it]
#
#
# 318it [06:55,  1.83s/it]
#
#
# 319it [06:57,  1.95s/it]
#
#
# 320it [06:58,  1.75s/it]
#
#
# 321it [07:00,  1.59s/it]
#
#
# 322it [07:01,  1.47s/it]
#
#
# 323it [07:02,  1.41s/it]
#
#
# 324it [07:03,  1.35s/it]
#
#
# 325it [07:04,  1.30s/it]
#
#
# 326it [07:06,  1.25s/it]
#
#
# 327it [07:07,  1.21s/it]
#
#
# 328it [07:08,  1.21s/it]
#
#
# 329it [07:09,  1.22s/it]
#
#
# 330it [07:10,  1.24s/it]
#
#
# 331it [07:12,  1.23s/it]
#
#
# 332it [07:13,  1.24s/it]
#
#
# 333it [07:14,  1.21s/it]
#
#
# 334it [07:15,  1.21s/it]
#
#
# 335it [07:17,  1.24s/it]
#
#
# 336it [07:18,  1.21s/it]
#
#
# 337it [07:19,  1.21s/it]
#
#
# 338it [07:20,  1.19s/it]
#
#
# 339it [07:21,  1.20s/it]
#
#
# 340it [07:22,  1.19s/it]
#
#
# 341it [07:24,  1.18s/it]
#
#
# 342it [07:25,  1.21s/it]
#
#
# 343it [07:26,  1.18s/it]
#
#
# 344it [07:27,  1.24s/it]
#
#
# 345it [07:29,  1.25s/it]
#
#
# 346it [07:30,  1.25s/it]
#
#
# 347it [07:31,  1.26s/it]
#
#
# 348it [07:32,  1.23s/it]
#
#
# 349it [07:33,  1.20s/it]
#
#
# 350it [07:35,  1.18s/it]
#
#
# 351it [07:36,  1.20s/it]
#
#
# 352it [07:37,  1.16s/it]
#
#
# 353it [07:38,  1.20s/it]
#
#
# 354it [07:39,  1.20s/it]
#
#
# 355it [07:41,  1.22s/it]
#
#
# 356it [07:42,  1.24s/it]
#
#
# 357it [07:43,  1.25s/it]
#
#
# 358it [07:44,  1.21s/it]
#
#
# 359it [07:46,  1.23s/it]
#
#
# 360it [07:47,  1.19s/it]
#
#
# 361it [07:48,  1.23s/it]
#
#
# 362it [07:49,  1.23s/it]
#
#
# 363it [07:50,  1.18s/it]
#
#
# 364it [07:53,  1.47s/it]
#
#
# 365it [07:55,  1.67s/it]
#
#
# 366it [07:56,  1.54s/it]
#
#
# 367it [07:57,  1.46s/it]
#
#
# 368it [07:59,  1.64s/it]
#
#
# 369it [08:01,  1.55s/it]
#
#
# 370it [08:02,  1.43s/it]
#
#
# 371it [08:03,  1.39s/it]
#
#
# 372it [08:04,  1.30s/it]
#
#
# 373it [08:05,  1.26s/it]
#
#
# 374it [08:07,  1.44s/it]
#
#
# 375it [08:08,  1.35s/it]
#
#
# 376it [08:10,  1.52s/it]
#
#
# 377it [08:11,  1.45s/it]
#
#
# 378it [08:13,  1.36s/it]
#
#
# 379it [08:14,  1.33s/it]
#
#
# 380it [08:15,  1.31s/it]
#
#
# 381it [08:16,  1.27s/it]
#
#
# 382it [08:17,  1.22s/it]
#
#
# 383it [08:19,  1.48s/it]
#
#
# 384it [08:22,  1.70s/it]
#
#
# 385it [08:24,  1.84s/it]
#
#
# 386it [08:25,  1.78s/it]
#
#
# 387it [08:28,  1.86s/it]
#
#
# 388it [08:29,  1.68s/it]
#
#
# 389it [08:31,  1.87s/it]
#
#
# 390it [08:32,  1.71s/it]
#
#
# 391it [08:34,  1.59s/it]
#
#
# 392it [08:35,  1.45s/it]
#
#
# 393it [08:36,  1.43s/it]
#
#
# 394it [08:38,  1.57s/it]
#
#
# 395it [08:40,  1.72s/it]
#
#
# 396it [08:42,  1.62s/it]
#
#
# 397it [08:44,  1.74s/it]
#
#
# 398it [08:45,  1.60s/it]
#
#
# 399it [08:47,  1.73s/it]
#
#
# 400it [08:48,  1.61s/it]
#
#
# 401it [08:50,  1.54s/it]
#
#
# 402it [08:51,  1.48s/it]
#
#
# 403it [08:52,  1.37s/it]
#
#
# 404it [08:53,  1.30s/it]
#
#
# 405it [08:55,  1.33s/it]
#
#
# 406it [08:56,  1.46s/it]
#
#
# 407it [08:58,  1.41s/it]
#
#
# 408it [08:59,  1.37s/it]
#
#
# 409it [09:00,  1.31s/it]
#
#
# 410it [09:01,  1.28s/it]
#
#
# 411it [09:02,  1.24s/it]
#
#
# 412it [09:04,  1.25s/it]
#
#
# 413it [09:05,  1.23s/it]
#
#
# 414it [09:06,  1.21s/it]
#
#
# 415it [09:07,  1.21s/it]
#
#
# 416it [09:08,  1.20s/it]
#
#
# 417it [09:10,  1.22s/it]
#
#
# 418it [09:11,  1.24s/it]
#
#
# 419it [09:12,  1.21s/it]
#
#
# 420it [09:13,  1.24s/it]
#
#
# 421it [09:15,  1.23s/it]
#
#
# 422it [09:16,  1.22s/it]
#
#
# 423it [09:17,  1.24s/it]
#
#
# 424it [09:18,  1.25s/it]
#
#
# 425it [09:21,  1.50s/it]
#
#
# 426it [09:22,  1.45s/it]
#
#
# 427it [09:23,  1.40s/it]
#
#
# 428it [09:24,  1.37s/it]
#
#
# 429it [09:26,  1.33s/it]
#
#
# 430it [09:27,  1.33s/it]
#
#
# 431it [09:28,  1.28s/it]
#
#
# 432it [09:29,  1.24s/it]
#
#
# 433it [09:31,  1.26s/it]
#
#
# 434it [09:32,  1.26s/it]
#
#
# 435it [09:33,  1.19s/it]
#
#
# 436it [09:34,  1.21s/it]
#
#
# 437it [09:35,  1.19s/it]
#
#
# 438it [09:37,  1.26s/it]
#
#
# 439it [09:38,  1.19s/it]
#
#
# 440it [09:39,  1.21s/it]
#
#
# 441it [09:40,  1.18s/it]
#
#
# 442it [09:41,  1.20s/it]
#
#
# 443it [09:43,  1.17s/it]
#
#
# 444it [09:44,  1.13s/it]
#
#
# 445it [09:45,  1.25s/it]
#
#
# 446it [09:47,  1.34s/it]
#
#
# 447it [09:48,  1.32s/it]
#
#
# 448it [09:49,  1.26s/it]
#
#
# 449it [09:50,  1.28s/it]
#
#
# 450it [09:52,  1.26s/it]
#
#
# 451it [09:53,  1.22s/it]
#
#
# 452it [09:54,  1.26s/it]
#
#
# 453it [09:55,  1.23s/it]
#
#
# 454it [09:56,  1.18s/it]
#
#
# 455it [09:58,  1.23s/it]
#
#
# 456it [09:59,  1.23s/it]
#
#
# 457it [10:00,  1.25s/it]
#
#
# 458it [10:01,  1.26s/it]
#
#
# 459it [10:03,  1.27s/it]
#
#
# 460it [10:04,  1.29s/it]
#
#
# 461it [10:06,  1.58s/it]
#
#
# 462it [10:08,  1.73s/it]
#
#
# 463it [10:10,  1.59s/it]
#
#
# 464it [10:11,  1.45s/it]
#
#
# 465it [10:12,  1.40s/it]
#
#
# 466it [10:13,  1.39s/it]
#
#
# 467it [10:15,  1.35s/it]
#
#
# 468it [10:16,  1.26s/it]
#
#
# 469it [10:17,  1.27s/it]
#
#
# 470it [10:19,  1.50s/it]
#
#
# 471it [10:21,  1.70s/it]
#
#
# 472it [10:23,  1.87s/it]
#
#
# 473it [10:25,  1.89s/it]
#
#
# 474it [10:27,  1.74s/it]
#
#
# 475it [10:28,  1.71s/it]
#
#
# 476it [10:30,  1.61s/it]
#
#
# 477it [10:31,  1.46s/it]
#
#
# 478it [10:32,  1.40s/it]
#
#
# 479it [10:33,  1.33s/it]
#
#
# 480it [10:35,  1.31s/it]
#
#
# 481it [10:36,  1.23s/it]
#
#
# 482it [10:37,  1.22s/it]
#
#
# 483it [10:38,  1.24s/it]
#
#
# 484it [10:39,  1.20s/it]
#
#
# 485it [10:41,  1.24s/it]
#
#
# 486it [10:42,  1.26s/it]
#
#
# 487it [10:43,  1.27s/it]
#
#
# 488it [10:45,  1.30s/it]
#
#
# 489it [10:46,  1.30s/it]
#
#
# 490it [10:47,  1.33s/it]
#
#
# 491it [10:49,  1.51s/it]
#
#
# 492it [10:51,  1.46s/it]
#
#
# 493it [10:52,  1.41s/it]
#
#
# 494it [10:53,  1.34s/it]
#
#
# 495it [10:55,  1.51s/it]
#
#
# 496it [10:57,  1.58s/it]
#
#
# 497it [10:59,  1.70s/it]
#
#
# 498it [11:00,  1.57s/it]
#
#
# 499it [11:01,  1.49s/it]
#
#
# 500it [11:03,  1.43s/it]
#
#
# 501it [11:04,  1.39s/it]
#
#
# 502it [11:05,  1.32s/it]
#
#
# 503it [11:06,  1.30s/it]
#
#
# 504it [11:07,  1.26s/it]
#
#
# 505it [11:08,  1.22s/it]
#
#
# 506it [11:10,  1.20s/it]
#
#
# 507it [11:11,  1.18s/it]
#
#
# 508it [11:12,  1.24s/it]
#
#
# 509it [11:14,  1.29s/it]
#
#
# 510it [11:15,  1.22s/it]
#
#
# 511it [11:16,  1.34s/it]
#
#
# 512it [11:17,  1.27s/it]
#
#
# 513it [11:19,  1.28s/it]
#
#
# 514it [11:20,  1.28s/it]
#
#
# 515it [11:21,  1.27s/it]
#
#
# 516it [11:22,  1.25s/it]
#
#
# 517it [11:24,  1.24s/it]
#
#
# 518it [11:25,  1.21s/it]
#
#
# 519it [11:26,  1.23s/it]
#
#
# 520it [11:27,  1.22s/it]
#
#
# 521it [11:28,  1.23s/it]
#
#
# 522it [11:30,  1.20s/it]
#
#
# 523it [11:31,  1.18s/it]
#
#
# 524it [11:32,  1.19s/it]
#
#
# 525it [11:33,  1.22s/it]
#
#
# 526it [11:35,  1.52s/it]
#
#
# 527it [11:37,  1.55s/it]
#
#
# 528it [11:39,  1.68s/it]
#
#
# 529it [11:40,  1.53s/it]
#
#
# 530it [11:42,  1.46s/it]
#
#
# 531it [11:43,  1.34s/it]
#
#
# 532it [11:44,  1.33s/it]
#
#
# 533it [11:46,  1.59s/it]
#
#
# 534it [11:47,  1.51s/it]
#
#
# 535it [11:49,  1.45s/it]
#
#
# 536it [11:51,  1.67s/it]
#
#
# 537it [11:52,  1.56s/it]
#
#
# 538it [11:54,  1.54s/it]
#
#
# 539it [11:55,  1.46s/it]
#
#
# 540it [11:56,  1.36s/it]
#
#
# 541it [11:57,  1.29s/it]
#
#
# 542it [11:58,  1.23s/it]
#
#
# 543it [12:00,  1.24s/it]
#
#
# 544it [12:01,  1.26s/it]
#
#
# 545it [12:02,  1.25s/it]
#
#
# 546it [12:04,  1.32s/it]
#
#
# 547it [12:05,  1.33s/it]
#
#
# 548it [12:06,  1.32s/it]
#
#
# 549it [12:08,  1.33s/it]
#
#
# 550it [12:09,  1.32s/it]
#
#
# 551it [12:10,  1.25s/it]
#
#
# 552it [12:11,  1.21s/it]
#
#
# 553it [12:12,  1.20s/it]
#
#
# 554it [12:14,  1.22s/it]
#
#
# 555it [12:15,  1.22s/it]
#
#
# 556it [12:16,  1.30s/it]
#
#
# 557it [12:18,  1.30s/it]
#
#
# 558it [12:19,  1.32s/it]
#
#
# 559it [12:20,  1.32s/it]
#
#
# 560it [12:21,  1.29s/it]
#
#
# 561it [12:23,  1.36s/it]
#
#
# 562it [12:25,  1.56s/it]
#
#
# 563it [12:26,  1.50s/it]
#
#
# 564it [12:28,  1.46s/it]
#
#
# 565it [12:29,  1.40s/it]
#
#
# 566it [12:30,  1.36s/it]
#
#
# 567it [12:31,  1.28s/it]
#
#
# 568it [12:33,  1.52s/it]
#
#
# 569it [12:36,  1.71s/it]
#
#
# 570it [12:38,  1.81s/it]
#
#
# 571it [12:39,  1.69s/it]
#
#
# 572it [12:41,  1.80s/it]
#
#
# 573it [12:42,  1.67s/it]
#
#
# 574it [12:44,  1.55s/it]
#
#
# 575it [12:45,  1.50s/it]
#
#
# 576it [12:46,  1.44s/it]
#
#
# 577it [12:48,  1.42s/it]
#
#
# 578it [12:50,  1.60s/it]
#
#
# 579it [12:51,  1.50s/it]
#
#
# 580it [12:52,  1.46s/it]
#
#
# 581it [12:54,  1.41s/it]
#
#
# 582it [12:56,  1.60s/it]
#
#
# 583it [12:58,  1.73s/it]
#
#
# 584it [12:59,  1.64s/it]
#
#
# 585it [13:01,  1.56s/it]
#
#
# 586it [13:02,  1.50s/it]
#
#
# 587it [13:03,  1.46s/it]
#
#
# 588it [13:05,  1.40s/it]
#
#
# 589it [13:06,  1.35s/it]
#
#
# 590it [13:07,  1.33s/it]
#
#
# 591it [13:08,  1.26s/it]
#
#
# 592it [13:10,  1.28s/it]
#
#
# 593it [13:11,  1.36s/it]
#
#
# 594it [13:12,  1.29s/it]
#
#
# 595it [13:13,  1.24s/it]
#
#
# 596it [13:15,  1.24s/it]
#
#
# 597it [13:16,  1.23s/it]
#
#
# 598it [13:17,  1.19s/it]
#
#
# 599it [13:18,  1.20s/it]
#
#
# 600it [13:19,  1.17s/it]
#
#
# 601it [13:20,  1.20s/it]
#
#
# 602it [13:22,  1.24s/it]
#
#
# 603it [13:23,  1.23s/it]
#
#
# 604it [13:24,  1.23s/it]
#
#
# 605it [13:25,  1.22s/it]
#
#
# 606it [13:27,  1.19s/it]
#
#
# 607it [13:28,  1.22s/it]
#
#
# 608it [13:29,  1.18s/it]
#
#
# 609it [13:30,  1.16s/it]
# 610it [13:31,  1.20s/it]
#
#
# 611it [13:33,  1.45s/it]
#
#
# 612it [13:36,  1.70s/it]
#
#
# 613it [13:38,  1.81s/it]
#
#
# 614it [13:40,  1.90s/it]
#
#
# 615it [13:41,  1.72s/it]
#
#
# 616it [13:42,  1.60s/it]
#
#
# 617it [13:44,  1.52s/it]
#
#
# 618it [13:45,  1.40s/it]
#
#
# 619it [13:46,  1.37s/it]
#
#
# 620it [13:48,  1.34s/it]
#
#
# 621it [13:49,  1.29s/it]
#
#
# 622it [13:50,  1.31s/it]
#
#
# 623it [13:51,  1.29s/it]
#
#
# 624it [13:52,  1.24s/it]
#
#
# 625it [13:54,  1.25s/it]
#
#
# 626it [13:55,  1.21s/it]
#
#
# 627it [13:56,  1.22s/it]
#
#
# 628it [13:57,  1.24s/it]
#
#
# 629it [13:58,  1.21s/it]
#
#
# 630it [14:00,  1.22s/it]
#
#
# 631it [14:01,  1.18s/it]
#
#
# 632it [14:02,  1.17s/it]
#
#
# 633it [14:03,  1.19s/it]
#
#
# 634it [14:05,  1.28s/it]
#
#
# 635it [14:06,  1.31s/it]
#
#
# 636it [14:07,  1.27s/it]
#
#
# 637it [14:08,  1.22s/it]
#
#
# 638it [14:09,  1.19s/it]
#
#
# 639it [14:11,  1.17s/it]
#
#
# 640it [14:12,  1.17s/it]
#
#
# 641it [14:13,  1.24s/it]
#
#
# 642it [14:14,  1.25s/it]
#
#
# 643it [14:16,  1.23s/it]
#
#
# 644it [14:17,  1.24s/it]
#
#
# 645it [14:18,  1.20s/it]
#
#
# 646it [14:19,  1.23s/it]
#
#
# 647it [14:21,  1.25s/it]
#
#
# 648it [14:22,  1.26s/it]
#
#
# 649it [14:23,  1.32s/it]
#
#
# 650it [14:25,  1.31s/it]
#
#
# 651it [14:26,  1.27s/it]
#
#
# 652it [14:27,  1.26s/it]
#
#
# 653it [14:28,  1.29s/it]
#
#
# 654it [14:30,  1.29s/it]
#
#
# 655it [14:31,  1.28s/it]
#
#
# 656it [14:32,  1.31s/it]
#
#
# 657it [14:34,  1.29s/it]
#
#
# 658it [14:35,  1.22s/it]
#
#
# 659it [14:36,  1.26s/it]
#
#
# 660it [14:37,  1.27s/it]
#
#
# 661it [14:39,  1.29s/it]
#
#
# 662it [14:40,  1.23s/it]
#
#
# 663it [14:41,  1.26s/it]
#
#
# 664it [14:42,  1.28s/it]
#
#
# 665it [14:44,  1.25s/it]
#
#
# 666it [14:45,  1.21s/it]
#
#
# 667it [14:46,  1.19s/it]
#
#
# 668it [14:47,  1.17s/it]
#
#
# 669it [14:49,  1.58s/it]
#
#
# 670it [14:51,  1.45s/it]
#
#
# 671it [14:52,  1.35s/it]
#
#
# 672it [14:53,  1.33s/it]
#
#
# 673it [14:54,  1.27s/it]
#
#
# 674it [14:55,  1.26s/it]
#
#
# 675it [14:57,  1.28s/it]
#
#
# 676it [14:58,  1.25s/it]
#
#
# 677it [14:59,  1.21s/it]
#
#
# 678it [15:00,  1.20s/it]
#
#
# 679it [15:01,  1.23s/it]
#
#
# 680it [15:03,  1.23s/it]
#
#
# 681it [15:04,  1.26s/it]
#
#
# 682it [15:05,  1.27s/it]
#
#
# 683it [15:07,  1.26s/it]
#
#
# 684it [15:09,  1.51s/it]
#
#
# 685it [15:11,  1.68s/it]
#
#
# 686it [15:13,  1.82s/it]
#
#
# 687it [15:14,  1.69s/it]
#
#
# 688it [15:16,  1.81s/it]
#
#
# 689it [15:18,  1.69s/it]
#
#
# 690it [15:20,  1.76s/it]
#
#
# 691it [15:21,  1.66s/it]
#
#
# 692it [15:22,  1.57s/it]
#
#
# 693it [15:24,  1.51s/it]
#
#
# 694it [15:25,  1.45s/it]
#
#
# 695it [15:26,  1.40s/it]
#
#
# 696it [15:28,  1.37s/it]
#
#
# 697it [15:29,  1.29s/it]
#
#
# 698it [15:30,  1.26s/it]
#
#
# 699it [15:31,  1.22s/it]
#
#
# 700it [15:32,  1.19s/it]
#
#
# 701it [15:34,  1.23s/it]
#
#
# 702it [15:35,  1.20s/it]
#
#
# 703it [15:36,  1.25s/it]
#
#
# 704it [15:37,  1.26s/it]
#
#
# 705it [15:39,  1.28s/it]
#
#
# 706it [15:40,  1.27s/it]
#
#
# 707it [15:41,  1.23s/it]
#
#
# 708it [15:42,  1.20s/it]
#
#
# 709it [15:43,  1.22s/it]
#
#
# 710it [15:45,  1.18s/it]
#
#
# 711it [15:46,  1.16s/it]
#
#
# 712it [15:47,  1.19s/it]
#
#
# 713it [15:48,  1.22s/it]
#
#
# 714it [15:50,  1.27s/it]
#
#
# 715it [15:51,  1.27s/it]
#
#
# 716it [15:52,  1.31s/it]
#
#
# 717it [15:55,  1.63s/it]
#
#
# 718it [15:56,  1.48s/it]
#
#
# 719it [15:57,  1.42s/it]
#
#
# 720it [15:58,  1.34s/it]
#
#
# 721it [15:59,  1.27s/it]
#
#
# 722it [16:01,  1.27s/it]
#
#
# 723it [16:02,  1.31s/it]
#
#
# 724it [16:03,  1.26s/it]
#
#
# 725it [16:05,  1.52s/it]
#
#
# 726it [16:07,  1.49s/it]
#
#
# 727it [16:08,  1.43s/it]
#
#
# 728it [16:09,  1.40s/it]
#
#
# 729it [16:11,  1.37s/it]
#
#
# 730it [16:12,  1.31s/it]
#
#
# 731it [16:13,  1.32s/it]
#
#
# 732it [16:14,  1.26s/it]
#
#
# 733it [16:16,  1.31s/it]
#
#
# 734it [16:17,  1.30s/it]
#
#
# 735it [16:18,  1.28s/it]
#
#
# 736it [16:19,  1.27s/it]
#
#
# 737it [16:21,  1.28s/it]
#
#
# 738it [16:22,  1.41s/it]
#
#
# 739it [16:24,  1.45s/it]
#
#
# 740it [16:25,  1.48s/it]
#
#
# 741it [16:27,  1.44s/it]
#
#
# 742it [16:28,  1.40s/it]
#
#
# 743it [16:29,  1.36s/it]
#
#
# 744it [16:31,  1.30s/it]
#
#
# 745it [16:32,  1.27s/it]
#
#
# 746it [16:33,  1.29s/it]
#
#
# 747it [16:34,  1.29s/it]
#
#
# 748it [16:35,  1.24s/it]
#
#
# 749it [16:37,  1.20s/it]
#
#
# 750it [16:38,  1.22s/it]
#
#
# 751it [16:39,  1.25s/it]
#
#
# 752it [16:40,  1.24s/it]
#
#
# 753it [16:42,  1.26s/it]
#
#
# 754it [16:43,  1.21s/it]
#
#
# 755it [16:45,  1.45s/it]
#
#
# 756it [16:47,  1.66s/it]
#
#
# 757it [16:48,  1.53s/it]
#
#
# 758it [16:50,  1.56s/it]
#
#
# 759it [16:52,  1.74s/it]
#
#
# 760it [16:54,  1.85s/it]
#
#
# 761it [16:56,  1.71s/it]
#
#
# 762it [16:57,  1.61s/it]
#
#
# 763it [16:58,  1.53s/it]
#
#
# 764it [16:59,  1.46s/it]
#
#
# 765it [17:01,  1.37s/it]
#
#
# 766it [17:02,  1.32s/it]
#
#
# 767it [17:03,  1.26s/it]
#
#
# 768it [17:04,  1.22s/it]
#
#
# 769it [17:05,  1.23s/it]
#
#
# 770it [17:07,  1.24s/it]
#
#
# 771it [17:08,  1.24s/it]
#
#
# 772it [17:09,  1.25s/it]
#
#
# 773it [17:10,  1.25s/it]
#
#
# 774it [17:12,  1.25s/it]
#
#
# 775it [17:13,  1.24s/it]
#
#
# 776it [17:14,  1.30s/it]
#
#
# 777it [17:15,  1.25s/it]
#
#
# 778it [17:17,  1.21s/it]
#
#
# 779it [17:18,  1.24s/it]
#
#
# 780it [17:19,  1.23s/it]
#
#
# 781it [17:20,  1.22s/it]
#
#
# 782it [17:22,  1.25s/it]
#
#
# 783it [17:23,  1.20s/it]
#
#
# 784it [17:24,  1.29s/it]
#
#
# 785it [17:26,  1.52s/it]
#
#
# 786it [17:27,  1.44s/it]
#
#
# 787it [17:29,  1.40s/it]
#
#
# 788it [17:30,  1.36s/it]
#
#
# 789it [17:31,  1.35s/it]
#
#
# 790it [17:33,  1.34s/it]
#
#
# 791it [17:34,  1.32s/it]
#
#
# 792it [17:35,  1.28s/it]
#
#
# 793it [17:36,  1.26s/it]
#
#
# 794it [17:38,  1.48s/it]
#
#
# 795it [17:40,  1.51s/it]
#
#
# 796it [17:41,  1.44s/it]
#
#
# 797it [17:43,  1.39s/it]
#
#
# 798it [17:44,  1.35s/it]
#
#
# 799it [17:45,  1.30s/it]
#
#
# 800it [17:46,  1.24s/it]
#
#
# 801it [17:47,  1.24s/it]
#
#
# 802it [17:48,  1.18s/it]
#
#
# 803it [17:50,  1.20s/it]
#
#
# 804it [17:51,  1.23s/it]
#
#
# 805it [17:53,  1.36s/it]
#
#
# 806it [17:55,  1.59s/it]
#
#
# 807it [17:56,  1.49s/it]
#
#
# 808it [17:57,  1.39s/it]
#
#
# 809it [17:58,  1.36s/it]
#
#
# 810it [18:00,  1.32s/it]
#
#
# 811it [18:01,  1.28s/it]
#
#
# 812it [18:02,  1.30s/it]
#
#
# 813it [18:03,  1.26s/it]
#
#
# 814it [18:05,  1.24s/it]
#
#
# 815it [18:06,  1.22s/it]
#
#
# 816it [18:07,  1.16s/it]
#
#
# 817it [18:08,  1.20s/it]
#
#
# 818it [18:09,  1.22s/it]
#
#
# 819it [18:11,  1.48s/it]
#
#
# 820it [18:14,  1.69s/it]
#
#
# 821it [18:15,  1.58s/it]
#
#
# 822it [18:16,  1.51s/it]
#
#
# 823it [18:17,  1.43s/it]
#
#
# 824it [18:19,  1.44s/it]
#
#
# 825it [18:20,  1.41s/it]
#
#
# 826it [18:21,  1.35s/it]
#
#
# 827it [18:23,  1.30s/it]
#
#
# 828it [18:24,  1.25s/it]
#
#
# 829it [18:25,  1.21s/it]
#
#
# 830it [18:26,  1.24s/it]
#
#
# 831it [18:27,  1.25s/it]
#
#
# 832it [18:29,  1.24s/it]
#
#
# 833it [18:30,  1.23s/it]
#
#
# 834it [18:31,  1.28s/it]
#
#
# 835it [18:32,  1.21s/it]
#
#
# 836it [18:33,  1.18s/it]
#
#
# 837it [18:35,  1.19s/it]
#
#
# 838it [18:36,  1.18s/it]
#
#
# 839it [18:37,  1.16s/it]
#
#
# 840it [18:38,  1.19s/it]
#
#
# 841it [18:40,  1.22s/it]
#
#
# 842it [18:41,  1.24s/it]
#
#
# 843it [18:42,  1.20s/it]
#
#
# 844it [18:43,  1.23s/it]
#
#
# 845it [18:45,  1.25s/it]
#
#
# 846it [18:46,  1.21s/it]
#
#
# 847it [18:47,  1.18s/it]
#
#
# 848it [18:48,  1.18s/it]
#
#
# 849it [18:49,  1.15s/it]
#
#
# 850it [18:51,  1.28s/it]
#
#
# 851it [18:52,  1.33s/it]
#
#
# 852it [18:53,  1.31s/it]
#
#
# 853it [18:55,  1.30s/it]
#
#
# 854it [18:56,  1.32s/it]
#
#
# 855it [18:57,  1.31s/it]
#
#
# 856it [18:58,  1.26s/it]
#
#
# 857it [19:01,  1.54s/it]
#
#
# 858it [19:02,  1.44s/it]
#
#
# 859it [19:03,  1.44s/it]
#
#
# 860it [19:04,  1.33s/it]
#
#
# 861it [19:05,  1.27s/it]
#
#
# 862it [19:07,  1.23s/it]
#
#
# 863it [19:08,  1.20s/it]
#
#
# 864it [19:09,  1.23s/it]
#
#
# 865it [19:10,  1.24s/it]
#
#
# 866it [19:11,  1.20s/it]
#
#
# 867it [19:13,  1.22s/it]
#
#
# 868it [19:14,  1.20s/it]
#
#
# 869it [19:15,  1.23s/it]
#
#
# 870it [19:16,  1.21s/it]
#
#
# 871it [19:17,  1.19s/it]
#
#
# 872it [19:19,  1.17s/it]
#
#
# 873it [19:20,  1.19s/it]
#
#
# 874it [19:21,  1.19s/it]
#
#
# 875it [19:22,  1.18s/it]
#
#
# 876it [19:23,  1.22s/it]
#
#
# 877it [19:26,  1.50s/it]
#
#
# 878it [19:27,  1.44s/it]
#
#
# 879it [19:28,  1.42s/it]
#
#
# 880it [19:29,  1.36s/it]
#
#
# 881it [19:31,  1.34s/it]
#
#
# 882it [19:32,  1.34s/it]
#
#
# 883it [19:34,  1.36s/it]
#
#
# 884it [19:35,  1.32s/it]
#
#
# 885it [19:36,  1.41s/it]
#
#
# 886it [19:38,  1.40s/it]
#
#
# 887it [19:40,  1.65s/it]
#
#
# 888it [19:42,  1.83s/it]
#
#
# 889it [19:43,  1.65s/it]
#
#
# 890it [19:45,  1.74s/it]
#
#
# 891it [19:47,  1.60s/it]
#
#
# 892it [19:48,  1.51s/it]
#
#
# 893it [19:49,  1.42s/it]
#
#
# 894it [19:50,  1.31s/it]
#
#
# 895it [19:52,  1.33s/it]
#
#
# 896it [19:53,  1.29s/it]
#
#
# 897it [19:54,  1.29s/it]
#
#
# 898it [19:55,  1.28s/it]
#
#
# 899it [19:57,  1.26s/it]
#
#
# 900it [19:58,  1.26s/it]
#
#
# 901it [19:59,  1.28s/it]
#
#
# 902it [20:00,  1.29s/it]
#
#
# 903it [20:02,  1.24s/it]
#
#
# 904it [20:03,  1.23s/it]
#
#
# 905it [20:04,  1.21s/it]
#
#
# 906it [20:05,  1.20s/it]
#
#
# 907it [20:06,  1.20s/it]
#
#
# 908it [20:07,  1.19s/it]
#
#
# 909it [20:09,  1.22s/it]
#
#
# 910it [20:10,  1.20s/it]
#
#
# 911it [20:11,  1.22s/it]
#
#
# 912it [20:13,  1.47s/it]
# 913it [20:14,  1.37s/it]
#
#
# 914it [20:15,  1.27s/it]
#
#
# 915it [20:17,  1.23s/it]
#
#
# 916it [20:18,  1.39s/it]
#
#
# 917it [20:20,  1.36s/it]
#
#
# 918it [20:21,  1.37s/it]
#
#
# 919it [20:22,  1.30s/it]
#
#
# 920it [20:23,  1.28s/it]
#
#
# 921it [20:25,  1.29s/it]
#
#
# 922it [20:26,  1.29s/it]
#
#
# 923it [20:27,  1.24s/it]
#
#
# 924it [20:29,  1.48s/it]
#
#
# 925it [20:31,  1.63s/it]
#
#
# 926it [20:33,  1.57s/it]
#
#
# 927it [20:34,  1.53s/it]
#
#
# 928it [20:36,  1.72s/it]
#
#
# 929it [20:38,  1.75s/it]
#
#
# 930it [20:39,  1.61s/it]
#
#
# 931it [20:41,  1.54s/it]
#
#
# 932it [20:42,  1.48s/it]
#
#
# 933it [20:43,  1.41s/it]
#
#
# 934it [20:45,  1.38s/it]
#
#
# 935it [20:46,  1.33s/it]
#
#
# 936it [20:47,  1.33s/it]
#
#
# 937it [20:48,  1.26s/it]
#
#
# 938it [20:49,  1.19s/it]
#
#
# 939it [20:50,  1.16s/it]
#
#
# 940it [20:52,  1.20s/it]
#
#
# 941it [20:53,  1.19s/it]
#
#
# 942it [20:54,  1.21s/it]
#
#
# 943it [20:55,  1.21s/it]
#
#
# 944it [20:57,  1.26s/it]
#
#
# 945it [20:58,  1.27s/it]
#
#
# 946it [20:59,  1.34s/it]
#
#
# 947it [21:01,  1.33s/it]
#
#
# 948it [21:02,  1.25s/it]
#
#
# 949it [21:03,  1.25s/it]
#
#
# 950it [21:04,  1.23s/it]
#
#
# 951it [21:05,  1.18s/it]
#
#
# 952it [21:06,  1.18s/it]
#
#
# 953it [21:08,  1.19s/it]
#
#
# 954it [21:09,  1.22s/it]
#
#
# 955it [21:10,  1.25s/it]
#
#
# 956it [21:12,  1.26s/it]
#
#
# 957it [21:13,  1.22s/it]
#
#
# 958it [21:14,  1.17s/it]
#
#
# 959it [21:15,  1.23s/it]
#
#
# 960it [21:17,  1.48s/it]
#
#
# 961it [21:19,  1.71s/it]
#
#
# 962it [21:21,  1.58s/it]
#
#
# 963it [21:22,  1.59s/it]
#
#
# 964it [21:24,  1.76s/it]
#
#
# 965it [21:26,  1.81s/it]
#
#
# 966it [21:28,  1.68s/it]
#
#
# 967it [21:29,  1.59s/it]
#
#
# 968it [21:30,  1.47s/it]
#
#
# 969it [21:31,  1.37s/it]
#
#
# 970it [21:33,  1.34s/it]
#
#
# 971it [21:34,  1.34s/it]
#
#
# 972it [21:35,  1.33s/it]
#
#
# 973it [21:36,  1.25s/it]
#
#
# 974it [21:38,  1.21s/it]
#
#
# 975it [21:39,  1.28s/it]
#
#
# 976it [21:40,  1.24s/it]
#
#
# 977it [21:41,  1.21s/it]
#
#
# 978it [21:42,  1.17s/it]
#
#
# 979it [21:44,  1.17s/it]
#
#
# 980it [21:45,  1.20s/it]
#
#
# 981it [21:46,  1.26s/it]
#
#
# 982it [21:47,  1.20s/it]
#
#
# 983it [21:48,  1.20s/it]
#
#
# 984it [21:50,  1.18s/it]
#
#
# 985it [21:51,  1.14s/it]
#
#
# 986it [21:52,  1.15s/it]
#
#
# 987it [21:53,  1.19s/it]
#
#
# 988it [21:54,  1.15s/it]
#
#
# 989it [21:55,  1.19s/it]
#
#
# 990it [21:57,  1.22s/it]
#
#
# 991it [21:58,  1.22s/it]
#
#
# 992it [21:59,  1.25s/it]
#
#
# 993it [22:01,  1.25s/it]
#
#
# 994it [22:02,  1.24s/it]
#
#
# 995it [22:03,  1.20s/it]
#
#
# 996it [22:04,  1.25s/it]
#
#
# 997it [22:05,  1.21s/it]
#
#
# 998it [22:06,  1.20s/it]
#
#
# 999it [22:08,  1.17s/it]
#
#
# 1000it [22:09,  1.18s/it]
#
#
# 1001it [22:10,  1.22s/it]
#
#
# 1002it [22:11,  1.16s/it]
#
#
# 1003it [22:12,  1.20s/it]
#
#
# 1004it [22:14,  1.18s/it]
#
#
# 1005it [22:15,  1.16s/it]
#
#
# 1006it [22:16,  1.35s/it]
#
#
# 1007it [22:18,  1.29s/it]
#
#
# 1008it [22:19,  1.21s/it]
#
#
# 1009it [22:20,  1.19s/it]
#
#
# 1010it [22:21,  1.18s/it]
#
#
# 1011it [22:22,  1.14s/it]
#
#
# 1012it [22:23,  1.18s/it]
#
#
# 1013it [22:24,  1.18s/it]
#
#
# 1014it [22:26,  1.20s/it]
#
#
# 1015it [22:27,  1.23s/it]
#
#
# 1016it [22:28,  1.25s/it]
#
#
# 1017it [22:29,  1.23s/it]
#
#
# 1018it [22:31,  1.24s/it]
#
#
# 1019it [22:32,  1.24s/it]
#
#
# 1020it [22:33,  1.25s/it]
#
#
# 1021it [22:35,  1.35s/it]
#
#
# 1022it [22:36,  1.40s/it]
#
#
# 1023it [22:38,  1.53s/it]
#
#
# 1024it [22:39,  1.42s/it]
#
#
# 1025it [22:41,  1.43s/it]
#
#
# 1026it [22:42,  1.38s/it]
#
#
# 1027it [22:43,  1.30s/it]
#
#
# 1028it [22:44,  1.29s/it]
#
#
# 1029it [22:46,  1.28s/it]
#
#
# 1030it [22:47,  1.25s/it]
#
#
# 1031it [22:48,  1.27s/it]
#
#
# 1032it [22:50,  1.31s/it]
#
#
# 1033it [22:51,  1.47s/it]
#
#
# 1034it [22:53,  1.39s/it]
#
#
# 1035it [22:54,  1.39s/it]
#
#
# 1036it [22:55,  1.33s/it]
#
#
# 1037it [22:56,  1.31s/it]
#
#
# 1038it [22:58,  1.30s/it]
#
#
# 1039it [22:59,  1.29s/it]
#
#
# 1040it [23:00,  1.21s/it]
#
#
# 1041it [23:01,  1.24s/it]
#
#
# 1042it [23:03,  1.33s/it]
#
#
# 1043it [23:04,  1.38s/it]
#
#
# 1044it [23:06,  1.36s/it]
#
#
# 1045it [23:07,  1.30s/it]
#
#
# 1046it [23:08,  1.25s/it]
#
#
# 1047it [23:09,  1.21s/it]
#
#
# 1048it [23:11,  1.50s/it]
#
#
# 1049it [23:13,  1.47s/it]
#
#
# 1050it [23:14,  1.43s/it]
#
#
# 1051it [23:15,  1.38s/it]
#
#
# 1052it [23:17,  1.36s/it]
#
#
# 1053it [23:18,  1.51s/it]
#
#
# 1054it [23:20,  1.41s/it]
#
#
# 1055it [23:21,  1.44s/it]
#
#
# 1056it [23:22,  1.35s/it]
#
#
# 1057it [23:24,  1.39s/it]
#
#
# 1058it [23:26,  1.61s/it]
#
#
# 1059it [23:27,  1.52s/it]
#
#
# 1060it [23:28,  1.44s/it]
#
#
# 1061it [23:30,  1.39s/it]
#
#
# 1062it [23:31,  1.31s/it]
#
#
# 1063it [23:32,  1.29s/it]
#
#
# 1064it [23:33,  1.29s/it]
#
#
# 1065it [23:35,  1.29s/it]
#
#
# 1066it [23:36,  1.29s/it]
#
#
# 1067it [23:37,  1.35s/it]
#
#
# 1068it [23:39,  1.33s/it]
#
#
# 1069it [23:40,  1.29s/it]
#
#
# 1070it [23:42,  1.56s/it]
#
#
# 1071it [23:43,  1.42s/it]
#
#
# 1072it [23:45,  1.38s/it]
#
#
# 1073it [23:46,  1.37s/it]
#
#
# 1074it [23:47,  1.35s/it]
#
#
# 1075it [23:48,  1.32s/it]
#
#
# 1076it [23:50,  1.32s/it]
#
#
# 1077it [23:51,  1.25s/it]
#
#
# 1078it [23:52,  1.22s/it]
#
#
# 1079it [23:54,  1.47s/it]
#
#
# 1080it [23:55,  1.39s/it]
#
#
# 1081it [23:57,  1.36s/it]
#
#
# 1082it [23:58,  1.33s/it]
#
#
# 1083it [23:59,  1.41s/it]
#
#
# 1084it [24:01,  1.57s/it]
#
#
# 1085it [24:03,  1.48s/it]
#
#
# 1086it [24:04,  1.45s/it]
#
#
# 1087it [24:05,  1.40s/it]
#
#
# 1088it [24:07,  1.36s/it]
#
#
# 1089it [24:08,  1.31s/it]
#
#
# 1090it [24:09,  1.26s/it]
#
#
# 1091it [24:10,  1.22s/it]
#
#
# 1092it [24:11,  1.24s/it]
#
#
# 1093it [24:14,  1.58s/it]
#
#
# 1094it [24:16,  1.74s/it]
#
#
# 1095it [24:18,  1.86s/it]
#
#
# 1096it [24:20,  1.79s/it]
#
#
# 1097it [24:22,  1.85s/it]
#
#
# 1098it [24:23,  1.70s/it]
#
#
# 1099it [24:24,  1.58s/it]
#
#
# 1100it [24:25,  1.48s/it]
#
#
# 1101it [24:27,  1.38s/it]
#
#
# 1102it [24:28,  1.34s/it]
#
#
# 1103it [24:29,  1.43s/it]
#
#
# 1104it [24:31,  1.33s/it]
#
#
# 1105it [24:32,  1.28s/it]
#
#
# 1106it [24:33,  1.23s/it]
#
#
# 1107it [24:34,  1.24s/it]
#
#
# 1108it [24:35,  1.27s/it]
#
#
# 1109it [24:37,  1.30s/it]
#
#
# 1110it [24:38,  1.24s/it]
#
#
# 1111it [24:39,  1.21s/it]
#
#
# 1112it [24:40,  1.18s/it]
#
#
# 1113it [24:41,  1.14s/it]
#
#
# 1114it [24:43,  1.19s/it]
#
#
# 1115it [24:44,  1.21s/it]
#
#
# 1116it [24:45,  1.19s/it]
#
#
# 1117it [24:46,  1.18s/it]
#
#
# 1118it [24:48,  1.44s/it]
#
#
# 1119it [24:49,  1.40s/it]
#
#
# 1120it [24:51,  1.38s/it]
#
#
# 1121it [24:52,  1.31s/it]
#
#
# 1122it [24:53,  1.31s/it]
#
#
# 1123it [24:54,  1.28s/it]
#
#
# 1124it [24:56,  1.22s/it]
#
#
# 1125it [24:57,  1.24s/it]
#
#
# 1126it [24:58,  1.27s/it]
#
#
# 1127it [24:59,  1.24s/it]
#
#
# 1128it [25:01,  1.27s/it]
#
#
# 1129it [25:02,  1.23s/it]
#
#
# 1130it [25:03,  1.26s/it]
#
#
# 1131it [25:04,  1.25s/it]
#
#
# 1132it [25:06,  1.23s/it]
#
#
# 1133it [25:07,  1.21s/it]
#
#
# 1134it [25:08,  1.32s/it]
#
#
# 1135it [25:09,  1.25s/it]
#
#
# 1136it [25:11,  1.29s/it]
#
#
# 1137it [25:12,  1.27s/it]
#
#
# 1138it [25:13,  1.29s/it]
#
#
# 1139it [25:15,  1.26s/it]
#
#
# 1140it [25:16,  1.30s/it]
#
#
# 1141it [25:17,  1.29s/it]
#
#
# 1142it [25:18,  1.29s/it]
#
#
# 1143it [25:20,  1.29s/it]
#
#
# 1144it [25:21,  1.21s/it]
#
#
# 1145it [25:22,  1.23s/it]
#
#
# 1146it [25:23,  1.27s/it]
#
#
# 1147it [25:25,  1.28s/it]
#
#
# 1148it [25:26,  1.25s/it]
#
#
# 1149it [25:27,  1.30s/it]
#
#
# 1150it [25:28,  1.24s/it]
#
#
# 1151it [25:30,  1.20s/it]
#
#
# 1152it [25:31,  1.23s/it]
#
#
# 1153it [25:33,  1.44s/it]
#
#
# 1154it [25:34,  1.42s/it]
#
#
# 1155it [25:36,  1.66s/it]
#
#
# 1156it [25:38,  1.56s/it]
#
#
# 1157it [25:39,  1.45s/it]
#
#
# 1158it [25:40,  1.41s/it]
#
#
# 1159it [25:41,  1.33s/it]
#
#
# 1160it [25:42,  1.25s/it]
#
#
# 1161it [25:44,  1.22s/it]
#
#
# 1162it [25:45,  1.22s/it]
#
#
# 1163it [25:46,  1.19s/it]
#
#
# 1164it [25:47,  1.20s/it]
#
#
# 1165it [25:48,  1.22s/it]
#
#
# 1166it [25:50,  1.37s/it]
#
#
# 1167it [25:51,  1.36s/it]
#
#
# 1168it [25:53,  1.29s/it]
#
#
# 1169it [25:54,  1.25s/it]
#
#
# 1170it [25:55,  1.23s/it]
#
#
# 1171it [25:56,  1.24s/it]
#
#
# 1172it [25:58,  1.52s/it]
#
#
# 1173it [26:01,  1.77s/it]
#
#
# 1174it [26:02,  1.62s/it]
#
#
# 1175it [26:03,  1.53s/it]
#
#
# 1176it [26:04,  1.42s/it]
#
#
# 1177it [26:06,  1.39s/it]
#
#
# 1178it [26:07,  1.37s/it]
#
#
# 1179it [26:08,  1.34s/it]
#
#
# 1180it [26:10,  1.28s/it]
#
#
# 1181it [26:11,  1.28s/it]
#
#
# 1182it [26:12,  1.27s/it]
#
#
# 1183it [26:13,  1.28s/it]
#
#
# 1184it [26:15,  1.28s/it]
#
#
# 1185it [26:16,  1.29s/it]
#
#
# 1186it [26:17,  1.23s/it]
#
#
# 1187it [26:18,  1.18s/it]
#
#
# 1188it [26:19,  1.16s/it]
#
#
# 1189it [26:20,  1.15s/it]
#
#
# 1190it [26:21,  1.12s/it]
#
#
# 1191it [26:23,  1.16s/it]
#
#
# 1192it [26:24,  1.16s/it]
#
#
# 1193it [26:25,  1.19s/it]
#
#
# 1194it [26:26,  1.18s/it]
#
#
# 1195it [26:27,  1.21s/it]
#
#
# 1196it [26:29,  1.25s/it]
#
#
# 1197it [26:30,  1.25s/it]
#
#
# 1198it [26:31,  1.25s/it]
#
#
# 1199it [26:33,  1.25s/it]
#
#
# 1200it [26:34,  1.33s/it]
#
#
# 1201it [26:35,  1.32s/it]
#
#
# 1202it [26:37,  1.32s/it]
#
#
# 1203it [26:38,  1.30s/it]
#
#
# 1204it [26:39,  1.30s/it]
#
#
# 1205it [26:41,  1.31s/it]
#
#
# 1206it [26:42,  1.25s/it]
#
#
# 1207it [26:43,  1.22s/it]
# 1208it [26:44,  1.23s/it]
#
#
# 1209it [26:45,  1.25s/it]
#
#
# 1210it [26:47,  1.22s/it]
#
#
# 1211it [26:49,  1.50s/it]
#
#
# 1212it [26:51,  1.73s/it]
#
#
# 1213it [26:52,  1.61s/it]
#
#
# 1214it [26:54,  1.73s/it]
#
#
# 1215it [26:56,  1.61s/it]
#
#
# 1216it [26:57,  1.54s/it]
#
#
# 1217it [26:58,  1.48s/it]
#
#
# 1218it [27:00,  1.43s/it]
#
#
# 1219it [27:02,  1.57s/it]
#
#
# 1220it [27:04,  1.75s/it]
#
#
# 1221it [27:05,  1.62s/it]
#
#
# 1222it [27:06,  1.53s/it]
#
#
# 1223it [27:08,  1.46s/it]
#
#
# 1224it [27:09,  1.39s/it]
#
#
# 1225it [27:10,  1.32s/it]
#
#
# 1226it [27:11,  1.25s/it]
#
#
# 1227it [27:12,  1.21s/it]
#
#
# 1228it [27:14,  1.23s/it]
#
#
# 1229it [27:15,  1.26s/it]
#
#
# 1230it [27:16,  1.34s/it]
#
#
# 1231it [27:17,  1.27s/it]
#
#
# 1232it [27:19,  1.27s/it]
#
#
# 1233it [27:20,  1.30s/it]
#
#
# 1234it [27:21,  1.25s/it]
#
#
# 1235it [27:22,  1.22s/it]
#
#
# 1236it [27:24,  1.21s/it]
#
#
# 1237it [27:25,  1.15s/it]
#
#
# 1238it [27:26,  1.15s/it]
#
#
# 1239it [27:27,  1.14s/it]
#
#
# 1240it [27:28,  1.22s/it]
#
#
# 1241it [27:30,  1.23s/it]
#
#
# 1242it [27:31,  1.21s/it]
#
#
# 1243it [27:32,  1.22s/it]
#
#
# 1244it [27:33,  1.23s/it]
#
#
# 1245it [27:34,  1.22s/it]
#
#
# 1246it [27:36,  1.19s/it]
#
#
# 1247it [27:37,  1.20s/it]
#
#
# 1248it [27:38,  1.23s/it]
#
#
# 1249it [27:39,  1.28s/it]
#
#
# 1250it [27:41,  1.24s/it]
#
#
# 1251it [27:42,  1.20s/it]
#
#
# 1252it [27:43,  1.24s/it]
#
#
# 1253it [27:44,  1.26s/it]
#
#
# 1254it [27:45,  1.20s/it]
#
#
# 1255it [27:47,  1.22s/it]
#
#
# 1256it [27:48,  1.20s/it]
#
#
# 1257it [27:49,  1.22s/it]
#
#
# 1258it [27:50,  1.21s/it]
#
#
# 1259it [27:51,  1.20s/it]
#
#
# 1260it [27:53,  1.21s/it]
#
#
# 1261it [27:54,  1.18s/it]
#
#
# 1262it [27:55,  1.17s/it]
#
#
# 1263it [27:56,  1.19s/it]
#
#
# 1264it [27:57,  1.18s/it]
#
#
# 1265it [27:59,  1.21s/it]
#
#
# 1266it [28:00,  1.15s/it]
#
#
# 1267it [28:01,  1.20s/it]
#
#
# 1268it [28:02,  1.19s/it]
#
#
# 1269it [28:03,  1.21s/it]
#
#
# 1270it [28:05,  1.22s/it]
#
#
# 1271it [28:06,  1.24s/it]
#
#
# 1272it [28:07,  1.25s/it]
#
#
# 1273it [28:08,  1.23s/it]
#
#
# 1274it [28:10,  1.27s/it]
#
#
# 1275it [28:11,  1.23s/it]
#
#
# 1276it [28:12,  1.20s/it]
#
#
# 1277it [28:13,  1.27s/it]
#
#
# 1278it [28:15,  1.28s/it]
#
#
# 1279it [28:16,  1.30s/it]
#
#
# 1280it [28:17,  1.27s/it]
#
#
# 1281it [28:19,  1.34s/it]
#
#
# 1282it [28:21,  1.62s/it]
#
#
# 1283it [28:22,  1.48s/it]
#
#
# 1284it [28:23,  1.42s/it]
#
#
# 1285it [28:25,  1.38s/it]
#
#
# 1286it [28:26,  1.31s/it]
#
#
# 1287it [28:27,  1.24s/it]
#
#
# 1288it [28:28,  1.21s/it]
#
#
# 1289it [28:29,  1.23s/it]
#
#
# 1290it [28:31,  1.27s/it]
#
#
# 1291it [28:32,  1.28s/it]
#
#
# 1292it [28:33,  1.28s/it]
#
#
# 1293it [28:35,  1.28s/it]
#
#
# 1294it [28:36,  1.30s/it]
#
#
# 1295it [28:37,  1.31s/it]
#
#
# 1296it [28:39,  1.32s/it]
#
#
# 1297it [28:40,  1.31s/it]
#
#
# 1298it [28:41,  1.32s/it]
#
#
# 1299it [28:43,  1.37s/it]
#
#
# 1300it [28:44,  1.35s/it]
#
#
# 1301it [28:45,  1.34s/it]
#
#
# 1302it [28:47,  1.52s/it]
#
#
# 1303it [28:49,  1.57s/it]
#
#
# 1304it [28:50,  1.46s/it]
#
#
# 1305it [28:52,  1.58s/it]
#
#
# 1306it [28:53,  1.46s/it]
#
#
# 1307it [28:55,  1.60s/it]
#
#
# 1308it [28:57,  1.52s/it]
#
#
# 1309it [28:58,  1.40s/it]
#
#
# 1310it [28:59,  1.37s/it]
#
#
# 1311it [29:00,  1.33s/it]
#
#
# 1312it [29:01,  1.24s/it]
#
#
# 1313it [29:02,  1.24s/it]
#
#
# 1314it [29:04,  1.19s/it]
#
#
# 1315it [29:05,  1.22s/it]
#
#
# 1316it [29:06,  1.23s/it]
#
#
# 1317it [29:07,  1.25s/it]
#
#
# 1318it [29:09,  1.26s/it]
#
#
# 1319it [29:10,  1.29s/it]
#
#
# 1320it [29:11,  1.26s/it]
#
#
# 1321it [29:12,  1.24s/it]
#
#
# 1322it [29:14,  1.29s/it]
#
#
# 1323it [29:15,  1.24s/it]
#
#
# 1324it [29:16,  1.27s/it]
#
#
# 1325it [29:18,  1.28s/it]
#
#
# 1326it [29:19,  1.29s/it]
#
#
# 1327it [29:20,  1.29s/it]
#
#
# 1328it [29:21,  1.24s/it]
#
#
# 1329it [29:22,  1.22s/it]
#
#
# 1330it [29:24,  1.29s/it]
#
#
# 1331it [29:25,  1.35s/it]
#
#
# 1332it [29:27,  1.34s/it]
#
#
# 1333it [29:28,  1.27s/it]
#
#
# 1334it [29:29,  1.20s/it]
#
#
# 1335it [29:30,  1.22s/it]
#
#
# 1336it [29:31,  1.23s/it]
#
#
# 1337it [29:33,  1.24s/it]
#
#
# 1338it [29:34,  1.23s/it]
#
#
# 1339it [29:35,  1.24s/it]
#
#
# 1340it [29:36,  1.25s/it]
#
#
# 1341it [29:38,  1.26s/it]
#
#
# 1342it [29:39,  1.27s/it]
#
#
# 1343it [29:40,  1.28s/it]
#
#
# 1344it [29:42,  1.29s/it]
#
#
# 1345it [29:43,  1.30s/it]
#
#
# 1346it [29:44,  1.30s/it]
#
#
# 1347it [29:45,  1.28s/it]
#
#
# 1348it [29:47,  1.28s/it]
#
#
# 1349it [29:48,  1.24s/it]
#
#
# 1350it [29:49,  1.21s/it]
#
#
# 1351it [29:50,  1.19s/it]
#
#
# 1352it [29:51,  1.17s/it]
#
#
# 1353it [29:53,  1.22s/it]
#
#
# 1354it [29:54,  1.20s/it]
#
#
# 1355it [29:55,  1.22s/it]
#
#
# 1356it [29:56,  1.18s/it]
#
#
# 1357it [29:57,  1.13s/it]
#
#
# 1358it [29:58,  1.16s/it]
#
#
# 1359it [30:00,  1.34s/it]
#
#
# 1360it [30:01,  1.27s/it]
#
#
# 1361it [30:02,  1.23s/it]
#
#
# 1362it [30:04,  1.38s/it]
#
#
# 1363it [30:05,  1.33s/it]
#
#
# 1364it [30:07,  1.36s/it]
#
#
# 1365it [30:08,  1.33s/it]
#
#
# 1366it [30:09,  1.32s/it]
#
#
# 1367it [30:11,  1.32s/it]
#
#
# 1368it [30:12,  1.28s/it]
#
#
# 1369it [30:13,  1.22s/it]
#
#
# 1370it [30:14,  1.18s/it]
#
#
# 1371it [30:15,  1.16s/it]
#
#
# 1372it [30:17,  1.26s/it]
#
#
# 1373it [30:18,  1.27s/it]
#
#
# 1374it [30:19,  1.27s/it]
#
#
# 1375it [30:21,  1.33s/it]
#
#
# 1376it [30:22,  1.28s/it]
#
#
# 1377it [30:23,  1.23s/it]
#
#
# 1378it [30:24,  1.19s/it]
#
#
# 1379it [30:25,  1.17s/it]
#
#
# 1380it [30:26,  1.19s/it]
#
#
# 1381it [30:28,  1.39s/it]
#
#
# 1382it [30:30,  1.57s/it]
#
#
# 1383it [30:31,  1.47s/it]
#
#
# 1384it [30:33,  1.65s/it]
#
#
# 1385it [30:35,  1.53s/it]
#
#
# 1386it [30:37,  1.65s/it]
#
#
# 1387it [30:38,  1.57s/it]
#
#
# 1388it [30:39,  1.51s/it]
#
#
# 1389it [30:41,  1.46s/it]
#
#
# 1390it [30:43,  1.65s/it]
#
#
# 1391it [30:45,  1.83s/it]
#
#
# 1392it [30:47,  1.90s/it]
#
#
# 1393it [30:49,  1.98s/it]
#
#
# 1394it [30:51,  1.78s/it]
#
#
# 1395it [30:52,  1.64s/it]
#
#
# 1396it [30:53,  1.55s/it]
#
#
# 1397it [30:55,  1.44s/it]
#
#
# 1398it [30:56,  1.41s/it]
#
#
# 1399it [30:57,  1.41s/it]
#
#
# 1400it [30:58,  1.33s/it]
#
#
# 1401it [31:00,  1.32s/it]
#
#
# 1402it [31:01,  1.30s/it]
#
#
# 1403it [31:02,  1.30s/it]
#
#
# 1404it [31:04,  1.48s/it]
#
#
# 1405it [31:05,  1.34s/it]
#
#
# 1406it [31:06,  1.29s/it]
#
#
# 1407it [31:07,  1.24s/it]
#
#
# 1408it [31:09,  1.26s/it]
#
#
# 1409it [31:10,  1.26s/it]
#
#
# 1410it [31:11,  1.28s/it]
#
#
# 1411it [31:13,  1.29s/it]
#
#
# 1412it [31:14,  1.23s/it]
#
#
# 1413it [31:15,  1.21s/it]
#
#
# 1414it [31:16,  1.20s/it]
#
#
# 1415it [31:17,  1.18s/it]
#
#
# 1416it [31:18,  1.19s/it]
#
#
# 1417it [31:20,  1.21s/it]
#
#
# 1418it [31:21,  1.23s/it]
#
#
# 1419it [31:22,  1.24s/it]
#
#
# 1420it [31:23,  1.22s/it]
#
#
# 1421it [31:25,  1.26s/it]
#
#
# 1422it [31:26,  1.23s/it]
#
#
# 1423it [31:27,  1.26s/it]
#
#
# 1424it [31:28,  1.21s/it]
#
#
# 1425it [31:29,  1.18s/it]
#
#
# 1426it [31:31,  1.28s/it]
#
#
# 1427it [31:32,  1.21s/it]
#
#
# 1428it [31:33,  1.18s/it]
#
#
# 1429it [31:34,  1.20s/it]
#
#
# 1430it [31:36,  1.24s/it]
#
#
# 1431it [31:37,  1.25s/it]
#
#
# 1432it [31:38,  1.23s/it]
#
#
# 1433it [31:40,  1.27s/it]
#
#
# 1434it [31:41,  1.29s/it]
#
#
# 1435it [31:42,  1.30s/it]
#
#
# 1436it [31:43,  1.27s/it]
#
#
# 1437it [31:45,  1.24s/it]
#
#
# 1438it [31:46,  1.43s/it]
#
#
# 1439it [31:48,  1.53s/it]
#
#
# 1440it [31:49,  1.43s/it]
#
#
# 1441it [31:51,  1.41s/it]
#
#
# 1442it [31:52,  1.32s/it]
#
#
# 1443it [31:53,  1.25s/it]
#
#
# 1444it [31:54,  1.21s/it]
#
#
# 1445it [31:55,  1.23s/it]
#
#
# 1446it [31:57,  1.24s/it]
#
#
# 1447it [31:58,  1.25s/it]
#
#
# 1448it [31:59,  1.20s/it]
#
#
# 1449it [32:00,  1.25s/it]
#
#
# 1450it [32:02,  1.24s/it]
#
#
# 1451it [32:03,  1.24s/it]
#
#
# 1452it [32:04,  1.23s/it]
#
#
# 1453it [32:05,  1.28s/it]
#
#
# 1454it [32:07,  1.26s/it]
#
#
# 1455it [32:08,  1.21s/it]
#
#
# 1456it [32:09,  1.21s/it]
#
#
# 1457it [32:10,  1.23s/it]
#
#
# 1458it [32:11,  1.21s/it]
#
#
# 1459it [32:13,  1.22s/it]
#
#
# 1460it [32:14,  1.24s/it]
#
#
# 1461it [32:15,  1.17s/it]
#
#
# 1462it [32:16,  1.15s/it]
#
#
# 1463it [32:17,  1.15s/it]
#
#
# 1464it [32:18,  1.13s/it]
#
#
# 1465it [32:20,  1.19s/it]
#
#
# 1466it [32:21,  1.21s/it]
#
#
# 1467it [32:23,  1.50s/it]
#
#
# 1468it [32:25,  1.66s/it]
#
#
# 1469it [32:27,  1.82s/it]
#
#
# 1470it [32:29,  1.76s/it]
#
#
# 1471it [32:31,  1.83s/it]
#
#
# 1472it [32:32,  1.64s/it]
#
#
# 1473it [32:33,  1.51s/it]
#
#
# 1474it [32:35,  1.44s/it]
#
#
# 1475it [32:36,  1.39s/it]
#
#
# 1476it [32:37,  1.39s/it]
#
#
# 1477it [32:39,  1.63s/it]
#
#
# 1478it [32:41,  1.77s/it]
#
#
# 1479it [32:44,  1.88s/it]
#
#
# 1480it [32:46,  1.94s/it]
#
#
# 1481it [32:47,  1.74s/it]
#
#
# 1482it [32:48,  1.62s/it]
#
#
# 1483it [32:50,  1.76s/it]
#
#
# 1484it [32:52,  1.61s/it]
#
#
# 1485it [32:54,  1.72s/it]
#
#
# 1486it [32:55,  1.60s/it]
#
#
# 1487it [32:56,  1.50s/it]
#
#
# 1488it [32:58,  1.45s/it]
#
#
# 1489it [32:59,  1.32s/it]
#
#
# 1490it [33:00,  1.26s/it]
#
#
# 1491it [33:01,  1.30s/it]
#
#
# 1492it [33:02,  1.25s/it]
#
#
# 1493it [33:03,  1.26s/it]
#
#
# 1494it [33:05,  1.26s/it]
#
#
# 1495it [33:06,  1.27s/it]
#
#
# 1496it [33:08,  1.33s/it]
#
#
# 1497it [33:09,  1.31s/it]
#
#
# 1498it [33:10,  1.26s/it]
#
#
# 1499it [33:11,  1.26s/it]
# 1500it [33:12,  1.27s/it]
#
#
# 1501it [33:14,  1.27s/it]
#
#
# 1502it [33:15,  1.28s/it]
#
#
# 1503it [33:16,  1.22s/it]
#
#
# 1504it [33:17,  1.19s/it]
#
#
# 1505it [33:19,  1.24s/it]
#
#
# 1506it [33:20,  1.24s/it]
#
#
# 1507it [33:21,  1.26s/it]
#
#
# 1508it [33:22,  1.26s/it]
#
#
# 1509it [33:24,  1.27s/it]
#
#
# 1510it [33:25,  1.24s/it]
#
#
# 1511it [33:26,  1.22s/it]
#
#
# 1512it [33:27,  1.24s/it]
#
#
# 1513it [33:28,  1.21s/it]
#
#
# 1514it [33:30,  1.23s/it]
#
#
# 1515it [33:31,  1.21s/it]
#
#
# 1516it [33:32,  1.19s/it]
#
#
# 1517it [33:33,  1.20s/it]
#
#
# 1518it [33:35,  1.48s/it]
#
#
# 1519it [33:37,  1.52s/it]
#
#
# 1520it [33:38,  1.45s/it]
#
#
# 1521it [33:40,  1.41s/it]
#
#
# 1522it [33:42,  1.59s/it]
#
#
# 1523it [33:43,  1.52s/it]
#
#
# 1524it [33:44,  1.46s/it]
#
#
# 1525it [33:46,  1.40s/it]
#
#
# 1526it [33:47,  1.39s/it]
#
#
# 1527it [33:49,  1.52s/it]
#
#
# 1528it [33:50,  1.59s/it]
#
#
# 1529it [33:52,  1.53s/it]
#
#
# 1530it [33:53,  1.50s/it]
#
#
# 1531it [33:54,  1.40s/it]
#
#
# 1532it [33:56,  1.52s/it]
#
#
# 1533it [33:58,  1.68s/it]
#
#
# 1534it [34:00,  1.57s/it]
#
#
# 1535it [34:01,  1.50s/it]
#
#
# 1536it [34:02,  1.45s/it]
#
#
# 1537it [34:04,  1.40s/it]
#
#
# 1538it [34:05,  1.32s/it]
#
#
# 1539it [34:06,  1.34s/it]
#
#
# 1540it [34:07,  1.33s/it]
#
#
# 1541it [34:09,  1.27s/it]
#
#
# 1542it [34:10,  1.26s/it]
#
#
# 1543it [34:11,  1.20s/it]
#
#
# 1544it [34:12,  1.22s/it]
#
#
# 1545it [34:14,  1.27s/it]
#
#
# 1546it [34:15,  1.25s/it]
#
#
# 1547it [34:16,  1.22s/it]
#
#
# 1548it [34:17,  1.22s/it]
#
#
# 1549it [34:18,  1.20s/it]
#
#
# 1550it [34:19,  1.18s/it]
#
#
# 1551it [34:21,  1.21s/it]
#
#
# 1552it [34:22,  1.18s/it]
#
#
# 1553it [34:23,  1.21s/it]
#
#
# 1554it [34:24,  1.23s/it]
#
#
# 1555it [34:25,  1.20s/it]
#
#
# 1556it [34:27,  1.21s/it]
#
#
# 1557it [34:28,  1.19s/it]
#
#
# 1558it [34:29,  1.17s/it]
#
#
# 1559it [34:30,  1.17s/it]
#
#
# 1560it [34:31,  1.16s/it]
#
#
# 1561it [34:32,  1.12s/it]
#
#
# 1562it [34:33,  1.12s/it]
#
#
# 1563it [34:35,  1.12s/it]
#
#
# 1564it [34:36,  1.15s/it]
#
#
# 1565it [34:37,  1.14s/it]
#
#
# 1566it [34:38,  1.13s/it]
#
#
# 1567it [34:39,  1.16s/it]
#
#
# 1568it [34:41,  1.22s/it]
#
#
# 1569it [34:42,  1.26s/it]
#
#
# 1570it [34:43,  1.30s/it]
#
#
# 1571it [34:45,  1.48s/it]
#
#
# 1572it [34:47,  1.45s/it]
#
#
# 1573it [34:48,  1.41s/it]
#
#
# 1574it [34:49,  1.37s/it]
#
#
# 1575it [34:50,  1.30s/it]
#
#
# 1576it [34:51,  1.25s/it]
#
#
# 1577it [34:53,  1.23s/it]
#
#
# 1578it [34:54,  1.39s/it]
#
#
# 1579it [34:56,  1.34s/it]
#
#
# 1580it [34:57,  1.27s/it]
#
#
# 1581it [34:58,  1.21s/it]
#
#
# 1582it [34:59,  1.18s/it]
#
#
# 1583it [35:00,  1.18s/it]
#
#
# 1584it [35:01,  1.14s/it]
#
#
# 1585it [35:02,  1.18s/it]
#
#
# 1586it [35:04,  1.16s/it]
#
#
# 1587it [35:05,  1.21s/it]
#
#
# 1588it [35:06,  1.20s/it]
#
#
# 1589it [35:07,  1.22s/it]
#
#
# 1590it [35:09,  1.23s/it]
#
#
# 1591it [35:10,  1.25s/it]
#
#
# 1592it [35:11,  1.18s/it]
#
#
# 1593it [35:12,  1.21s/it]
#
#
# 1594it [35:13,  1.19s/it]
#
#
# 1595it [35:15,  1.22s/it]
#
#
# 1596it [35:16,  1.25s/it]
#
#
# 1597it [35:17,  1.27s/it]
#
#
# 1598it [35:18,  1.28s/it]
#
#
# 1599it [35:20,  1.23s/it]
#
#
# 1600it [35:21,  1.20s/it]
#
#
# 1601it [35:22,  1.25s/it]
#
#
# 1602it [35:24,  1.41s/it]
#
#
# 1603it [35:25,  1.37s/it]
#
#
# 1604it [35:26,  1.30s/it]
#
#
# 1605it [35:28,  1.28s/it]
#
#
# 1606it [35:29,  1.31s/it]
#
#
# 1607it [35:30,  1.27s/it]
#
#
# 1608it [35:31,  1.24s/it]
#
#
# 1609it [35:32,  1.18s/it]
#
#
# 1610it [35:34,  1.20s/it]
#
#
# 1611it [35:35,  1.18s/it]
#
#
# 1612it [35:36,  1.17s/it]
#
#
# 1613it [35:37,  1.17s/it]
#
#
# 1614it [35:38,  1.20s/it]
#
#
# 1615it [35:40,  1.23s/it]
#
#
# 1616it [35:41,  1.26s/it]
#
#
# 1617it [35:42,  1.27s/it]
#
#
# 1618it [35:43,  1.27s/it]
#
#
# 1619it [35:45,  1.28s/it]
#
#
# 1620it [35:46,  1.25s/it]
#
#
# 1621it [35:47,  1.25s/it]
#
#
# 1622it [35:48,  1.18s/it]
#
#
# 1623it [35:49,  1.21s/it]
#
#
# 1624it [35:51,  1.19s/it]
#
#
# 1625it [35:52,  1.18s/it]
#
#
# 1626it [35:53,  1.18s/it]
#
#
# 1627it [35:54,  1.14s/it]
#
#
# 1628it [35:55,  1.15s/it]
#
#
# 1629it [35:56,  1.14s/it]
#
#
# 1630it [35:57,  1.11s/it]
#
#
# 1631it [35:58,  1.09s/it]
#
#
# 1632it [35:59,  1.10s/it]
#
#
# 1633it [36:01,  1.10s/it]
#
#
# 1634it [36:03,  1.41s/it]
#
#
# 1635it [36:04,  1.35s/it]
#
#
# 1636it [36:05,  1.35s/it]
#
#
# 1637it [36:07,  1.40s/it]
#
#
# 1638it [36:08,  1.38s/it]
#
#
# 1639it [36:09,  1.35s/it]
#
#
# 1640it [36:11,  1.31s/it]
#
#
# 1641it [36:12,  1.29s/it]
#
#
# 1642it [36:16,  2.19s/it]
#
#
# 1643it [36:17,  1.93s/it]
#
#
# 1644it [36:19,  1.73s/it]
#
#
# 1645it [36:20,  1.56s/it]
#
#
# 1646it [36:21,  1.44s/it]
#
#
# 1647it [36:22,  1.40s/it]
#
#
# 1648it [36:24,  1.37s/it]
#
#
# 1649it [36:25,  1.32s/it]
#
#
# 1650it [36:26,  1.36s/it]
#
#
# 1651it [36:27,  1.28s/it]
#
#
# 1652it [36:29,  1.27s/it]
#
#
# 1653it [36:30,  1.23s/it]
#
#
# 1654it [36:31,  1.19s/it]
#
#
# 1655it [36:32,  1.19s/it]
#
#
# 1656it [36:33,  1.25s/it]
#
#
# 1657it [36:35,  1.27s/it]
#
#
# 1658it [36:36,  1.25s/it]
#
#
# 1659it [36:37,  1.24s/it]
#
#
# 1660it [36:38,  1.24s/it]
#
#
# 1661it [36:40,  1.23s/it]
#
#
# 1662it [36:41,  1.26s/it]
#
#
# 1663it [36:42,  1.26s/it]
#
#
# 1664it [36:44,  1.27s/it]
#
#
# 1665it [36:45,  1.27s/it]
#
#
# 1666it [36:46,  1.27s/it]
#
#
# 1667it [36:47,  1.27s/it]
#
#
# 1668it [36:49,  1.28s/it]
#
#
# 1669it [36:50,  1.23s/it]
#
#
# 1670it [36:51,  1.25s/it]
#
#
# 1671it [36:52,  1.22s/it]
#
#
# 1672it [36:53,  1.19s/it]
#
#
# 1673it [36:54,  1.17s/it]
#
#
# 1674it [36:56,  1.18s/it]
#
#
# 1675it [36:57,  1.22s/it]
#
#
# 1676it [36:58,  1.16s/it]
#
#
# 1677it [36:59,  1.14s/it]
#
#
# 1678it [37:00,  1.14s/it]
#
#
# 1679it [37:01,  1.14s/it]
#
#
# 1680it [37:02,  1.13s/it]
#
#
# 1681it [37:04,  1.12s/it]
#
#
# 1682it [37:05,  1.14s/it]
#
#
# 1683it [37:06,  1.16s/it]
#
#
# 1684it [37:07,  1.18s/it]
#
#
# 1685it [37:08,  1.21s/it]
#
#
# 1686it [37:10,  1.30s/it]
#
#
# 1687it [37:11,  1.30s/it]
#
#
# 1688it [37:13,  1.35s/it]
#
#
# 1689it [37:14,  1.33s/it]
#
#
# 1690it [37:15,  1.27s/it]
#
#
# 1691it [37:16,  1.27s/it]
#
#
# 1692it [37:18,  1.27s/it]
#
#
# 1693it [37:19,  1.23s/it]
#
#
# 1694it [37:20,  1.25s/it]
#
#
# 1695it [37:22,  1.30s/it]
#
#
# 1696it [37:24,  1.51s/it]
#
#
# 1697it [37:25,  1.44s/it]
#
#
# 1698it [37:26,  1.42s/it]
#
#
# 1699it [37:27,  1.38s/it]
#
#
# 1700it [37:29,  1.30s/it]
#
#
# 1701it [37:30,  1.29s/it]
#
#
# 1702it [37:31,  1.26s/it]
#
#
# 1703it [37:32,  1.24s/it]
#
#
# 1704it [37:33,  1.24s/it]
#
#
# 1705it [37:35,  1.28s/it]
#
#
# 1706it [37:36,  1.27s/it]
#
#
# 1707it [37:37,  1.22s/it]
#
#
# 1708it [37:38,  1.24s/it]
#
#
# 1709it [37:40,  1.26s/it]
#
#
# 1710it [37:41,  1.28s/it]
#
#
# 1711it [37:43,  1.49s/it]
#
#
# 1712it [37:44,  1.45s/it]
#
#
# 1713it [37:46,  1.39s/it]
#
#
# 1714it [37:47,  1.37s/it]
#
#
# 1715it [37:48,  1.34s/it]
#
#
# 1716it [37:49,  1.28s/it]
#
#
# 1717it [37:51,  1.28s/it]
#
#
# 1718it [37:52,  1.24s/it]
#
#
# 1719it [37:53,  1.28s/it]
#
#
# 1720it [37:54,  1.22s/it]
#
#
# 1721it [37:56,  1.20s/it]
#
#
# 1722it [37:57,  1.23s/it]
#
#
# 1723it [37:58,  1.25s/it]
#
#
# 1724it [37:59,  1.23s/it]
#
#
# 1725it [38:01,  1.25s/it]
#
#
# 1726it [38:02,  1.22s/it]
#
#
# 1727it [38:03,  1.20s/it]
#
#
# 1728it [38:04,  1.18s/it]
#
#
# 1729it [38:05,  1.13s/it]
#
#
# 1730it [38:06,  1.13s/it]
#
#
# 1731it [38:07,  1.14s/it]
#
#
# 1732it [38:09,  1.17s/it]
#
#
# 1733it [38:10,  1.20s/it]
#
#
# 1734it [38:11,  1.22s/it]
#
#
# 1735it [38:12,  1.26s/it]
#
#
# 1736it [38:14,  1.33s/it]
#
#
# 1737it [38:15,  1.27s/it]
#
#
# 1738it [38:16,  1.28s/it]
#
#
# 1739it [38:18,  1.24s/it]
#
#
# 1740it [38:19,  1.19s/it]
#
#
# 1741it [38:20,  1.21s/it]
#
#
# 1742it [38:21,  1.25s/it]
#
#
# 1743it [38:23,  1.29s/it]
#
#
# 1744it [38:24,  1.24s/it]
#
#
# 1745it [38:25,  1.21s/it]
#
#
# 1746it [38:26,  1.23s/it]
#
#
# 1747it [38:28,  1.29s/it]
#
#
# 1748it [38:29,  1.29s/it]
#
#
# 1749it [38:30,  1.24s/it]
#
#
# 1750it [38:31,  1.30s/it]
#
#
# 1751it [38:33,  1.27s/it]
#
#
# 1752it [38:34,  1.25s/it]
#
#
# 1753it [38:35,  1.21s/it]
#
#
# ...
#
#
# 5744it [2:05:12,  1.32s/it]
#
#
# 5745it [2:05:14,  1.34s/it]
#
#
# 5746it [2:05:15,  1.24s/it]
#
#
# 5747it [2:05:16,  1.26s/it]
#
#
# 5748it [2:05:17,  1.27s/it]
#
#
# 5749it [2:05:19,  1.35s/it]
#
#
# 5750it [2:05:20,  1.34s/it]
#
#
# 5751it [2:05:21,  1.28s/it]
#
#
# 5752it [2:05:22,  1.25s/it]
#
#
# 5753it [2:05:24,  1.26s/it]
#
#
# 5754it [2:05:25,  1.24s/it]
#
#
# 5755it [2:05:26,  1.25s/it]
#
#
# 5756it [2:05:27,  1.25s/it]
#
#
# 5757it [2:05:29,  1.22s/it]
#
#
# 5758it [2:05:30,  1.19s/it]
#
#
# 5759it [2:05:31,  1.15s/it]
#
#
# 5760it [2:05:32,  1.14s/it]
#
#
# 5761it [2:05:33,  1.20s/it]
#
#
# 5762it [2:05:35,  1.24s/it]
#
#
# 5763it [2:05:36,  1.21s/it]
#
#
# 5764it [2:05:37,  1.19s/it]
#
#
# 5765it [2:05:38,  1.23s/it]
#
#
# 5766it [2:05:39,  1.17s/it]
#
#
# 5767it [2:05:40,  1.16s/it]
#
#
# 5768it [2:05:41,  1.13s/it]
#
#
# 5769it [2:05:43,  1.13s/it]
#
#
# 5770it [2:05:44,  1.14s/it]
#
#
# 5771it [2:05:45,  1.16s/it]
#
#
# 5772it [2:05:46,  1.19s/it]
#
#
# 5773it [2:05:47,  1.17s/it]
#
#
# 5774it [2:05:49,  1.22s/it]
#
#
# 5775it [2:05:50,  1.21s/it]
#
#
# 5776it [2:05:51,  1.20s/it]
#
#
# 5777it [2:05:52,  1.19s/it]
#
#
# 5778it [2:05:53,  1.17s/it]
#
#
# 5779it [2:05:55,  1.20s/it]
#
#
# 5780it [2:05:56,  1.16s/it]
#
#
# 5781it [2:05:57,  1.16s/it]
#
#
# 5782it [2:05:58,  1.20s/it]
#
#
# 5783it [2:05:59,  1.20s/it]
#
#
# 5784it [2:06:01,  1.24s/it]
#
#
# 5785it [2:06:02,  1.22s/it]
#
#
# 5786it [2:06:03,  1.19s/it]
#
#
# 5787it [2:06:04,  1.21s/it]
#
#
# 5788it [2:06:05,  1.22s/it]
#
#
# 5789it [2:06:07,  1.24s/it]
#
#
# 5790it [2:06:08,  1.25s/it]
#
#
# 5791it [2:06:09,  1.21s/it]
#
#
# 5792it [2:06:10,  1.19s/it]
#
#
# 5793it [2:06:11,  1.17s/it]
#
#
# 5794it [2:06:13,  1.20s/it]
#
#
# 5795it [2:06:14,  1.21s/it]
#
#
# 5796it [2:06:15,  1.20s/it]
#
#
# 5797it [2:06:16,  1.22s/it]
#
#
# 5798it [2:06:17,  1.20s/it]
#
#
# 5799it [2:06:19,  1.23s/it]
#
#
# 5800it [2:06:20,  1.27s/it]
#
#
# 5801it [2:06:21,  1.28s/it]
#
#
# 5802it [2:06:23,  1.27s/it]
#
#
# 5803it [2:06:24,  1.33s/it]
#
#
# 5804it [2:06:25,  1.25s/it]
#
#
# 5805it [2:06:27,  1.27s/it]
#
#
# 5806it [2:06:28,  1.28s/it]
#
#
# 5807it [2:06:29,  1.30s/it]
#
#
# 5808it [2:06:30,  1.28s/it]
#
#
# 5809it [2:06:32,  1.27s/it]
#
#
# 5810it [2:06:33,  1.20s/it]
#
#
# 5811it [2:06:34,  1.23s/it]
#
#
# 5812it [2:06:35,  1.28s/it]
#
#
# 5813it [2:06:37,  1.26s/it]
#
#
# 5814it [2:06:38,  1.23s/it]
#
#
# 5815it [2:06:39,  1.26s/it]
#
#
# 5816it [2:06:40,  1.23s/it]
#
#
# 5817it [2:06:41,  1.22s/it]
#
#
# 5818it [2:06:43,  1.19s/it]
#
#
# 5819it [2:06:44,  1.17s/it]
#
#
# 5820it [2:06:45,  1.19s/it]
#
#
# 5821it [2:06:47,  1.45s/it]
#
#
# 5822it [2:06:49,  1.54s/it]
#
#
# 5823it [2:06:50,  1.46s/it]
#
#
# 5824it [2:06:51,  1.41s/it]
#
#
# 5825it [2:06:52,  1.33s/it]
#
#
# 5826it [2:06:54,  1.26s/it]
#
#
# 5827it [2:06:55,  1.26s/it]
#
#
# 5828it [2:06:56,  1.24s/it]
#
#
# 5829it [2:06:57,  1.22s/it]
#
#
# 5830it [2:06:58,  1.25s/it]
#
#
# 5831it [2:07:00,  1.34s/it]
#
#
# 5832it [2:07:02,  1.38s/it]
#
#
# 5833it [2:07:03,  1.37s/it]
#
#
# 5834it [2:07:04,  1.32s/it]
#
#
# 5835it [2:07:05,  1.32s/it]
#
#
# 5836it [2:07:07,  1.32s/it]
#
#
# 5837it [2:07:08,  1.31s/it]
#
#
# 5838it [2:07:09,  1.33s/it]
#
#
# 5839it [2:07:11,  1.28s/it]
#
#
# 5840it [2:07:12,  1.25s/it]
#
#
# 5841it [2:07:13,  1.19s/it]
#
#
# 5842it [2:07:15,  1.43s/it]
#
#
# 5843it [2:07:16,  1.40s/it]
#
#
# 5844it [2:07:17,  1.39s/it]
#
#
# 5845it [2:07:19,  1.36s/it]
#
#
# 5846it [2:07:21,  1.52s/it]
#
#
# 5847it [2:07:23,  1.73s/it]
#
#
# 5848it [2:07:24,  1.63s/it]
#
#
# 5849it [2:07:26,  1.53s/it]
#
#
# 5850it [2:07:27,  1.46s/it]
#
#
# 5851it [2:07:28,  1.40s/it]
#
#
# 5852it [2:07:29,  1.33s/it]
#
#
# 5853it [2:07:31,  1.31s/it]
#
#
# 5854it [2:07:32,  1.31s/it]
#
#
# 5855it [2:07:33,  1.26s/it]
#
#
# 5856it [2:07:34,  1.26s/it]
#
#
# 5857it [2:07:35,  1.23s/it]
#
#
# 5858it [2:07:37,  1.28s/it]
#
#
# 5859it [2:07:38,  1.23s/it]
#
#
# 5860it [2:07:39,  1.20s/it]
#
#
# 5861it [2:07:40,  1.16s/it]
#
#
# 5862it [2:07:41,  1.19s/it]
#
#
# 5863it [2:07:43,  1.22s/it]
#
#
# 5864it [2:07:44,  1.20s/it]
#
#
# 5865it [2:07:45,  1.17s/it]
#
#
# 5866it [2:07:46,  1.18s/it]
#
#
# 5867it [2:07:47,  1.19s/it]
#
#
# 5868it [2:07:48,  1.16s/it]
#
#
# 5869it [2:07:50,  1.16s/it]
#
#
# 5870it [2:07:51,  1.13s/it]
#
#
# 5871it [2:07:52,  1.18s/it]
#
#
# 5872it [2:07:53,  1.22s/it]
#
#
# 5873it [2:07:54,  1.20s/it]
#
#
# 5874it [2:07:55,  1.17s/it]
#
#
# 5875it [2:07:57,  1.21s/it]
#
#
# 5876it [2:07:58,  1.20s/it]
#
#
# 5877it [2:08:00,  1.43s/it]
#
#
# 5878it [2:08:01,  1.38s/it]
#
#
# 5879it [2:08:02,  1.33s/it]
#
#
# 5880it [2:08:04,  1.32s/it]
#
#
# 5881it [2:08:05,  1.26s/it]
#
#
# 5882it [2:08:06,  1.26s/it]
#
#
# 5883it [2:08:07,  1.26s/it]
#
#
# 5884it [2:08:09,  1.24s/it]
#
#
# 5885it [2:08:10,  1.24s/it]
#
#
# 5886it [2:08:11,  1.18s/it]
#
#
# 5887it [2:08:12,  1.13s/it]
#
#
# 5888it [2:08:13,  1.10s/it]
#
#
# 5889it [2:08:14,  1.11s/it]
#
#
# 5890it [2:08:15,  1.15s/it]
#
#
# 5891it [2:08:16,  1.17s/it]
#
#
# 5892it [2:08:18,  1.16s/it]
#
#
# 5893it [2:08:19,  1.17s/it]
#
#
# 5894it [2:08:20,  1.15s/it]
#
#
# 5895it [2:08:21,  1.14s/it]
#
#
# 5896it [2:08:22,  1.18s/it]
#
#
# 5897it [2:08:23,  1.18s/it]
#
#
# 5898it [2:08:25,  1.17s/it]
#
#
# 5899it [2:08:26,  1.21s/it]
#
#
# 5900it [2:08:27,  1.19s/it]
#
#
# 5901it [2:08:28,  1.18s/it]
#
#
# 5902it [2:08:29,  1.19s/it]
#
#
# 5903it [2:08:31,  1.22s/it]
#
#
# 5904it [2:08:32,  1.21s/it]
#
#
# 5905it [2:08:33,  1.23s/it]
#
#
# 5906it [2:08:34,  1.23s/it]
#
#
# 5907it [2:08:36,  1.22s/it]
#
#
# 5908it [2:08:37,  1.28s/it]
#
#
# 5909it [2:08:38,  1.24s/it]
#
#
# 5910it [2:08:39,  1.21s/it]
#
#
# 5911it [2:08:40,  1.19s/it]
#
#
# 5912it [2:08:46,  2.52s/it]
#
#
# 5913it [2:08:47,  2.15s/it]
#
#
# 5914it [2:08:49,  1.88s/it]
#
#
# 5915it [2:08:50,  1.68s/it]
#
#
# 5916it [2:08:51,  1.56s/it]
#
#
# 5917it [2:08:52,  1.44s/it]
#
#
# 5918it [2:08:53,  1.34s/it]
#
#
# 5919it [2:08:55,  1.32s/it]
#
#
# 5920it [2:08:56,  1.27s/it]
#
#
# 5921it [2:08:57,  1.21s/it]
#
#
# 5922it [2:08:58,  1.20s/it]
#
#
# 5923it [2:08:59,  1.16s/it]
#
#
# 5924it [2:09:00,  1.19s/it]
#
#
# 5925it [2:09:02,  1.19s/it]
#
#
# 5926it [2:09:03,  1.18s/it]
#
#
# 5927it [2:09:04,  1.21s/it]
#
#
# 5928it [2:09:05,  1.18s/it]
#
#
# 5929it [2:09:06,  1.22s/it]
#
#
# 5930it [2:09:08,  1.20s/it]
#
#
# 5931it [2:09:09,  1.21s/it]
#
#
# 5932it [2:09:10,  1.33s/it]
#
#
# 5933it [2:09:12,  1.27s/it]
#
#
# 5934it [2:09:13,  1.19s/it]
#
#
# 5935it [2:09:14,  1.17s/it]
#
#
# 5936it [2:09:15,  1.20s/it]
#
#
# 5937it [2:09:16,  1.21s/it]
#
#
# 5938it [2:09:17,  1.25s/it]
#
#
# 5939it [2:09:19,  1.26s/it]
#
#
# 5940it [2:09:20,  1.27s/it]
#
#
# 5941it [2:09:21,  1.26s/it]
#
#
# 5942it [2:09:23,  1.49s/it]
#
#
# 5943it [2:09:25,  1.67s/it]
#
#
# 5944it [2:09:27,  1.74s/it]
#
#
# 5945it [2:09:29,  1.70s/it]
#
#
# 5946it [2:09:31,  1.85s/it]
#
#
# 5947it [2:09:32,  1.64s/it]
# 5948it [2:09:34,  1.55s/it]
#
#
# 5949it [2:09:35,  1.50s/it]
#
#
# 5950it [2:09:36,  1.41s/it]
#
#
# 5951it [2:09:37,  1.36s/it]
#
#
# 5952it [2:09:39,  1.55s/it]
#
#
# 5953it [2:09:42,  1.75s/it]
#
#
# 5954it [2:09:44,  1.88s/it]
#
#
# 5955it [2:09:46,  1.96s/it]
#
#
# 5956it [2:09:47,  1.79s/it]
#
#
# 5957it [2:09:49,  1.63s/it]
#
#
# 5958it [2:09:51,  1.74s/it]
#
#
# 5959it [2:09:52,  1.59s/it]
#
#
# 5960it [2:09:53,  1.54s/it]
#
#
# 5961it [2:09:55,  1.47s/it]
#
#
# 5962it [2:09:56,  1.32s/it]
#
#
# 5963it [2:09:57,  1.29s/it]
#
#
# 5964it [2:09:58,  1.28s/it]
#
#
# 5965it [2:09:59,  1.22s/it]
#
#
# 5966it [2:10:00,  1.24s/it]
#
#
# 5967it [2:10:01,  1.18s/it]
#
#
# 5968it [2:10:03,  1.19s/it]
#
#
# 5969it [2:10:04,  1.22s/it]
#
#
# 5970it [2:10:05,  1.20s/it]
#
#
# 5971it [2:10:06,  1.18s/it]
#
#
# 5972it [2:10:07,  1.16s/it]
#
#
# 5973it [2:10:09,  1.18s/it]
#
#
# 5974it [2:10:10,  1.20s/it]
#
#
# 5975it [2:10:11,  1.24s/it]
#
#
# 5976it [2:10:12,  1.21s/it]
#
#
# 5977it [2:10:13,  1.19s/it]
#
#
# 5978it [2:10:15,  1.16s/it]
#
#
# 5979it [2:10:16,  1.15s/it]
#
#
# 5980it [2:10:17,  1.19s/it]
#
#
# 5981it [2:10:18,  1.21s/it]
#
#
# 5982it [2:10:19,  1.20s/it]
#
#
# 5983it [2:10:21,  1.20s/it]
#
#
# 5984it [2:10:23,  1.45s/it]
#
#
# 5985it [2:10:25,  1.63s/it]
#
#
# 5986it [2:10:27,  1.79s/it]
#
#
# 5987it [2:10:28,  1.71s/it]
#
#
# 5988it [2:10:30,  1.81s/it]
#
#
# 5989it [2:10:32,  1.67s/it]
#
#
# 5990it [2:10:33,  1.57s/it]
#
#
# 5991it [2:10:34,  1.47s/it]
#
#
# 5992it [2:10:36,  1.39s/it]
#
#
# 5993it [2:10:37,  1.35s/it]
#
#
# 5994it [2:10:38,  1.35s/it]
#
#
# 5995it [2:10:39,  1.33s/it]
#
#
# 5996it [2:10:40,  1.26s/it]
#
#
# 5997it [2:10:42,  1.22s/it]
#
#
# 5998it [2:10:43,  1.19s/it]
#
#
# 5999it [2:10:44,  1.18s/it]
#
#
# 6000it [2:10:45,  1.18s/it]
#
#
# 6001it [2:10:46,  1.21s/it]
#
#
# 6002it [2:10:47,  1.18s/it]
#
#
# 6003it [2:10:49,  1.17s/it]
#
#
# 6004it [2:10:50,  1.16s/it]
#
#
# 6005it [2:10:51,  1.12s/it]
#
#
# 6006it [2:10:52,  1.13s/it]
#
#
# 6007it [2:10:53,  1.17s/it]
#
#
# 6008it [2:10:54,  1.17s/it]
#
#
# 6009it [2:10:55,  1.15s/it]
#
#
# 6010it [2:10:57,  1.16s/it]
#
#
# 6011it [2:10:58,  1.12s/it]
#
#
# 6012it [2:10:59,  1.16s/it]
#
#
# 6013it [2:11:00,  1.18s/it]
#
#
# 6014it [2:11:01,  1.16s/it]
#
#
# 6015it [2:11:03,  1.21s/it]
#
#
# 6016it [2:11:04,  1.18s/it]
#
#
# 6017it [2:11:05,  1.22s/it]
#
#
# 6018it [2:11:06,  1.25s/it]
#
#
# 6019it [2:11:08,  1.25s/it]
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# c:\users\waii\appdata\local\programs\python\python36\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# c:\users\waii\appdata\local\programs\python\python36\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      82     if err is not None:
# ---> 83         raise err
#      84
#
# c:\users\waii\appdata\local\programs\python\python36\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# c:\users\waii\appdata\local\programs\python\python36\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# c:\users\waii\appdata\local\programs\python\python36\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     344         try:
# --> 345             self._validate_conn(conn)
#     346         except (SocketTimeout, BaseSSLError) as e:
#
# c:\users\waii\appdata\local\programs\python\python36\lib\site-packages\requests\packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     843         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 844             conn.connect()
#     845
#
# c:\users\waii\appdata\local\programs\python\python36\lib\site-packages\requests\packages\urllib3\connection.py in connect(self)
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#
# c:\users\waii\appdata\local\programs\python\python36\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     149             raise NewConnectionError(
# --> 150                 self, "Failed to establish a new connection: %s" % e)
#     151
#
# NewConnectionError: <requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x000001CFCF4FB240>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# c:\users\waii\appdata\local\programs\python\python36\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#
# c:\users\waii\appdata\local\programs\python\python36\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     648             retries = retries.increment(method, url, error=e, _pool=self,
# --> 649                                         _stacktrace=sys.exc_info()[2])
#     650             retries.sleep()
#
# c:\users\waii\appdata\local\programs\python\python36\lib\site-packages\requests\packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     375         if new_retry.is_exhausted():
# --> 376             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     377
#
# MaxRetryError: HTTPSConnectionPool(host='omictools.com', port=443): Max retries exceeded with url: /clover-tool (Caused by NewConnectionError('<requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x000001CFCF4FB240>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-118-96f467cf3a8d> in <module>()
# ----> 1 tool_dict = generate_tool_dict(category_lookup,interested_category)
#
# <ipython-input-111-40374c2ceed7> in generate_tool_dict(category_lookup, interested_category)
#       8                         state = tool
#       9                         omictool = "https://omictools.com"+tool
# ---> 10                         response = requests.get(omictool)
#      11                         html = BeautifulSoup(response.text,"html5lib")
#      12                         a_list = html.find_all('a')
#
# c:\users\waii\appdata\local\programs\python\python36\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# c:\users\waii\appdata\local\programs\python\python36\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# c:\users\waii\appdata\local\programs\python\python36\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# c:\users\waii\appdata\local\programs\python\python36\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# c:\users\waii\appdata\local\programs\python\python36\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     485                 raise ProxyError(e, request=request)
#     486
# --> 487             raise ConnectionError(e, request=request)
#     488
#     489         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='omictools.com', port=443): Max retries exceeded with url: /clover-tool (Caused by NewConnectionError('<requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x000001CFCF4FB240>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))

# %%
with open('tool_dict.pickle', 'wb') as f:
    pickle.dump(tool_dict, f)

# %%
tool_dict
# Out:
# {'/beast-tool': set(),
#  '/paml-tool': set(),
#  '/dambe-tool': set(),
#  '/tipdate-tool': set(),
#  '/physher-tool': set(),
#  '/tempest-tool': set(),
#  '/r8s-tool': set(),
#  '/newbler-tool': set(),
#  '/emboss-tool': set(),
#  '/trimmomatic-tool': set(),
#  '/trim-galore-tool': set(),
#  '/alientrimmer-tool': set(),
#  '/skewer-tool': set(),
#  '/peat-tool': set(),
#  '/seqpurge-tool': set(),
#  '/ddocent-tool': set(),
#  '/cutadapt-tool': set(),
#  '/jassa-tool': set(),
#  '/gps-sumo-tool': set(),
#  '/psumo-cd-tool': set(),
#  '/sumogo-tool': set(),
#  '/sumoplot-tool': set(),
#  '/sumoamvr-tool': set(),
#  '/ptmprober-tool': set(),
#  '/seesumo-tool': set(),
#  '/sumohydro-tool': set(),
#  '/gat-tool': set(),
#  '/regioner-tool': set(),
#  '/stereogene-tool': set(),
#  '/cruzdb-tool': set(),
#  '/intersect-tool': set(),
#  '/sequila-tool': set(),
#  '/genometricorr-tool': set(),
#  '/ginom-tool': set(),
#  '/kltepigenome-tool': set(),
#  '/valr-tool': set(),
#  '/ncidp-tool': set(),
#  '/cheshift-tool': set(),
#  '/shiftx-tool': set(),
#  '/vasco-tool': set(),
#  '/sparta-tool': set(),
#  '/sparta-3-tool': set(),
#  '/proshift-tool': set(),
#  '/lacs-tool': set(),
#  '/nightshift-tool': set(),
#  '/checkshift-tool': set(),
#  '/rescue-ese-tool': set(),
#  '/cryp-skip-tool': set(),
#  '/spliceman-tool': set(),
#  '/sfmap-tool': set(),
#  '/esefinder-tool': set(),
#  '/splicepredictor-tool': set(),
#  '/netgene2-tool': set(),
#  '/skippy-tool': set(),
#  '/mutpred-splice-tool': set(),
#  '/hsf-tool': set(),
#  '/grinder-tool': set(),
#  '/metasmc-tool': set(),
#  '/gemsim-tool': set(),
#  '/metasim-tool': set(),
#  '/nessm-tool': set(),
#  '/bear-tool': set(),
#  '/lrsim-tool': set(),
#  '/camisim-tool': set(),
#  '/functionsim-tool': set(),
#  '/riboswitch-scanner-tool': set(),
#  '/ribex-tool': set(),
#  '/riboswitch-finder-tool': set(),
#  '/pasific-tool': set(),
#  '/rnabor-tool': set(),
#  '/drd-tool': set(),
#  '/ribosw-tool': set(),
#  '/rnabormea-tool': set(),
#  '/edger-tool': set(),
#  '/limma-tool': set(),
#  '/sva-2-tool': set(),
#  '/altanalyze-tool': set(),
#  '/svaseq-tool': set(),
#  '/noiseq-tool': set(),
#  '/impulsede2-tool': set(),
#  '/gpca-tool': set(),
#  '/quantnorm-tool': set(),
#  '/dasc-tool': set(),
#  '/rosetta-software-suite-tool': set(),
#  '/tide-2-tool': set(),
#  '/vapper-tool': set(),
#  '/airlab-tool': set(),
#  '/tcrmodel-tool': set(),
#  '/brepertoire-tool': set(),
#  '/mebt-tool': set(),
#  '/immunomebrowser-tool': set(),
#  '/gg-mtsl-tool': set(),
#  '/mad-hype-tool': set(),
#  '/mitotip-tool': set(),
#  '/g-mmpbsa-tool': set(),
#  '/mcsm-tool': set(),
#  '/elaspic-tool': set(),
#  '/csm-lig-tool': set(),
#  '/beatmusic-tool': set(),
#  '/acfis-tool': set(),
#  '/manoraa-tool': set(),
#  '/cafe-3-tool': set(),
#  '/prodigy-lig-tool': set(),
#  '/icfn-tool': set(),
#  '/targetscan-tool': set(),
#  '/targetscans-tool': set(),
#  '/pictar-tool': set(),
#  '/genmir-tool': set(),
#  '/sylamer-tool': set(),
#  '/intarna-tool': set(),
#  '/diana-mirpath-tool': set(),
#  '/microon-tool': set(),
#  '/psrnatarget-tool': set(),
#  '/mircheck-tool': set(),
#  '/rnbeads-tool': set(),
#  '/minfi-tool': set(),
#  '/fastdma-tool': set(),
#  '/champ-tool': set(),
#  '/qdmr-tool': set(),
#  '/cohcap-tool': set(),
#  '/bumphunter-tool': set(),
#  '/ima-tool': set(),
#  '/comb-p-tool': set(),
#  '/aclust-tool': set(),
#  '/blastn-tool': set(),
#  '/blastp-tool': set(),
#  '/hhsuite-tool': set(),
#  '/hmmer-tool': set(),
#  '/hhblits-tool': set(),
#  '/m4t-tool': set(),
#  '/genewise-tool': set(),
#  '/protdec-ltr-tool': set(),
#  '/staden-tool': set(),
#  '/jackhmmer-tool': set(),
#  '/find-circ-tool': set(),
#  '/segemehl-tool': set(),
#  '/circexplorer-tool': set(),
#  '/super-seq-tool': set(),
#  '/ciri-tool': set(),
#  '/knife-tool': set(),
#  '/mapsplice-tool': set(),
#  '/uroborus-tool': set(),
#  '/nclscan-tool': set(),
#  '/circrna-finder-tool': set(),
#  '/mummer-tool': set(),
#  '/jspeciesws-tool': set(),
#  '/drep-tool': set(),
#  '/gvista-tool': set(),
#  '/mvista-tool': set(),
#  '/mauve-tool': set(),
#  '/last-tool': set(),
#  '/lagan-tool': set(),
#  '/ksnp-tool': set(),
#  '/wgvista-tool': set(),
#  '/bayfish-tool': set(),
#  '/smufin-tool': set(),
#  '/breakdancer-tool': set(),
#  '/factera-tool': set(),
#  '/novobreak-tool': set(),
#  '/svmerge-tool': set(),
#  '/breakmer-tool': set(),
#  '/digit-2-tool': set(),
#  '/prism-5-tool': set(),
#  '/gustaf-tool': set(),
#  '/ulysses-2-tool': set(),
#  '/cablast-cablat-tool': set(),
#  '/quartz-tool': set(),
#  '/gqt-tool': set(),
#  '/deez-tool': set(),
#  '/dnazip-tool': set(),
#  '/beetl-tool': set(),
#  '/path-encoding-tool': set(),
#  '/cram-tool': set(),
#  '/dsrc-tool': set(),
#  '/compressed-sam-format-tool': set(),
#  '/baseplayer-tool': set(),
#  '/team-tool': set(),
#  '/myvcf-tool': set(),
#  '/cges-tool': set(),
#  '/biogranat-ig-tool': set(),
#  '/clinlabgeneticist-tool': set(),
#  '/mtb-report-tool': set(),
#  '/phenotips-tool': set(),
#  '/geneyenta-tool': set(),
#  '/varelect-tool': set(),
#  '/oligowiz-tool': set(),
#  '/oligoarray-tool': set(),
#  '/picky-3-tool': set(),
#  '/arrayoligoselector-tool': set(),
#  '/teolenn-tool': set(),
#  '/oli2go-tool': set(),
#  '/affyprobeminer-tool': set(),
#  '/mipgen-tool': set(),
#  '/goarrays-tool': set(),
#  '/kaspod-tool': set(),
#  '/multiqc-tool': set(),
#  '/ngs-qc-generator-tool': set(),
#  '/htseq-tool': set(),
#  '/fastqc-tool': set(),
#  '/uea-srna-toolkit-tool': set(),
#  '/bbt-tool': set(),
#  '/micra-tool': set(),
#  '/phantompeakqualtools-tool': set(),
#  '/ptm-x-tool': set(),
#  '/samtools-tool': set(),
#  '/stacks-tool': set(),
#  '/bio-samtools-tool': set(),
#  '/umi-tools-tool': set(),
#  '/eager-tool': set(),
#  '/octopus-toolkit-tool': set(),
#  '/picard-tool': set(),
#  '/pardre-tool': set(),
#  '/shortread-tool': set(),
#  '/bamtools-tool': set(),
#  '/sqtlseeker-tool': set(),
#  '/glimmps-tool': set(),
#  '/altrans-tool': set(),
#  '/ulfasqtl-tool': set(),
#  '/bayesdrimseq-tool': set(),
#  '/drimseq-tool': set(),
#  '/leafcutter-tool': set(),
#  '/ivas-tool': set(),
#  '/srma-tool': set(),
#  '/rnasequel-tool': set(),
#  '/mmr-tool': set(),
#  '/tophat-recondition-tool': set(),
#  '/bisearch-tool': set(),
#  '/amuser-tool': set(),
#  '/snpbox-tool': set(),
#  '/primerize-tool': set(),
#  '/assembly-pcr-oligo-maker-tool': set(),
#  '/prifi-tool': set(),
#  '/gst-prime-tool': set(),
#  '/mcbasc-tool': set(),
#  '/highssr-tool': set(),
#  '/primerize-2d-tool': set(),
#  '/lcr-exxxplorer-tool': set(),
#  '/dape-tool': set(),
#  '/messa-tool': set(),
#  '/flps-tool': set(),
#  '/lps-annotate-tool': set(),
#  '/mafft-tool': set(),
#  '/mafftash-tool': set(),
#  '/muscle-tool': set(),
#  '/t-coffee-tool': set(),
#  '/halign-tool': set(),
#  '/clustal-omega-tool': set(),
#  '/locarna-tool': set(),
#  '/clustal-w-tool': set(),
#  '/base-by-base-tool': set(),
#  '/picxaa-tool': set(),
#  '/pyrobayes-tool': set(),
#  '/phred-tool': set(),
#  '/alta-cyclic-tool': set(),
#  '/ibis-tool': set(),
#  '/ayb-tool': set(),
#  '/naivebayescall-tool': set(),
#  '/gbs-snp-crop-tool': set(),
#  '/pecaller-tool': set(),
#  '/swift-tool': set(),
#  '/freeibis-tool': set(),
#  '/btyper-tool': set(),
#  '/virulencefinder-tool': set(),
#  '/abricate-tool': set(),
#  '/cardinal-tool': set(),
#  '/pybasis-tool': set(),
#  '/msireader-tool': set(),
#  '/picaudetal2018-tool': set(),
#  '/mitics-tool': set(),
#  '/bedtools-tool': set(),
#  '/sambamba-tool': set(),
#  '/vancouver-short-read-analysis-tool': set(),
#  '/fasparser-tool': set(),
#  '/japsa-tool': set(),
#  '/anticp-tool': set(),
#  '/pepsavi-ms-tool': set(),
#  '/acpred-fl-tool': set(),
#  '/iacp-tool': set(),
#  '/tumorhpd-tool': set(),
#  '/vaccimm-tool': set(),
#  '/mlacp-tool': set(),
#  '/svmdlf-tool': set(),
#  '/acpp-tool': set(),
#  '/k-ecoli457-tool': set(),
#  '/disselkoenetal2016-tool': set(),
#  '/metingear-tool': set(),
#  '/pmfa-tool': set(),
#  '/cgmanalyzer-tool': set(),
#  '/promact-tool': set(),
#  '/lux-score-tool': set(),
#  '/drum-tool': set(),
#  '/mmf-tool': set(),
#  '/psomcs-tool': set(),
#  '/quadbase-tool': set(),
#  '/g4hunter-tool': set(),
#  '/qgrs-mapper-tool': set(),
#  '/qgrs-h-predictor-tool': set(),
#  '/g4rna-screener-tool': set(),
#  '/pqsfinder-tool': set(),
#  '/quadfinder-tool': set(),
#  '/quadpredict-tool': set(),
#  '/integrate-neo-tool': set(),
#  '/cloudneo-tool': set(),
#  '/pvac-seq-tool': set(),
#  '/tsnad-tool': set(),
#  '/mupexi-tool': set(),
#  '/neoantigenr-tool': set(),
#  '/neoepiscope-tool': set(),
#  '/gatk-tool': set(),
#  '/archtex-tool': set(),
#  '/ngs-bits-tool': set(),
#  '/jvarkit-tool': set(),
#  '/elprep-tool': set(),
#  '/xstk-tool': set(),
#  '/seres-tool': set(),
#  '/the-flux-capacitor-tool': set(),
#  '/ssa-tool': set(),
#  '/flux-simulator-tool': set(),
#  '/lncseeker-tool': set(),
#  '/powsimr-tool': set(),
#  '/analyzereplication-tool': set(),
#  '/samexplorer-tool': set(),
#  '/scotty-tool': set(),
#  '/proper-tool': set(),
#  '/subseq-tool': set(),
#  '/mqtl-tool': set(),
#  '/mvapack-tool': set(),
#  '/icoshift-tool': set(),
#  '/automics-tool': set(),
#  '/chemospec-tool': set(),
#  '/nmrprocflow-tool': set(),
#  '/datachord-spectrum-analyst-tool': set(),
#  '/hires-tool': set(),
#  '/focus-tool': set(),
#  '/batman-tool': set(),
#  '/nmrpipe-tool': set(),
#  '/mnova-nmr-tool': set(),
#  '/matnmr-tool': set(),
#  '/bayesil-tool': set(),
#  '/metabohunter-tool': set(),
#  '/nuts-tool': set(),
#  '/newton-tool': set(),
#  '/knowitall-informatics-system-tool': set(),
#  '/ransy-ramsy-tool': set(),
#  '/pfim-tool': set(),
#  '/ednaoccupancy-tool': set(),
#  '/polypk-tool': set(),
#  '/jags-tool': set(),
#  '/phxnlme-tool': set(),
#  '/gpkpdsim-tool': set(),
#  '/nonmem-tool': set(),
#  '/winbugs-tool': set(),
#  '/phoenix-nlme-tool': set(),
#  '/blastx-tool': set(),
#  '/mmseqs-tool': set(),
#  '/diamond-tool': set(),
#  '/blat-tool': set(),
#  '/super-focus-tool': set(),
#  '/consensus-sequence-searches-tool': set(),
#  '/falp-tool': set(),
#  '/taxonomer-tool': set(),
#  '/rapsearch-tool': set(),
#  '/spider-2-tool': set(),
#  '/focus-3-tool': set(),
#  '/dynamo-tool': set(),
#  '/tomominer-2-tool': set(),
#  '/peet-tool': set(),
#  '/tomoalign-tool': set(),
#  '/raza-tool': set(),
#  '/protomo-tool': set(),
#  '/tccc-tool': set(),
#  '/bowtie-tool': set(),
#  '/bowtie2-tool': set(),
#  '/giggle-tool': set(),
#  '/rsf-tool': set(),
#  '/soap2-tool': set(),
#  '/spades-tool': set(),
#  '/trinity-tool': set(),
#  '/trans-abyss-tool': set(),
#  '/rsem-tool': set(),
#  '/ebardenovo-tool': set(),
#  '/velvet-tool': set(),
#  '/kissplice-tool': set(),
#  '/rockhopper-tool': set(),
#  '/mira-2-tool': set(),
#  '/ragtop-tool': set(),
#  '/rnapdbee-tool': set(),
#  '/pseudoviewer-tool': set(),
#  '/unafold-tool': set(),
#  '/nanofolder-tool': set(),
#  '/rna-decoder-tool': set(),
#  '/bhg-tool': set(),
#  '/dotknot-tool': set(),
#  '/dssr-tool': set(),
#  '/pseudobase-tool': set(),
#  '/repitools-tool': set(),
#  '/medme-tool': set(),
#  '/qsea-tool': set(),
#  '/methylaction-tool': set(),
#  '/medips-tool': set(),
#  '/meqa-tool': set(),
#  '/methyl-analyzer-tool': set(),
#  '/medusa-tool': set(),
#  '/mirvas-tool': set(),
#  '/mirnasnp-tool': set(),
#  '/masigpro-tool': set(),
#  '/cstea-tool': set(),
#  '/dynb-tool': set(),
#  '/ebseq-hmm-tool': set(),
#  '/diffsplicing-tool': set(),
#  '/diceseq-tool': set(),
#  '/impulsede-tool': set(),
#  '/funpat-tool': set(),
#  '/detect-tool': set(),
#  '/priam-tool': set(),
#  '/nebcutter-tool': set(),
#  '/dbcan-tool': set(),
#  '/kea-tool': set(),
#  '/phosphochain-tool': set(),
#  '/modl-tool': set(),
#  '/ikap-tool': set(),
#  '/seql-nrps-tool': set(),
#  '/hcsa-tool': set(),
#  '/glo-roots-tool': set(),
#  '/rootnav-tool': set(),
#  '/rootgraph-tool': set(),
#  '/nefi-tool': set(),
#  '/gia-roots-tool': set(),
#  '/leaf-gui-tool': set(),
#  '/breakseq-tool': set(),
#  '/genome-strip-tool': set(),
#  '/meerkat-tool': set(),
#  '/mrcanavar-tool': set(),
#  '/cnvnator-tool': set(),
#  '/control-freec-tool': set(),
#  '/crest-tool': set(),
#  '/conserting-tool': set(),
#  '/groc-svs-tool': set(),
#  '/bic-seq-tool': set(),
#  '/smrt-sv-tool': set(),
#  '/syzygy-tool': set(),
#  '/platypus-tool': set(),
#  '/nanopolish-tool': set(),
#  '/modil-tool': set(),
#  '/denovogear-tool': set(),
#  '/splitread-tool': set(),
#  '/david-tool': set(),
#  '/blast2go-tool': set(),
#  '/genemania-tool': set(),
#  '/agrigo-tool': set(),
#  '/great-tool': set(),
#  '/webgestalt-tool': set(),
#  '/navigo-tool': set(),
#  '/seqsphere-tool': set(),
#  '/abawaca-tool': set(),
#  '/checkm-tool': set(),
#  '/cegma-tool': set(),
#  '/quast-tool': set(),
#  '/qualimap-tool': set(),
#  '/reapr-tool': set(),
#  '/cgal-tool': set(),
#  '/busco-tool': set(),
#  '/kat-tool': set(),
#  '/ucsf-chimera-tool': set(),
#  '/eman-tool': set(),
#  '/cryosparc-tool': set(),
#  '/emringer-tool': set(),
#  '/thunder-tool': set(),
#  '/relion-tool': set(),
#  '/imagic-tool': set(),
#  '/rome-tool': set(),
#  '/scansite-tool': set(),
#  '/elm-tool': set(),
#  '/14-3-3-pred-tool': set(),
#  '/ania-tool': set(),
#  '/-magellan-tool': set(),
#  '/nanoj-fluidics-tool': set(),
#  '/rtxi-tool': set(),
#  '/scanimage-tool': set(),
#  '/mmanager-tool': set(),
#  '/digital-autofocus-tool': set(),
#  '/youscope-tool': set(),
#  '/metamorph-tool': set(),
#  '/image-pro-tool': set(),
#  '/cellsens-tool': set(),
#  '/antiangiopred-tool': set(),
#  '/antangiocool-tool': set(),
#  '/birdsuite-tool': set(),
#  '/rlmm-tool': set(),
#  '/affypipe-tool': set(),
#  '/vcf2sm-tool': set(),
#  '/ensemblecnv-tool': set(),
#  '/rice-galaxy-tool': set(),
#  '/suretypesc-tool': set(),
#  '/genosnp-tool': set(),
#  '/pride-converter-tool': set(),
#  '/proteowizard-tool': set(),
#  '/multiplierz-tool': set(),
#  '/pymzml-tool': set(),
#  '/rawconverter-tool': set(),
#  '/mzrefinery-tool': set(),
#  '/libfbi-tool': set(),
#  '/mzdesktop-tool': set(),
#  '/thermo-msf-parser-tool': set(),
#  '/jtraml-tool': set(),
#  '/posibatch-tool': set(),
#  '/combat-tool': set(),
#  '/meme-suite-tool': set(),
#  '/spp-tool': set(),
#  '/deepbind-tool': set(),
#  '/macs-tool': set(),
#  '/geworkbench-tool': set(),
#  '/rvista-tool': set(),
#  '/extreme-tool': set(),
#  '/rcistarget-tool': set(),
#  '/signalspider-tool': set(),
#  '/cufflinks-tool': set(),
#  '/fusorsv-tool': set(),
#  '/vcftools-tool': set(),
#  '/conomass-tool': set(),
#  '/conoprec-tool': set(),
#  '/conodictor-tool': set(),
#  '/gaq-tool': set(),
#  '/gfpe-tool': set(),
#  '/ugahash-tool': set(),
#  '/eval-tool': set(),
#  '/cgl-tool': set(),
#  '/annotation-issues-tool': set(),
#  '/aegean-tool': set(),
#  '/parseval-tool': set(),
#  '/meta-a-nnotator-tool': set(),
#  '/acs-tool': set(),
#  '/pyrotools-tool': set(),
#  '/bsseq-tool': set(),
#  '/saap-rrbs-tool': set(),
#  '/bseqc-tool': set(),
#  '/minionqc-tool': set(),
#  '/smap-2-tool': set(),
#  '/tabsat-tool': set(),
#  '/methyqa-tool': set(),
#  '/bspat-tool': set(),
#  '/amrfinder-tool': set(),
#  '/mea-2-tool': set(),
#  '/methpipe-tool': set(),
#  '/omsv-tool': set(),
#  '/soma-tool': set(),
#  '/missequel-tool': set(),
#  '/omblast-tool': set(),
#  '/maplinker-tool': set(),
#  '/omtools-tool': set(),
#  '/maligner-tool': set(),
#  '/irys-extract-tool': set(),
#  '/omsim-tool': set(),
#  '/bmsim-tool': set(),
#  '/ascat-tool': set(),
#  '/aneufinder-tool': set(),
#  '/madseq-tool': set(),
#  '/thapmix-tool': set(),
#  '/niptmer-tool': set(),
#  '/scploid-tool': set(),
#  '/coffee-tool': set(),
#  '/wandy-tool': set(),
#  '/iro-3wpseknc-tool': set(),
#  '/iori-human-tool': set(),
#  '/ori-finder-2-tool': set(),
#  '/ori-finder-1-tool': set(),
#  '/mmarge-tool': set(),
#  '/bifet-tool': set(),
#  '/dastk-tool': set(),
#  '/i-atac-tool': set(),
#  '/hmmratac-tool': set(),
#  '/deepatac-tool': set(),
#  '/penncnv-tool': set(),
#  '/nowaves-tool': set(),
#  '/waca-tool': set(),
#  '/upset-tool': set(),
#  '/biovenn-tool': set(),
#  '/venndis-tool': set(),
#  '/venny-tool': set(),
#  '/interactivenn-tool': set(),
#  '/jvenn-tool': set(),
#  '/orthovenn-tool': set(),
#  '/venn-diagram-tool': set(),
#  '/venndiagram-tool': set(),
#  '/openmzxy-tool': set(),
#  '/chims-tool': set(),
#  '/analyzethis-tool': set(),
#  '/mmsit-tool': set(),
#  '/4000-series-imaging-tool': set(),
#  '/imagequest-tool': set(),
#  '/usearch-tool': set(),
#  '/uclust-tool': set(),
#  '/mpi-bioinformatics-toolkit-tool': set(),
#  '/kpax-2-tool': set(),
#  '/modclus-tool': set(),
#  '/kfits-tool': set(),
#  '/kappa-tool': set(),
#  '/evoclust3d-tool': set(),
#  '/ogcleaner-tool': set(),
#  '/dace-tool': set(),
#  '/gsea-tool': set(),
#  '/deseq2-tool': set(),
#  '/babelomics-tool': set(),
#  '/pathview-tool': set(),
#  '/pbcr-tool': set(),
#  '/ides-tool': set(),
#  '/poreseq-tool': set(),
#  '/standalone-hamming-tool': set(),
#  '/lqs-tool': set(),
#  '/mecat-2-tool': set(),
#  '/sga-ice-tool': set(),
#  '/falcon-2-tool': set(),
#  '/canu-tool': set(),
#  '/sga-tool': set(),
#  '/profeat-tool': set(),
#  '/pse-in-one-tool': set(),
#  '/partslist-tool': set(),
#  '/pseaac-builder-tool': set(),
#  '/propy-tool': set(),
#  '/psekraac-tool': set(),
#  '/bioseq-analysis-tool': set(),
#  '/oogenesis-pred-tool': set(),
#  '/ultrapse-tool': set(),
#  '/pepcomp-tool': set(),
#  '/bioimagexd-tool': set(),
#  '/vibe-z-tool': set(),
#  '/debias-tool': set(),
#  '/jacop-tool': set(),
#  '/diana-2-tool': set(),
#  '/mosaicia-tool': set(),
#  '/cda-2-tool': set(),
#  '/obcol-tool': set(),
#  '/huygens-tool': set(),
#  '/coloc-2-tool': set(),
#  '/multimaging-tool': set(),
#  '/varscan-tool': set(),
#  '/xhmm-tool': set(),
#  '/oncocnv-tool': set(),
#  '/codex-2-tool': set(),
#  '/excavator-tool': set(),
#  '/canvas-tool': set(),
#  '/conifer-tool': set(),
#  '/fuge-tool': set(),
#  '/oompa-tool': set(),
#  '/expander-tool': set(),
#  '/brb-arraytools-tool': set(),
#  '/j-express-tool': set(),
#  '/mem-tool': set(),
#  '/arrayanalysis-org-tool': set(),
#  '/genedata-expressionist-tool': set(),
#  '/robina-tool': set(),
#  '/homer-tool': set(),
#  '/deeptools-tool': set(),
#  '/poretools-tool': set(),
#  '/maq-tool': set(),
#  '/pore-tool': set(),
#  '/micropilot-tool': set(),
#  '/easy-frap-tool': set(),
#  '/pyfrap-tool': set(),
#  '/pyfdap-tool': set(),
#  '/simfrap-tool': set(),
#  '/frap-profiler-tool': set(),
#  '/frap-norm-tool': set(),
#  '/frapcalc-tool': set(),
#  '/frapanalyser-tool': set(),
#  '/labguru-tool': set(),
#  '/elabftw-tool': set(),
#  '/emen2-tool': set(),
#  '/emen-tool': set(),
#  '/sumatra-tool': set(),
#  '/elabjournal-tool': set(),
#  '/labarchives-tool': set(),
#  '/labfolder-tool': set(),
#  '/scinote-tool': set(),
#  '/mbook-tool': set(),
#  '/plink-tool': set(),
#  '/diseasequest-tool': set(),
#  '/gengen-tool': set(),
#  '/genets-tool': set(),
#  '/i-gsea4gwas-tool': set(),
#  '/mapman-tool': set(),
#  '/paris-2-tool': set(),
#  '/vegas-tool': set(),
#  '/gsa-snp-tool': set(),
#  '/icsnpathway-tool': set(),
#  '/antheprot-tool': set(),
#  '/protein-sol-tool': set(),
#  '/proso-ii-tool': set(),
#  '/soda-2-tool': set(),
#  '/cleversuite-tool': set(),
#  '/ccsol-omics-tool': set(),
#  '/parsnip-tool': set(),
#  '/deepsol-tool': set(),
#  '/protein-ml-tool': set(),
#  '/bwtool-tool': set(),
#  '/caftools-tool': set(),
#  '/methprimer-tool': set(),
#  '/hgvs-tool': set(),
#  '/sra-toolkit-tool': set(),
#  '/detect-nahr-tool': set(),
#  '/hrefinder-tool': set(),
#  '/npinv-tool': set(),
#  '/deepvariant-tool': set(),
#  '/deepsvr-tool': set(),
#  '/marginalign-tool': set(),
#  '/speedseq-tool': set(),
#  '/monovar-tool': set(),
#  '/gr-calculator-tool': set(),
#  '/yangetal2017-tool': set(),
#  '/g2p-hcv-tool': set(),
#  '/positionalmi-tool': set(),
#  '/biozyne-p-gp-predictor-tool': set(),
#  '/vrprofile-tool': set(),
#  '/mdp-tool': set(),
#  '/igb-2-tool': set(),
#  '/cancerdr-tool': set(),
#  '/icma-tool': set(),
#  '/field-ii-tool': set(),
#  '/plus-tool': set(),
#  '/cyberlogic-tool': set(),
#  '/awesome-ultrasound-simulator-tool': set(),
#  '/gpcrm-tool': set(),
#  '/gpcr-modsim-tool': set(),
#  '/gpcrsclass-tool': set(),
#  '/galaxygpcrloop-tool': set(),
#  '/gpcrhmm-tool': set(),
#  '/liticon-tool': set(),
#  '/griffin-tool': set(),
#  '/outrigger-tool': set(),
#  '/bonvoyage-tool': set(),
#  '/brie-tool': set(),
#  '/singlesplice-tool': set(),
#  '/isop-tool': set(),
#  '/triocaller-tool': set(),
#  '/genomevip-tool': set(),
#  '/epidenovo-tool': set(),
#  '/famseq-tool': set(),
#  '/triodenovo-tool': set(),
#  '/dnmfilter-tool': set(),
#  '/epigram-tool': set(),
#  '/mutalisk-tool': set(),
#  '/dcma-tool': set(),
#  '/deepchrome-tool': set(),
#  '/hmcan-tool': set(),
#  '/lpchp-tool': set(),
#  '/deepdiff-tool': set(),
#  '/epiregnet-tool': set(),
#  '/epicode-tool': set(),
#  '/chipseqr-tool': set(),
#  '/haploview-tool': set(),
#  '/poplddecay-tool': set(),
#  '/ldlink-tool': set(),
#  '/qtdt-tool': set(),
#  '/ldak-tool': set(),
#  '/ldheatmap-tool': set(),
#  '/avengeme-tool': set(),
#  '/loco-ld-tool': set(),
#  '/ldstore-tool': set(),
#  '/lian-tool': set(),
#  '/flowflowjo-tool': set(),
#  '/modfit-lt-tool': set(),
#  '/nmrlab-tool': set(),
#  '/specmine-tool': set(),
#  '/jmrui-tool': set(),
#  '/mitobo-tool': set(),
#  '/seevis-tool': set(),
#  '/scip-tool': set(),
#  '/html5-pivotviewer-tool': set(),
#  '/mia-3-tool': set(),
#  '/imod-tool': set(),
#  '/3d-slicer-tool': set(),
#  '/synd-tool': set(),
#  '/celltool-tool': set(),
#  '/snpsift-tool': set(),
#  '/maftools-tool': set(),
#  '/mucor-tool': set(),
#  '/hnmf-tool': set(),
#  '/vtc-tool': set(),
#  '/qpileup-tool': set(),
#  '/joinx-tool': set(),
#  '/phenoripper-tool': set(),
#  '/nat-nblast-tool': set(),
#  '/blobfinder-tool': set(),
#  '/chrysalis-tool': set(),
#  '/cytopacq-tool': set(),
#  '/deepometry-tool': set(),
#  '/aivia-tool': set(),
#  '/ecc-tool': set(),
#  '/cellaging-tool': set(),
#  '/vizardous-tool': set(),
#  '/microbetracker-tool': set(),
#  '/lm-2-tool': set(),
#  '/tracmit-tool': set(),
#  '/bacstalk-tool': set(),
#  '/lineagetracker-tool': set(),
#  '/treej-tool': set(),
#  '/imosflm-tool': set(),
#  '/eom-tool': set(),
#  '/monsa-tool': set(),
#  '/xds-tool': set(),
#  '/cryson-tool': set(),
#  '/dammin-tool': set(),
#  '/gasbor-tool': set(),
#  '/atsas-tool': set(),
#  '/sasref-tool': set(),
#  '/bunch-tool': set(),
#  '/trend-tool': set(),
#  '/chaste-tool': set(),
#  '/plinguacore-tool': set(),
#  '/e-cell-tool': set(),
#  '/compucell3d-tool': set(),
#  '/virtualleaf-tool': set(),
#  '/rallpacks-tool': set(),
#  '/timothy-tool': set(),
#  '/mea-tools-tool': set(),
#  '/find-tool': set(),
#  '/admire-tool': set(),
#  '/meviz-tool': set(),
#  '/methyanalysis-tool': set(),
#  '/riboabacus-tool': set(),
#  '/stalcalc-tool': set(),
#  '/mdfit-tool': set(),
#  '/baps-tool': set(),
#  '/seraphim-tool': set(),
#  '/gengis-tool': set(),
#  '/spread-tool': set(),
#  '/geosymbio-tool': set(),
#  '/phylogeoviz-tool': set(),
#  '/ginkgo-2-tool': set(),
#  '/spagedi-tool': set(),
#  '/tcsbu-tool': set(),
#  '/fswm-tool': set(),
#  '/flowjo-tool': set(),
#  '/flowai-tool': set(),
#  '/autogate-tool': set(),
#  '/platecore-tool': set(),
#  '/bd-facsdiva-tool': set(),
#  '/flowing-software-tool': set(),
#  '/targetfinder-2-tool': set(),
#  '/pep-tool': set(),
#  '/ep2vec-tool': set(),
#  '/speid-tool': set(),
#  '/targetfinder-tool': set(),
#  '/13check-rna-tool': set(),
#  '/m6asnp-tool': set(),
#  '/repprofile-tool': set(),
#  '/trnamodpred-tool': set(),
#  '/trnamod-tool': set(),
#  '/irna-psecoll-tool': set(),
#  '/appion-tool': set(),
#  '/mib-2-tool': set(),
#  '/fiji-macro-3d-art-veselect-tool': set(),
#  '/tomosegmentv-tool': set(),
#  '/tomosegmem-tool': set(),
#  '/em3d-tool': set(),
#  '/interactive-h-watershed-tool': set(),
#  '/amira-3d-software-for-life-sciences-tool': set(),
#  '/ucsc-liftover-tool': set(),
#  '/crossmap-tool': set(),
#  '/recot-tool': set(),
#  '/segment-liftover-tool': set(),
#  '/ncbi-genome-remapping-service-tool': set(),
#  '/assembly-converter-tool': set(),
#  '/squizz-tool': set(),
#  '/abra-tool': set(),
#  '/omindel-tool': set(),
#  '/ffea-tool': set(),
#  '/enrich2-tool': set(),
#  '/enrich-tool': set(),
#  '/dms-tools-tool': set(),
#  '/dms2dfe-tool': set(),
#  '/signalp-tool': set(),
#  '/caspredictor-tool': set(),
#  '/prosperous-tool': set(),
#  '/deepsig-tool': set(),
#  '/iprot-sub-tool': set(),
#  '/labcas-tool': set(),
#  '/hivcleave-tool': set(),
#  '/pops-tool': set(),
#  '/peptidecutter-tool': set(),
#  '/rapid-peptides-generator-tool': set(),
#  '/hemopi-tool': set(),
#  '/masstrix-tool': set(),
#  '/pathvisio-tool': set(),
#  '/chemsmp-tool': set(),
#  '/marvis-pathway-tool': set(),
#  '/metamapp-tool': set(),
#  '/cpath-tool': set(),
#  '/magi-4-tool': set(),
#  '/analyzerpro-tool': set(),
#  '/incromap-tool': set(),
#  '/metdat-tool': set(),
#  '/scooby-domain-tool': set(),
#  '/phobius-tool': set(),
#  '/scanprosite-tool': set(),
#  '/comet-tool': set(),
#  '/swakk-tool': set(),
#  '/global-tool': set(),
#  '/fiefdom-tool': set(),
#  '/threadomex-tool': set(),
#  '/gsb-tool': set(),
#  '/biodwh-tool': set(),
#  '/aws-public-datasets-tool': set(),
#  '/seqhound-tool': set(),
#  '/phymmbl-tool': set(),
#  '/concoct-tool': set(),
#  '/metabat-tool': set(),
#  '/metacluster-ta-tool': set(),
#  '/maxbin-tool': set(),
#  '/hmmufotu-tool': set(),
#  '/metagen-2-tool': set(),
#  '/d2sbin-tool': set(),
#  '/vizbin-tool': set(),
#  '/metawrap-tool': set(),
#  '/free-d-tool': set(),
#  '/cellorganizer-tool': set(),
#  '/pview-2-tool': set(),
#  '/bids-apps-tool': set(),
#  '/nibabel-tool': set(),
#  '/pynifti-tool': set(),
#  '/edfbrowser-tool': set(),
#  '/scwrl-tool': set(),
#  '/opus-rota-tool': set(),
#  '/nq-flipper-tool': set(),
#  '/betascpweb-tool': set(),
#  '/scap-tool': set(),
#  '/opus-psp-tool': set(),
#  '/pscpp-tool': set(),
#  '/irecs-tool': set(),
#  '/basilisk-tool': set(),
#  '/cis-rr-tool': set(),
#  '/flya-tool': set(),
#  '/nmr-constraints-analyser-tool': set(),
#  '/nmrfam-sparky-tool': set(),
#  '/pine-sparky-tool': set(),
#  '/nvassign-tool': set(),
#  '/autoassign-tool': set(),
#  '/pine-nmr-tool': set(),
#  '/autolink-tool': set(),
#  '/adapt-nmr-tool': set(),
#  '/sencs-tool': set(),
#  '/s-peaker-tool': set(),
#  '/slic-cage-tool': set(),
#  '/pipipes-tool': set(),
#  '/reclu-tool': set(),
#  '/capfilter-tool': set(),
#  '/cagefightr-tool': set(),
#  '/methylphet-tool': set(),
#  '/pybedtools-tool': set(),
#  '/pgltools-tool': set(),
#  '/csvtk-tool': set(),
#  '/cellcognition-tool': set(),
#  '/histocat-tool': set(),
#  '/cellprofiler-tool': set(),
#  '/phenoplot-tool': set(),
#  '/mineotaur-tool': set(),
#  '/more-software-analysis-tool': set(),
#  '/cpa-tool': set(),
#  '/motiw-tool': set(),
#  '/tactics-tool': set(),
#  '/cellh5-tool': set(),
#  '/3d-cell-shape-and-migration-tool': set(),
#  '/patternunmixer-tool': set(),
#  '/cmeanalysis-tool': set(),
#  '/synpanal-tool': set(),
#  '/automated-image-analysis-of-protein-localization-in-budding-yeast-tool': set(),
#  '/s-psorter-tool': set(),
#  '/plast-tool': set(),
#  '/pcaanalyser-tool': set(),
#  '/qfsm-tool': set(),
#  '/tcpa-tool': set(),
#  '/rppanalyzer-tool': set(),
#  '/a-robust-classifier-for-quality-control-of-reverse-phase-protein-arrays-tool': set(),
#  '/miracle-tool': set(),
#  '/normacurve-tool': set(),
#  '/rppapipe-tool': set(),
#  '/microvigene-tool': set(),
#  '/supercurve-tool': set(),
#  '/rppa-preprocess-tool': set(),
#  '/webknossos-tool': set(),
#  '/ultratracer-tool': set(),
#  '/segem-tool': set(),
#  '/axontracker-3d-tool': set(),
#  '/deepem3d-tool': set(),
#  '/rhoana-tool': set(),
#  '/neuroproof-tool': set(),
#  '/farsight-tool': set(),
#  '/spinelab-tool': set(),
#  '/reconstruct-tool': set(),
#  '/quake-tool': set(),
#  '/bystro-tool': set(),
#  '/varaft-tool': set(),
#  '/bcftools-tool': set(),
#  '/utrscan-tool': set(),
#  '/popera-tool': set(),
#  '/mscan-tool': set(),
#  '/bobro-tool': set(),
#  '/mcast-tool': set(),
#  '/regulus-tool': set(),
#  '/monkey-tool': set(),
#  ...}

# %%
pmid_dict = generate_pmid_dict()

# %%
pmid_category_dict =

# %%
for i in pmid_dict:
    if len(pmid_dict[i]) > 1:
        print(i,pmid_dict[i])
# Out:
# 28159004 {'/3d-genome-browser-tool', '/my5c-tool', '/diffhic-tool', '/hicplotter-tool', '/tadkit-tool', '/shrec3d-tool'}
# 29531215 {'/hicup-tool', '/3d-genome-browser-tool', '/chia-pet-tool'}
# 28977418 {'/autochrom3d-tool', '/hiclib-tool'}
# 28180292 {'/lordg-tool', '/shrec3d-tool'}
# 28771695 {'/biojs-tool', '/aquaria-tool', '/tadbit-tool', '/magi-2-tool', '/tadkit-tool'}
# 29170434 {'/squirrel-tool', '/tadbit-tool', '/simcheck-tool'}
# 29686798 {'/higlass-tool', '/f-seq-tool', '/juicebox-tool', '/tadbit-tool', '/danpos-tool', '/dnase2tf-tool', '/centipede-tool', '/hicpipe-tool', '/juicer-tool'}
# 28954001 {'/mlst-tool', '/alientrimmer-tool'}
# 29691339 {'/alientrimmer-tool', '/mash-tool'}
# 29301880 {'/spades-tool', '/cutadapt-tool', '/pgap-2-tool'}
# 29311560 {'/cutadapt-tool', '/fastx-toolkit-tool'}
# 29320577 {'/tigger-tool', '/bowtie-tool', '/cutadapt-tool', '/deseq-tool'}
# 29354114 {'/cutadapt-tool', '/psrnatarget-tool'}
# 29743479 {'/meme-chip-tool', '/km-plotter-tool', '/cutadapt-tool', '/subread-tool', '/deeptools-tool', '/thor-tool'}
# 29760424 {'/tabsat-tool', '/cutadapt-tool', '/trim-galore-tool', '/bowtie-tool', '/monocle-tool'}
# 29764370 {'/star-3-tool', '/cutadapt-tool'}
# 28616190 {'/ddocent-tool', '/bgc-tool'}
# 28729652 {'/ddocent-tool', '/pyrad-tool'}
# 29435226 {'/ddocent-tool', '/bamtools-tool', '/odintifier-tool', '/paleomix-tool'}
# 29515871 {'/ddocent-tool', '/pyrad-tool'}
# 10827456 {'/emboss-tool', '/skipredundant-tool'}
# 29061367 {'/emboss-tool', '/muscle-tool'}
# 29326200 {'/rast-tool', '/genemarks-tool', '/prodigal-tool', '/trnascan-se-tool', '/clc-bio-tool', '/emboss-tool', '/glimmer-tool'}
# 29467727 {'/emboss-tool', '/phobius-tool'}
# 29743632 {'/emboss-tool', '/coloc-2-tool', '/raptorx-tool', '/fcs-express-tool'}
# 29768530 {'/maxquant-tool', '/tempest-tool', '/seqinr-tool', '/emboss-tool', '/aliview-tool', '/beast-tool'}
# 29777105 {'/bwa-tool', '/gatk-tool', '/clc-bio-tool', '/picard-tool', '/samtools-tool', '/emboss-tool', '/ggbio-tool'}
# 29326207 {'/newbler-tool', '/prokka-tool'}
# 29371367 {'/newbler-tool', '/glimmer-tool'}
# 29371910 {'/newbler-tool', '/prodigal-tool'}
# 29434576 {'/mummer-tool', '/newbler-tool', '/idba-ud-tool', '/ori-finder-2-tool'}
# 29435100 {'/newbler-tool', '/tmhmm-tool', '/staden-tool'}
# 29748396 {'/aragorn-tool', '/newbler-tool', '/genemark-tool', '/glimmer-tool'}
# 29748402 {'/newbler-tool', '/prokka-tool'}
# 29748410 {'/newbler-tool', '/checkm-tool', '/concoct-tool', '/prokka-tool'}
# 29773850 {'/easyfig-tool', '/blastp-tool', '/newbler-tool', '/gendb-tool', '/clustal-w-tool', '/phyml-tool'}
# 28178932 {'/repet-tool', '/skewer-tool'}
# 28267806 {'/centrimo-tool', '/skewer-tool'}
# 28417958 {'/transrate-tool', '/upset-tool', '/skewer-tool'}
# 28793306 {'/snprelate-tool', '/skewer-tool'}
# 29317592 {'/ants-tool', '/dti-tk-tool', '/skewer-tool'}
# 29367590 {'/symap-tool', '/genomescope-tool', '/skewer-tool'}
# 29391536 {'/sc3-tool', '/skewer-tool'}
# 29651122 {'/pear-tool', '/skewer-tool'}
# 29301895 {'/spades-tool', '/genemark-tool', '/trim-galore-tool'}
# 29317678 {'/bedtools-tool', '/trim-galore-tool'}
# 29351814 {'/macs-tool', '/trim-galore-tool'}
# 29730990 {'/masigpro-tool', '/dynet-tool', '/bd-facsdiva-tool', '/trim-galore-tool'}
# 29738525 {'/ruvseq-tool', '/noiseq-tool', '/multiqc-tool', '/trim-galore-tool'}
# 29743012 {'/genepop-tool', '/trim-galore-tool', '/popoolation-tool', '/stm-tool', '/pcadapt-tool', '/quast-tool'}
# 29764946 {'/augustus-tool', '/cegma-tool', '/trim-galore-tool', '/iq-tree-tool', '/tmhmm-tool', '/genemark-hmm-tool', '/picard-tool', '/blast2go-tool', '/mummer-tool', '/signalp-tool', '/varscan-tool'}
# 29297464 {'/bowtie-tool', '/edger-tool', '/htseq-tool', '/trimmomatic-tool'}
# 29300724 {'/star-3-tool', '/htseq-tool', '/trimmomatic-tool', '/deseq2-tool'}
# 29301877 {'/serotypefinder-tool', '/fastqc-tool', '/trimmomatic-tool'}
# 29301900 {'/trimmomatic-tool', '/blastp-tool', '/prodigal-tool', '/spades-tool', '/fastqc-tool', '/aragorn-tool'}
# 29302059 {'/igv-tool', '/bowtie2-tool', '/trimmomatic-tool', '/sispotr-tool'}
# 29765032 {'/homer-tool', '/gsea-tool', '/trimmomatic-tool'}
# 29773799 {'/tophat-tool', '/subread-tool', '/trimmomatic-tool', '/edger-tool', '/bowtie2-tool', '/fastqc-tool', '/fuma-2-tool', '/minimac-tool', '/bolt-lmm-tool'}
# 29774232 {'/trimmomatic-tool', '/astral-tool', '/gblocks-tool', '/phyluce-tool', '/phytools-tool', '/trinity-tool', '/mafft-tool'}
# 28931413 {'/juicer-tool', '/juicebox-tool', '/piq-tool', '/pydnase-tool'}
# 29654311 {'/juicebox-tool', '/fimo-tool', '/hic-pro-tool'}
# 28854926 {'/sspace-longread-tool', '/lachesis-tool'}
# 29145861 {'/juicer-tool', '/gapfill-tool', '/lachesis-tool'}
# 29423238 {'/hicpipe-tool', '/hicup-tool', '/synmap-tool', '/lachesis-tool'}
# 26039089 {'/chipotle-tool', '/salsa-tool'}
# 21245079 {'/alta-cyclic-tool', '/swift-tool', '/naivebayescall-tool'}
# 26920804 {'/ibis-tool', '/ayb-tool', '/simseq-tool', '/naivebayescall-tool'}
# 27436340 {'/snpest-tool', '/freeibis-tool', '/saber-tool', '/tsser-tool', '/naivebayescall-tool'}
# 27463017 {'/deml-tool', '/preseq-tool', '/freeibis-tool'}
# 27669147 {'/deml-tool', '/scde-2-tool', '/freeibis-tool', '/leehom-tool'}
# 28695206 {'/freeibis-tool', '/leehom-tool'}
# 29234095 {'/simcoal-tool', '/haplofind-tool', '/freeibis-tool'}
# 29255116 {'/pcadapt-tool', '/gbs-snp-crop-tool'}
# 25212860 {'/ibis-tool', '/mia-tool'}
# 23020841 {'/bystro-tool', '/pecaller-tool'}
# 28440315 {'/bystro-tool', '/pecaller-tool'}
# 29025761 {'/crossmap-tool', '/pecaller-tool'}
# 27844108 {'/phred-tool', '/ssaha-tool'}
# 23936375 {'/bio-samtools-tool', '/pyrobayes-tool'}
# 12538238 {'/affy-tool', '/rmaexpress-tool'}
# 29329273 {'/affy-tool', '/mieaa-tool'}
# 29337789 {'/affy-tool', '/limma-tool'}
# 29387060 {'/affy-tool', '/sva-2-tool'}
# 29720087 {'/affy-tool', '/normfinder-tool', '/agrigo-tool', '/fastpcr-tool'}
# 29743953 {'/affy-tool', '/goseq-tool'}
# 29764390 {'/affy-tool', '/weblogo-tool', '/cistrome-tool', '/tomtom-tool'}
# 29773851 {'/affy-tool', '/targetscan-tool', '/cytoscape-tool'}
# 29556568 {'/arrayanalysis-org-tool', '/centiscape-tool', '/jactivemodules-tool'}
# 28827734 {'/cpgassoc-tool', '/watermelon-tool', '/champ-tool'}
# 29692867 {'/minfi-tool', '/bumphunter-tool', '/champ-tool'}
# 29721079 {'/ima-tool', '/msp-htprimer-tool', '/champ-tool'}
# 29484035 {'/minfi-tool', '/ruvm-tool', '/bumphunter-tool', '/missmethyl-tool'}
# 29671397 {'/swan-tool', '/missmethyl-tool', '/illuminaio-tool', '/watermelon-tool', '/methylumi-tool', '/enmix-tool', '/minfi-tool', '/bmiq-tool'}
# 29695247 {'/sva-2-tool', '/watermelon-tool', '/enmix-tool', '/minfi-tool', '/bmiq-tool'}
# 29743579 {'/minfi-tool', '/enmix-tool', '/cohcap-tool'}
# 29763623 {'/cbioportal-tool', '/annovar-tool', '/conumee-tool', '/minfi-tool', '/breakdancer-tool', '/mricron-tool'}
# 25233806 {'/rnbeads-tool', '/fastdma-tool', '/reffreeewas-tool'}
# 27462864 {'/rnbeads-tool', '/bmiq-tool'}
# 28814741 {'/metagen-2-tool', '/rnbeads-tool', '/bmiq-tool'}
# 29259247 {'/rnbeads-tool', '/conumee-tool'}
# 29382824 {'/rnbeads-tool', '/epidish-tool'}
# 29598829 {'/rnbeads-tool', '/methylumi-tool'}
# 29703973 {'/rnbeads-tool', '/methylumi-tool'}
# 29761124 {'/rnbeads-tool', '/lumi-tool'}
# 27347385 {'/ruvm-tool', '/illuminaio-tool'}
# 29240831 {'/ruvm-tool', '/svaseq-tool'}
# 29529020 {'/ruvm-tool', '/vardom-tool'}
# 29374279 {'/david-tool', '/sva-2-tool'}
# 29593239 {'/sva-2-tool', '/lumi-tool'}
# 29593587 {'/sva-2-tool', '/toppgene-suite-tool', '/htqpcr-tool'}
# 29670400 {'/sva-2-tool', '/geo2r-tool'}
# 29695774 {'/sva-2-tool', '/ldsc-tool', '/wikipathways-tool', '/fastx-toolkit-tool'}
# 29755323 {'/sva-2-tool', '/kallisto-tool', '/webgestalt-tool', '/pscan-tool'}
# 29760449 {'/sva-2-tool', '/limma-tool'}
# 29089515 {'/mango-2-tool', '/quin-tool'}
# 26328929 {'/tadkit-tool', '/hibrowse-tool', '/hic-inspector-tool'}
# 28078515 {'/hibrowse-tool', '/hicdat-tool', '/sushi-r-tool', '/diffhic-tool', '/hicpipe-tool', '/hifive-tool'}
# 29503869 {'/simcheck-tool', '/fit-hi-c-tool'}
# 29507293 {'/ceas-tool', '/fit-hi-c-tool'}
# 29632299 {'/snptest-tool', '/eigensoft-tool', '/hugin-tool', '/fit-hi-c-tool'}
# 29765020 {'/colocalization-test-tool', '/hiclib-tool', '/deseq-tool', '/fit-hi-c-tool'}
# 29769521 {'/polyphen-tool', '/fit-hi-c-tool', '/bolt-reml-tool', '/gcta-tool', '/plink-2-tool', '/g-profiler-tool', '/bolt-lmm-tool'}
# 28475897 {'/peakc-tool', '/hic-pro-tool'}
# 28671686 {'/methprimer-tool', '/ice-tool', '/hic-pro-tool'}
# 28922346 {'/sushi-r-tool', '/hic-pro-tool'}
# 29335486 {'/topdom-2-tool', '/hicexplorer-tool'}
# 29374152 {'/homer-tool', '/metilene-tool', '/deeptools-tool', '/hicexplorer-tool'}
# 22941365 {'/ice-tool', '/hiclib-tool'}
# 29094699 {'/higlass-tool', '/hiclib-tool'}
# 29643333 {'/biobase-tool', '/hiclib-tool'}
# 28334773 {'/hicpipe-tool', '/hicplotter-tool', '/topdom-2-tool', '/hubpredictor-tool'}
# 29367853 {'/homer-tool', '/wikipathways-tool'}
# 29371665 {'/homer-tool', '/webgestalt-tool'}
# 29403501 {'/homer-tool', '/pscan-tool'}
# 29760437 {'/methprimer-tool', '/homer-tool', '/star-3-tool'}
# 29765016 {'/bismark-tool', '/gsea-tool', '/edger-tool', '/macs-tool', '/flowcore-tool', '/homer-tool', '/bowtie-tool', '/fastqc-tool'}
# 29765031 {'/deseq2-tool', '/htseq-tool', '/macs-tool', '/homer-tool', '/bowtie-tool', '/chromhmm-tool', '/diffbind-tool', '/chromasig-tool'}
# 29769529 {'/music-2-tool', '/gsea-tool', '/sra-toolkit-tool', '/igv-tool', '/bowtie2-tool', '/macs-tool', '/homer-tool', '/bedtools-tool', '/deeptools-tool', '/samtools-tool'}
# 28885554 {'/topdom-2-tool', '/ice-tool', '/juicer-tool'}
# 29654302 {'/ice-tool', '/chopchop-tool'}
# 29325078 {'/juicer-tool', '/genecbr-tool'}
# 29739942 {'/nmrpipe-tool', '/cns-tool', '/hifive-tool', '/arp-warp-tool'}
# 29048467 {'/hictrans-tool', '/avesim-tool', '/hicnv-tool'}
# 29416042 {'/ic-finder-tool', '/hicrep-tool', '/hic-bench-tool'}
# 28620196 {'/bamtools-tool', '/methylkit-tool'}
# 28713572 {'/bamtools-tool', '/kddn-tool', '/ddn-tool'}
# 29361673 {'/bamtools-tool', '/dnaplotter-tool'}
# 29434199 {'/bamtools-tool', '/sailfish-tool', '/super-seq-tool'}
# 29636006 {'/sga-tool', '/bamtools-tool'}
# 29391530 {'/promethease-tool', '/eager-tool', '/schmutzi-tool'}
# 29717136 {'/megahit-tool', '/megan-tool', '/mapdamage-tool', '/haplogrep-tool', '/vcftools-tool', '/mauve-tool', '/eager-tool'}
# 29746563 {'/eager-tool', '/beast-tool'}
# 29298683 {'/tophat-tool', '/cufflinks-tool', '/picard-tool', '/star-3-tool', '/cytoscape-tool'}
# 29302025 {'/gatk-tool', '/picard-tool', '/bwa-tool', '/annovar-tool'}
# 29304727 {'/gatk-tool', '/bwa-tool', '/picard-tool', '/samtools-tool'}
# 29317692 {'/gatk-tool', '/picard-tool'}
# 29320567 {'/picard-tool', '/edger-tool'}
# 29769526 {'/bwa-tool', '/plink-2-tool', '/picard-tool', '/finemap-tool', '/gatk-tool', '/genome-strip-tool'}
# 29769567 {'/tophat-tool', '/tophat-fusion-tool', '/htseq-tool', '/picard-tool', '/samtools-tool', '/deseq-tool', '/gatk-tool'}
# 29773913 {'/agrigo-tool', '/macs-tool', '/bowtie-tool', '/picard-tool', '/ngs-plot-tool'}
# 19505943 {'/samtools-tview-tool', '/samtools-tool'}
# 21903627 {'/samtools-tool', '/bcftools-tool'}
# 29300782 {'/bwa-tool', '/mapdamage-tool', '/haplogrep-tool', '/leehom-tool', '/samtools-tool'}
# 29301499 {'/esefinder-tool', '/rescue-ese-tool', '/samtools-tool'}
# 29304067 {'/bedtools-tool', '/fastqc-tool', '/samtools-tool', '/hisat-tool', '/deseq2-tool'}
# 29304111 {'/fastqc-tool', '/bwa-tool', '/samtools-tool'}
# 29769555 {'/bwa-tool', '/tide-tool', '/prognos-tool', '/samtools-tool', '/quantasoft-tool', '/gatk-tool', '/signalp-tool'}
# 29777171 {'/bwa-tool', '/subread-tool', '/edger-tool', '/htseq-tool', '/deeptools-tool', '/fastqc-tool', '/samtools-tool', '/flowjo-tool', '/deseq2-tool', '/cytoscape-tool', '/star-3-tool'}
# 28130424 {'/shortread-tool', '/biostrings-tool'}
# 29269494 {'/nondetects-tool', '/shortread-tool'}
# 29432414 {'/quasr-tool', '/shortread-tool'}
# 29552334 {'/sinvict-tool', '/baysic-tool', '/crisp-tool', '/snver-tool', '/poreseq-tool', '/umi-tools-tool', '/deepsnv-tool', '/splinter-tool', '/outlyzer-tool', '/lofreq-tool', '/bamsurgeon-tool', '/mageri-tool', '/ides-tool', '/deepvariant-tool', '/maq-tool', '/ingap-sv-tool'}
# 29568492 {'/predixcan-tool', '/rbind-tool', '/ggbio-tool', '/genomicinteractions-tool'}
# 29497042 {'/bolt-lmm-tool', '/bolt-reml-tool', '/hugin-tool'}
# 26007656 {'/sushi-r-tool', '/repitools-tool'}
# 28000665 {'/easyrnaseq-tool', '/sushi-r-tool'}
# 28635624 {'/chicp-tool', '/insight-tool', '/linsight-tool'}
# 28870212 {'/guessfm-tool', '/chicp-tool'}
# 29304737 {'/improbizer-tool', '/clc-bio-tool'}
# 29317509 {'/clc-bio-tool', '/tm4-tool'}
# 29764461 {'/clc-bio-tool', '/blastx-tool'}
# 29764951 {'/iq-tree-tool', '/clc-bio-tool'}
# 29765033 {'/rast-tool', '/maxbin-tool', '/geneious-tool', '/clc-bio-tool', '/spades-tool', '/fastqc-tool', '/checkm-tool', '/mafft-tool'}
# 29773794 {'/clc-bio-tool', '/toppgene-suite-tool', '/flowjo-tool'}
# 29142137 {'/targetfinder-2-tool', '/hicup-tool'}
# 29666371 {'/deepsea-tool', '/ldsc-tool', '/hicup-tool'}
# 28112728 {'/bbt-tool', '/meerkat-tool'}
# 29298680 {'/orthofinder-tool', '/sortmerna-tool', '/hmmer-tool', '/edger-tool', '/bowtie2-tool', '/fastqc-tool', '/trinity-tool'}
# 29769539 {'/fastqc-tool', '/deseq-tool'}
# 29298676 {'/star-3-tool', '/htseq-tool', '/deseq2-tool'}
# 29311649 {'/david-tool', '/sylamer-tool', '/htseq-tool', '/deseq-tool'}
# 29354030 {'/htseq-tool', '/impala-tool'}
# 29769607 {'/panther-2-tool', '/tophat-tool', '/htseq-tool', '/deseq2-tool'}
# 29773832 {'/gap-tool', '/tophat-tool', '/genomestudio-tool', '/bwa-tool', '/htseq-tool', '/macs-tool', '/cufflinks-tool', '/bedtools-tool', '/limma-tool', '/chromhmm-tool', '/star-3-tool', '/tqn-tool', '/cytoscape-tool'}
# 29642940 {'/kraken-2-tool', '/micra-tool'}
# 29755418 {'/conet-tool', '/explicet-tool', '/micra-tool', '/silvangs-tool'}
# 29755482 {'/winrhizo-tool', '/micra-tool'}
# 29774014 {'/uchime-tool', '/lefse-tool', '/metagenomeseq-tool', '/micra-tool', '/picrust-tool'}
# 29615780 {'/sga-tool', '/snoscan-tool', '/metassembler-tool', '/multiqc-tool'}
# 28934481 {'/phantompeakqualtools-tool', '/hihmm-tool'}
# 29504911 {'/csaw-tool', '/phantompeakqualtools-tool'}
# 29719267 {'/chromhmm-tool', '/phantompeakqualtools-tool'}
# 28886174 {'/psrna-tool', '/uea-srna-toolkit-tool'}
# 29657296 {'/psrna-tool', '/uea-srna-toolkit-tool', '/segemehl-tool'}
# 27677335 {'/basic4cseq-tool', '/r3cseq-tool', '/chance-tool'}
# 28195176 {'/impute-tool', '/r3cseq-tool'}
# 27848966 {'/4cseqpipe-tool', '/4c-ker-tool'}
# 29529026 {'/gat-tool', '/4c-ker-tool', '/pybedtools-tool'}
# 25735743 {'/4cseqpipe-tool', '/rubioseq-tool'}
# 28691095 {'/genometricorr-tool', '/meme-chip-tool', '/4cseqpipe-tool'}
# 27940490 {'/foursig-tool', '/fourcseq-tool'}
# 29042628 {'/cleanadaptors-tool', '/foursig-tool'}
# 29412141 {'/bismark-tool', '/peakc-tool'}
# 29540679 {'/segemehl-tool', '/w4cseq-tool', '/pybedtools-tool'}
# 28287392 {'/danpos-tool', '/nucleoatac-tool', '/centrimo-tool'}
# 28891464 {'/nucleoatac-tool', '/rsat-peak-motifs-tool'}
# 29346761 {'/nucleoatac-tool', '/chromvar-tool'}
# 26229551 {'/templatefilter-tool', '/chromvar-tool'}
# 27980397 {'/metilene-tool', '/sebnif-tool', '/omiras-tool', '/cermit-tool', '/wavcluster-tool', '/qdmr-tool', '/methpipe-tool', '/iseerna-tool', '/matrixreduce-tool', '/dclip-tool'}
# 29065907 {'/methpipe-tool', '/bamutil-tool'}
# 29076502 {'/seqplots-tool', '/methpipe-tool'}
# 29580210 {'/cisgenome-tool', '/bumphunter-tool', '/bsseq-tool', '/methpipe-tool', '/comb-p-tool'}
# 27358654 {'/methylation-plotter-tool', '/methylpipe-tool', '/bsseq-tool', '/gbsa-tool', '/bspat-tool', '/smap-2-tool'}
# 29653584 {'/bismark-tool', '/circlize-tool', '/bsseq-tool', '/bisearch-tool', '/rmats-tool', '/methylkit-tool', '/fntm-tool'}
# 29765549 {'/methprimer-tool', '/bisearch-tool'}
# 29769563 {'/blastn-tool', '/primer3-tool', '/bisearch-tool'}
# 27785156 {'/saap-rrbs-tool', '/epidesigner-tool'}
# 29563500 {'/brb-arraytools-tool', '/epidesigner-tool'}
# 29158416 {'/kismeth-tool', '/meerkat-tool'}
# 28720816 {'/methprimer-tool', '/gsdraw-tool'}
# 24252160 {'/crac-tool', '/cram-tool', '/dsrc-tool'}
# 27075447 {'/deez-tool', '/gqt-tool', '/cram-tool', '/codex-2-tool'}
# 28369191 {'/irap-tool', '/bioservices-tool', '/cram-tool'}
# 28531267 {'/cram-tool', '/bamutil-tool'}
# 28115622 {'/gqt-tool', '/kggseq-tool'}
# 26243131 {'/topsi-tool', '/path-encoding-tool'}
# 28520864 {'/mmsat-2-tool', '/chemtreemap-tool', '/msclust-tool', '/simat-tool', '/aplcms-tool', '/metfusion-tool', '/sirius-tool', '/meltdb-tool', '/splash-tool', '/metab-tool', '/normalyzer-tool', '/ransy-ramsy-tool', '/mastr-ms-tool', '/metabolitedetector-tool', '/lipidqa-tool', '/msprep-tool', '/mpea-tool', '/limsa-tool', '/metpp-tool', '/ptw-tool', '/probmetab-tool', '/marvis-suite-tool', '/incromap-tool', '/binche-tool', '/metaquant-tool', '/ipo-tool', '/massypup-tool', '/metabnet-tool', '/exims-tool', '/metabolyzer-tool', '/iis-tool', '/lda-tool', '/cts-tool', '/masstrix-tool', '/decoms2-tool', '/metmsline-tool', '/paintomics-tool', '/metap-server-tool', '/ict-tool', '/targetsearch-tool', '/met-idea-tool', '/mettailor-tool', '/batmass-tool', '/metaboqc-tool', '/openmsi-tool', '/adap-gc-tool', '/lipid-pro-tool', '/fragpred-tool', '/lobstahs-tool', '/xmsanalyzer-tool', '/specktackle-tool', '/mait-tool', '/mrmprobs-tool', '/valid-tool', '/mzmatch-iso-tool', '/metcirc-tool', '/path-encoding-tool'}
# 25250827 {'/omicssimla-tool', '/seqsimla-tool'}
# 25541952 {'/omicssimla-tool', '/seqsimla-tool', '/ffbskat-tool'}
# 29358944 {'/omicssimla-tool', '/cosi-tool'}
# 28946896 {'/seqminer-tool', '/epiexplorer-tool'}
# 26463000 {'/savant-tool', '/epiviz-tool', '/cnamet-tool', '/lcb-tool'}
# 29699480 {'/jbrowse-tool', '/epiviz-tool'}
# 30135734 {'/epiviz-tool', '/pseui-tool'}
# 28814981 {'/methylation-plotter-tool', '/bspat-tool', '/easyroc-tool'}
# 29444933 {'/pipipes-tool', '/seqmonk-tool'}
# 29615716 {'/goplot-tool', '/seqmonk-tool'}
# 29618374 {'/bsseq-tool', '/seqmonk-tool', '/repenrich-tool'}
# 29670118 {'/rseqc-tool', '/cistrome-tool', '/seqmonk-tool'}
# 29675472 {'/cummerbund-tool', '/seqmonk-tool'}
# 26184873 {'/dss-single-tool', '/gbsa-tool'}
# 29225348 {'/dss-single-tool', '/spamo-tool'}
# 29514626 {'/dss-single-tool', '/metilene-tool', '/bsseq-tool', '/moabs-tool', '/methylkit-tool'}
# 28854222 {'/tetoolkit-tool', '/methylkit-tool'}
# 28978943 {'/bis-snp-tool', '/methylkit-tool', '/bsseq-tool'}
# 29653520 {'/bismark-tool', '/methylkit-tool'}
# 29686887 {'/bismark-tool', '/webgestalt-tool', '/genomation-tool', '/methylkit-tool', '/sidr-2-tool'}
# 28955039 {'/chromasig-tool', '/metilene-tool', '/epicseg-tool'}
# 27428748 {'/qdmr-tool', '/moabs-tool'}
# 29394393 {'/pscan-tool', '/bseqc-tool', '/moabs-tool', '/pscanchip-tool'}
# 28693600 {'/lola-tool', '/reffreeewas-tool', '/eforge-tool'}
# 29097680 {'/missmethyl-tool', '/eforge-tool'}
# 29109506 {'/shinymethyl-tool', '/eforge-tool'}
# 29740313 {'/fuma-2-tool', '/eforge-tool'}
# 29046582 {'/bs-snper-tool', '/fast-lmm-ewasher-tool', '/reffreeewas-tool'}
# 29321239 {'/refactor-tool', '/prottest-tool', '/seaview-tool', '/blobology-tool'}
# 29521624 {'/refactor-tool', '/tnseq-tool'}
# 29513726 {'/bmiq-tool', '/watermelon-tool', '/reffreeewas-tool'}
# 29293496 {'/bedtools-tool', '/ucsc-liftover-tool', '/rnacompete-tool', '/tepic-tool'}
# 29321036 {'/bedtools-tool', '/csaw-tool'}
# 29337314 {'/rnammer-tool', '/hmmer-tool', '/bedtools-tool', '/trimal-tool', '/checkm-tool'}
# 29739336 {'/circexplorer-tool', '/find-circ-tool', '/rnahybrid-tool', '/bedtools-tool', '/ciri-tool'}
# 29760376 {'/david-tool', '/bedtools-tool', '/chipseeker-tool'}
# 22383036 {'/cufflinks-tool', '/tuxedo-tool', '/cummerbund-tool'}
# 29290775 {'/tophat-tool', '/cbioportal-tool', '/complex-heatmaps-tool', '/bowtie2-tool', '/macs-tool', '/cufflinks-tool', '/beta-tool'}
# 29298675 {'/cufflinks-tool', '/tophat-tool', '/mapman-tool'}
# 29301488 {'/blastx-tool', '/cufflinks-tool', '/ontologizer-tool', '/astalavista-tool', '/blast2go-tool'}
# 29301509 {'/tophat-tool', '/igv-tool', '/fastx-toolkit-tool', '/cufflinks-tool', '/bowtie-tool'}
# 29764374 {'/cufflinks-tool', '/targetscan-tool'}
# 29765017 {'/cufflinks-tool', '/gatk-tool'}
# 29769535 {'/polyphen-tool', '/cadd-tool', '/fathmm-tool', '/igv-tool', '/cufflinks-tool', '/rna2dnalign-tool', '/seattleseq-annotation-tool', '/tuxedo-tool'}
# 29769602 {'/kallisto-tool', '/edger-tool', '/miso-tool', '/cufflinks-tool', '/rmats-tool', '/rsem-tool', '/star-3-tool', '/majiq-tool'}
# 26106402 {'/networkanalyzer-tool', '/rackj-tool'}
# 29535339 {'/erange-tool', '/rackj-tool'}
# 29636446 {'/sweepfinder-tool', '/vcf-kit-tool'}
# 29354142 {'/vcftools-tool', '/bwa-tool', '/plink-tool'}
# 29370772 {'/vcftools-tool', '/regioner-tool', '/genemania-tool'}
# 29420653 {'/cadd-tool', '/plink-tool', '/vcftools-tool', '/vep-tool', '/eigensoft-tool'}
# 29703145 {'/partitionfinder-tool', '/freebayes-tool', '/vcftools-tool', '/dnasp-tool', '/bcftools-tool', '/popart-tool'}
# 29712833 {'/vcftools-tool', '/snprelate-tool'}
# 29720620 {'/vcftools-tool', '/numpy-tool'}
# 29739910 {'/jalview-tool', '/angsd-tool', '/vcftools-tool', '/snprelate-tool', '/adegenet-tool'}
# 27246599 {'/aneufinder-tool', '/bamutil-tool'}
# 28683715 {'/epigbs-tool', '/bamutil-tool'}
# 29317634 {'/abra-tool', '/bamutil-tool'}
# 29522538 {'/baseplayer-tool', '/oncodrivefml-tool', '/bamutil-tool'}
# 28081260 {'/trf-tool', '/gendb-tool', '/biostrings-tool'}
# 29360959 {'/lofreq-tool', '/biostrings-tool'}
# 29703137 {'/gsds-tool', '/circoletto-tool', '/biostrings-tool'}
# 29728068 {'/genedata-expressionist-tool', '/trnascan-se-tool', '/meme-suite-tool', '/cistrome-tool', '/biostrings-tool', '/aragorn-tool', '/tomtom-tool'}
# 29742107 {'/tm4-tool', '/biostrings-tool'}
# 29761785 {'/efi-est-tool', '/biostrings-tool'}
# 22594911 {'/quantnorm-tool', '/gff-utilities-tool', '/jorca-tool'}
# 25741336 {'/velvet-tool', '/bcftools-tool'}
# 29700146 {'/bcftools-tool', '/freebayes-tool'}
# 29712900 {'/mixomics-tool', '/bcftools-tool', '/phangorn-tool'}
# 29720102 {'/bic-seq-tool', '/bcftools-tool', '/genalex-tool'}
# 29748622 {'/platypus-tool', '/annovar-tool', '/somaticsignatures-tool', '/aceseq-tool', '/cnvkit-tool', '/bcftools-tool'}
# 29330436 {'/gatk-tool', '/misa-tool', '/blast2go-tool', '/noiseq-tool'}
# 29335443 {'/gatk-tool', '/ascat-tool'}
# 28790205 {'/baps-tool', '/quake-tool'}
# 29298673 {'/signalp-tool', '/quake-tool', '/psort-tool', '/phobius-tool'}
# 29343235 {'/symap-tool', '/genomescope-tool', '/metassembler-tool', '/orthovenn-tool', '/quake-tool', '/jellyfish-tool'}
# 29339748 {'/macs-tool', '/deeptools-tool', '/bwtool-tool', '/danpos-tool'}
# 29373953 {'/deeptools-tool', '/agrigo-tool', '/danpos-tool', '/ngs-plot-tool'}
# 29423272 {'/deeptools-tool', '/gsea-tool'}
# 29719263 {'/igb-tool', '/deeptools-tool', '/ngs-plot-tool'}
# 29563587 {'/tcga-assembler-tool', '/poretools-tool'}
# 29760718 {'/poretools-tool', '/nanopolish-tool'}
# 29298661 {'/seqprep-tool', '/kaas-tool', '/rsem-tool', '/blast2go-tool', '/trinity-tool'}
# 29313259 {'/rsem-tool', '/blastx-tool'}
# 29320569 {'/estscan-tool', '/blastx-tool', '/goseq-tool', '/rsem-tool', '/deseq-tool'}
# 29324804 {'/rsem-tool', '/proloc-tool', '/bowtie-tool', '/tm4-tool'}
# 29324867 {'/wego-tool', '/rsem-tool', '/hisat-tool', '/noiseq-tool'}
# 29760388 {'/rsem-tool', '/netmhc-tool'}
# 29765039 {'/rsem-tool', '/treeview-tool', '/cbioportal-tool'}
# 29777108 {'/david-tool', '/ease-tool', '/gsea-tool', '/rsem-tool', '/flowjo-tool', '/cytoscape-tool', '/cellprofiler-tool', '/cibersort-tool'}
# 29785177 {'/seqprep-tool', '/interpro-tool', '/blastx-tool', '/primer-premier-tool', '/rsem-tool', '/blast2go-tool', '/primer3-tool', '/trinity-tool'}
# 27457073 {'/japsa-tool', '/npreader-tool'}
# 28218240 {'/japsa-tool', '/npreader-tool'}
# 27097556 {'/shore-tool', '/pybedtools-tool'}
# 29463659 {'/braker-tool', '/genomescope-tool', '/pybedtools-tool', '/assemblytics-tool', '/codingquarry-tool', '/repet-tool'}
# 29559621 {'/parclip-suite-tool', '/flexbar-tool', '/jamm-tool', '/graphprot-tool', '/pybedtools-tool', '/paralyzer-tool'}
# 29695722 {'/biopython-tool', '/percolator-tool', '/pybedtools-tool'}
# 28487883 {'/sambamba-tool', '/platypus-tool'}
# 28837078 {'/sambamba-tool', '/genome-strip-tool', '/speedseq-tool'}
# 29300972 {'/sambamba-tool', '/exomiser-tool'}
# 29422656 {'/sambamba-tool', '/complex-heatmaps-tool', '/platypus-tool'}
# 29632298 {'/sambamba-tool', '/bs-seeker-tool', '/seqinr-tool'}
# 28732548 {'/assembly-converter-tool', '/bs-seeker-tool', '/bwtool-tool'}
# 29317769 {'/sra-toolkit-tool', '/trinity-tool', '/node-dating-tool'}
# 29661148 {'/sra-toolkit-tool', '/cadd-tool'}
# 29764375 {'/sra-toolkit-tool', '/kaas-tool', '/velvet-tool', '/fastx-toolkit-tool', '/stm-tool', '/cd-hit-tool'}
# 22573177 {'/archtex-tool', '/archalign-tool'}
# 28439269 {'/archtex-tool', '/pscanchip-tool'}
# 25188499 {'/sga-tool', '/jvarkit-tool', '/popoolation-te-tool', '/amos-tool'}
# 28099457 {'/xstk-tool', '/slicembler-tool'}
# 29554948 {'/xstk-tool', '/metaphlan-tool', '/panphlan-tool', '/metabat-tool', '/super-focus-tool', '/concoct-tool', '/metameta-tool'}
# 29297465 {'/igv-tool', '/bowtie2-tool', '/fastx-toolkit-tool'}
# 29716635 {'/piranha-tool', '/parclip-suite-tool', '/fast-iclip-tool', '/cermit-tool', '/wavcluster-tool', '/fastx-toolkit-tool', '/paralyzer-tool', '/soap-tool', '/pyicos-tool', '/clipper-2-tool'}
# 29755354 {'/velvet-tool', '/fastx-toolkit-tool'}
# 27141848 {'/ngs-toolbox-tool', '/trackster-tool'}
# 25608970 {'/cel-seq-tool', '/ngsutils-tool'}
# 27897201 {'/iseerna-tool', '/ngsutils-tool'}
# 29743957 {'/tetoolkit-tool', '/retroseq-tool', '/ngsutils-tool', '/t-lex-tool'}
# 29760383 {'/annovar-tool', '/igv-tool', '/bowtie-tool', '/pyclone-tool', '/rescue-ese-tool'}
# 29300744 {'/edger-tool', '/tophat-tool', '/agrigo-tool', '/bowtie2-tool'}
# 29769661 {'/edger-tool', '/bowtie2-tool'}
# 27803181 {'/sppider-tool', '/rsf-tool'}
# 29593268 {'/rsf-tool', '/mapix-tool'}
# 29141580 {'/annotatr-tool', '/togows-tool'}
# 29587824 {'/centrimo-tool', '/cbioportal-tool', '/chipseeker-tool', '/saap-rrbs-tool'}
# 29419727 {'/bismark-tool', '/wfmm-tool'}
# 28925810 {'/bs-seeker-tool', '/bsseq-tool'}
# 29333247 {'/bs-seeker-tool', '/annotationdbi-tool'}
# 29556342 {'/virema-tool', '/cgmaptools-tool'}
# 23175756 {'/enmix-tool', '/bmiq-tool'}
# 23631413 {'/enmix-tool', '/watermelon-tool'}
# 27869616 {'/umap-2-tool', '/bseqc-tool'}
# 28859663 {'/bseqc-tool', '/danpos-tool'}
# 23034175 {'/bsmooth-align-tool', '/bsseq-tool'}
# 25278959 {'/cohcap-tool', '/ima-tool'}
# 28638988 {'/last-tool', '/nanosv-tool', '/npreader-tool', '/nanopolish-tool'}
# 28912319 {'/sealer-tool', '/nanopolish-tool'}
# 29321680 {'/circlator-tool', '/nanopolish-tool'}
# 29614013 {'/racon-tool', '/nanopolish-tool'}
# 29700138 {'/reapr-tool', '/velvet-tool', '/nanopolish-tool'}
# 29700153 {'/racon-tool', '/nanopolish-tool'}
# 28196958 {'/igb-tool', '/segemehl-tool', '/reademption-tool', '/tsspredator-tool'}
# 28394930 {'/segemehl-tool', '/reademption-tool'}
# 28787591 {'/seqplots-tool', '/eisa-2-tool', '/segemehl-tool'}
# 28819222 {'/segemehl-tool', '/ciri-tool'}
# 29487214 {'/panseq-tool', '/segemehl-tool'}
# 29592812 {'/dapars-tool', '/snakemake-tool', '/segemehl-tool', '/kapac-tool', '/paqr-tool'}
# 29431738 {'/lumpy-tool', '/cat-4-tool', '/svtyper-tool', '/marginalign-tool', '/signalalign-tool', '/assemblytics-tool', '/whatshap-tool'}
# 2231712 {'/blastx-tool', '/blastn-tool'}
# 24259429 {'/tblastx-tool', '/blastn-tool', '/blastp-tool'}
# 29357911 {'/cegma-tool', '/blastn-tool', '/hmmer-tool'}
# 29390076 {'/trnamodpred-tool', '/blastn-tool'}
# 29459752 {'/weblogo-tool', '/kallisto-tool', '/blastn-tool'}
# 29669586 {'/clustal-w-tool', '/blastn-tool'}
# 29773797 {'/tophat-tool', '/antismash-tool', '/augustus-tool', '/blastn-tool', '/deseq-tool'}
# 29774238 {'/discovar-tool', '/muscle-tool', '/blastn-tool', '/geneious-tool'}
# 9254694 {'/blastx-tool', '/hhsuite-tool', '/blastn-tool', '/blastp-tool'}
# 29188023 {'/orthofinder-tool', '/busco-tool', '/genemark-tool', '/blastp-tool'}
# 29293601 {'/megahit-tool', '/blastp-tool', '/fraggenescan-tool', '/muscle-tool', '/mega-tool', '/cd-hit-tool'}
# 29326199 {'/genemark-tool', '/glimmer-tool', '/blastp-tool'}
# 29769532 {'/clustal-w-tool', '/blastp-tool'}
# 29769695 {'/plasmidfinder-tool', '/interpro-tool', '/rast-tool', '/blastp-tool', '/splitstree-tool', '/mummer-tool'}
# 29774236 {'/hmmer-tool', '/blastp-tool', '/ggplot2-tool', '/geneious-tool', '/signalp-tool', '/mafft-tool'}
# 29570745 {'/jbrowse-tool', '/genewise-tool'}
# 29635287 {'/pasa-tool', '/genewise-tool'}
# 29661185 {'/trimal-tool', '/platanus-tool', '/notung-tool', '/genewise-tool'}
# 29688346 {'/lastz-tool', '/genewise-tool', '/fragscaff-tool'}
# 29691383 {'/glimmerhmm-tool', '/mcscanx-tool', '/geneid-tool', '/genewise-tool', '/pseudopipe-tool', '/cafe-2-tool', '/mitofy-tool', '/ogdraw-tool', '/pasa-tool'}
# 22198341 {'/hhsuite-tool', '/hhblits-tool'}
# 28398238 {'/coils-pcoils-tool', '/hhsuite-tool'}
# 29131623 {'/alignme-tool', '/hhsuite-tool'}
# 29712973 {'/panther-2-tool', '/mentha-tool', '/hhsuite-tool'}
# 29732410 {'/prottest-tool', '/hhsuite-tool'}
# 29755369 {'/swiss-model-tool', '/hhsuite-tool'}
# 29764421 {'/sitehound-tool', '/hhsuite-tool', '/qmean-tool', '/g-mmpbsa-tool', '/swiss-model-tool', '/beast-tool'}
# 25943547 {'/jackhmmer-tool', '/hmmer-tool'}
# 29335005 {'/megahit-tool', '/hmmer-tool', '/prodigal-tool', '/cd-hit-tool', '/quast-tool'}
# 29743013 {'/mcscanx-tool', '/hmmer-tool', '/paml-tool', '/hemi-tool', '/gsds-tool'}
# 29743490 {'/hmmer-tool', '/kaas-tool', '/tmhmm-tool', '/ruvseq-tool', '/cd-hit-tool'}
# 29747580 {'/orthofinder-tool', '/antismash-tool', '/genemark-tool', '/cegma-tool', '/hmmer-tool', '/dbcan-tool', '/tmhmm-tool', '/signalp-tool', '/blast2go-tool', '/cafe-2-tool', '/soap-tool', '/soapdenovo-tool'}
# 29751792 {'/modeller-tool', '/memoir-tool', '/jalview-tool', '/hmmer-tool', '/geneid-tool', '/foldx-tool'}
# 26100409 {'/jackhmmer-tool', '/multi-harmony-tool'}
# 29198957 {'/jackhmmer-tool', '/psicov-tool', '/raptorx-tool', '/dali-tool', '/evmutation-tool'}
# 29263101 {'/jackhmmer-tool', '/mpi-bioinformatics-toolkit-tool'}
# 29471489 {'/jackhmmer-tool', '/sasref-tool', '/dammin-tool'}
# 29540682 {'/jackhmmer-tool', '/topcons-tool'}
# 29670199 {'/jackhmmer-tool', '/tm-align-tool'}
# 27934875 {'/m4t-tool', '/3drefine-tool'}
# 29361909 {'/robetta-tool', '/m4t-tool', '/vaast-tool', '/pcons-net-tool'}
# 29348418 {'/2l-pirna-tool', '/pse-in-one-tool', '/protdec-ltr-tool', '/predisi-tool'}
# 29364862 {'/ber-tool', '/staden-tool'}
# 28327945 {'/cloudman-tool', '/maftools-tool'}
# 29674644 {'/seqprep-tool', '/deconstructsigs-tool', '/crossmap-tool', '/maftools-tool'}
# 29291727 {'/snpsift-tool', '/prokka-tool', '/popgenome-tool', '/roary-tool', '/circos-tool', '/spades-tool', '/cisa-tool', '/mafft-tool'}
# 29510741 {'/snpsift-tool', '/i-mutant-tool'}
# 29515596 {'/circos-tool', '/cnvnator-tool', '/snpsift-tool'}
# 29723202 {'/snpsift-tool', '/dendroscope-tool', '/freebayes-tool'}
# 29739316 {'/breakdancer-tool', '/snpsift-tool', '/cnvnator-tool'}
# 29587630 {'/epigbs-tool', '/fastaptamer-tool'}
# 29233090 {'/p3bsseq-tool', '/manorm-tool'}
# 28394351 {'/quasr-tool', '/v-fat-tool'}
# 29106373 {'/quasr-tool', '/eisa-2-tool'}
# 27964752 {'/mrcanavar-tool', '/appris-tool', '/rubioseq-tool'}
# 29764360 {'/speid-tool', '/gkmsvm-tool', '/im-pet-tool', '/chia-pet-tool', '/deepsea-tool', '/chromhmm-tool', '/ep2vec-tool', '/targetfinder-2-tool', '/segway-tool', '/centrimo-tool'}
# 29309647 {'/piranha-tool', '/ceas-tool', '/diffbind-tool', '/pscanchip-tool', '/mango-2-tool', '/trap-3-tool'}
# 28911122 {'/chip-nexus-tool', '/cexor-tool', '/peakzilla-tool', '/q-nexus-tool'}
# 27798116 {'/chip-nexus-tool', '/hint-2-tool'}
# 28811569 {'/chip-nexus-tool', '/dreg-tool'}
# 27129152 {'/copywriter-tool', '/dfilter-tool'}
# 29028826 {'/stamp-tool', '/dfilter-tool', '/chance-tool'}
# 29396493 {'/seqminer-tool', '/ceas-tool', '/dfilter-tool'}
# 29385521 {'/peakxus-tool', '/spamo-tool', '/peakzilla-tool'}
# 28395144 {'/chromhmm-tool', '/meme-chip-tool', '/peakzilla-tool'}
# 27497616 {'/matrixreduce-tool', '/amadeus-tool', '/alignace-tool'}
# 28407733 {'/ncbi-genome-remapping-service-tool', '/ceas-tool'}
# 29100329 {'/spamo-tool', '/ceas-tool'}
# 28225770 {'/cisgenome-tool', '/finemap-tool'}
# 29309682 {'/igb-tool', '/cisgenome-tool'}
# 28209164 {'/cistrome-tool', '/opossum-tool'}
# 28387316 {'/cistrome-tool', '/manorm-tool'}
# 29749381 {'/cellprofiler-tool', '/cistrome-tool', '/treeview-tool', '/galaxy-tool'}
# 20074339 {'/mdscan-tool', '/alignace-tool'}
# 21931761 {'/weeder-tool', '/mdscan-tool', '/trawler-tool'}
# 22416066 {'/mdscan-tool', '/alignace-tool'}
# 25657638 {'/bobro-tool', '/mdscan-tool', '/rvista-tool', '/alignace-tool'}
# 27507169 {'/bobro-tool', '/microfootprinter-tool', '/mdscan-tool', '/alignace-tool'}
# 27832791 {'/mdscan-tool', '/melina-ii-tool'}
# 25521328 {'/mm-chip-tool', '/pavis-tool'}
# 25765478 {'/mm-chip-tool', '/beta-tool'}
# 29378633 {'/alignerboost-tool', '/noiseq-tool'}
# 29568413 {'/alignerboost-tool', '/cora-tool'}
# 29323241 {'/star-3-tool', '/qualimap-tool'}
# 29636463 {'/easyfig-tool', '/dnaplotter-tool', '/plasmidspades-tool', '/circlator-tool', '/trf-tool', '/roary-tool', '/qualimap-tool'}
# 29700154 {'/antismash-tool', '/qualimap-tool'}
# 29309643 {'/rseqc-tool', '/crossmap-tool'}
# 29363429 {'/rseqc-tool', '/wikipathways-tool', '/hint-2-tool', '/pep-tool'}
# 29559983 {'/rseqc-tool', '/cpc-tool'}
# 29664468 {'/rseqc-tool', '/svaseq-tool', '/mrin-tool'}
# 28335003 {'/alleleseq-tool', '/weeder-tool', '/funseq-tool'}
# 28717173 {'/alleleseq-tool', '/ncbi-genome-remapping-service-tool'}
# 28806168 {'/cpc-tool', '/allelome-pro-tool'}
# 29275859 {'/limma-tool', '/genomestudio-tool', '/lumi-tool', '/fastgenomics-tool'}
# 29287311 {'/bumphunter-tool', '/lumi-tool', '/missmethyl-tool'}
# 29507296 {'/genomestudio-tool', '/lumi-tool'}
# 29511161 {'/genomestudio-tool', '/lumi-tool'}
# 29554922 {'/lumi-tool', '/mageck-tool'}
# 24485148 {'/methylumi-tool', '/cpgassoc-tool'}
# 27517910 {'/bmiq-tool', '/methylumi-tool'}
# 29587883 {'/coloc-tool', '/watermelon-tool', '/methylumi-tool'}
# 29740475 {'/watermelon-tool', '/methylumi-tool'}
# 28499350 {'/chromasig-tool', '/hmmseg-tool'}
# 28515787 {'/chromasig-tool', '/epicseg-tool'}
# 28700586 {'/segway-tool', '/chromhmm-tool'}
# 29712937 {'/chromhmm-tool', '/cpgassoc-tool'}
# 29425248 {'/gpcrhmm-tool', '/dnn-hmm-tool'}
# 29179726 {'/genomation-tool', '/segway-tool', '/tapdance-tool'}
# 28819152 {'/spectacle-tool', '/meme-chip-tool', '/centrimo-tool'}
# 15980535 {'/creme-tool', '/ecr-browser-tool'}
# 20360861 {'/gibbsmodule-tool', '/matcompare-tool'}
# 17241466 {'/mcast-tool', '/mscan-tool'}
# 28497059 {'/cluster-buster-tool', '/mscan-tool'}
# 10592223 {'/utrscan-tool', '/utrblast-tool'}
# 11752330 {'/utrscan-tool', '/utrblast-tool'}
# 15608165 {'/utrscan-tool', '/utrblast-tool'}
# 19880380 {'/utrscan-tool', '/utrblast-tool'}
# 28272408 {'/utrscan-tool', '/utrblast-tool', '/nomad-ref-tool'}
# 28276452 {'/utrscan-tool', '/weeder-tool'}
# 28676128 {'/utrscan-tool', '/nomad-ref-tool'}
# 28955198 {'/utrscan-tool', '/dapars-tool'}
# 9847176 {'/utrscan-tool', '/utrblast-tool'}
# 27169896 {'/music-2-tool', '/chipsim-tool'}
# 29579120 {'/f-seq-tool', '/chipseeker-tool'}
# 29760402 {'/chipseeker-tool', '/cager-tool'}
# 28653622 {'/genomation-tool', '/danpos-tool'}
# 29223978 {'/ngs-plot-tool', '/pavis-tool'}
# 29736258 {'/seqminer-tool', '/pavis-tool'}
# 27582050 {'/rsat-peak-motifs-tool', '/gat-tool'}
# 28854641 {'/stamp-tool', '/rsat-peak-motifs-tool', '/cluster-buster-tool', '/i-cistarget-tool', '/clover-tool'}
# 29017520 {'/musera-tool', '/rsat-peak-motifs-tool', '/gat-tool', '/pscanchip-tool'}
# 29520289 {'/wego-tool', '/estscan-tool', '/noiseq-tool'}
# 29681917 {'/venny-tool', '/clustvis-tool', '/noiseq-tool'}
# 29695303 {'/diffbind-tool', '/noiseq-tool'}
# 29728590 {'/prottest-tool', '/kallisto-tool', '/noiseq-tool'}
# 29432416 {'/seqminer-tool', '/centrimo-tool'}
# 29581148 {'/fimo-tool', '/centrimo-tool'}
# 29642851 {'/notung-tool', '/centrimo-tool'}
# 16845028 {'/meme-suite-tool', '/meme-tool'}
# 19458158 {'/meme-suite-tool', '/tomtom-tool'}
# 29325123 {'/meme-suite-tool', '/seqinr-tool', '/phast-tool'}
# 29479499 {'/meme-suite-tool', '/meme-tool', '/gomo-tool', '/tomtom-tool'}
# 29497429 {'/meme-suite-tool', '/clustal-w-tool'}
# 29728569 {'/weblogo-tool', '/meme-suite-tool', '/tm4-tool', '/psrnatarget-tool'}
# 29739980 {'/interpro-tool', '/mfold-tool', '/psrnatarget-tool', '/meme-suite-tool', '/protparam-tool', '/dnasp-tool'}
# 29769381 {'/meme-suite-tool', '/cellstar-tool', '/meme-tool'}
# 28881989 {'/gkmsvm-tool', '/motifrg-tool'}
# 26282110 {'/multigps-tool', '/hmmseg-tool'}
# 26764273 {'/qchipat-tool', '/multigps-tool', '/grohmm-tool'}
# 28704389 {'/multigps-tool', '/centipede-tool', '/piq-tool'}
# 27295177 {'/signalspider-tool', '/ccat-tool', '/peakseq-tool'}
# 29670105 {'/balony-tool', '/danpos-tool'}
# 29738565 {'/seqplots-tool', '/diffbind-tool'}
# 27507714 {'/centdist-tool', '/manorm-tool'}
# 29700302 {'/meme-chip-tool', '/manorm-tool'}
# 25033408 {'/kmer-svm-tool', '/gkmsvm-tool'}
# 28881969 {'/kmer-svm-tool', '/gkmsvm-tool'}
# 29219068 {'/kmer-svm-tool', '/gkmsvm-tool'}
# 29618048 {'/deltasvm-tool', '/gkmsvm-tool'}
# 26562774 {'/cluster-buster-tool', '/i-cistarget-tool'}
# 27181057 {'/mirdup-tool', '/ienhancer-2l-tool', '/mirduplexsvm-tool', '/mirmat-tool'}
# 28874753 {'/im-pet-tool', '/mutascope-tool'}
# 29059683 {'/im-pet-tool', '/gengen-tool'}
# 29453388 {'/im-pet-tool', '/gwava-tool', '/funseq-tool'}
# 27030570 {'/irspot-psednc-tool', '/kmer-svm-tool'}
# 28361702 {'/deltasvm-tool', '/kmer-svm-tool'}
# 29267279 {'/sangerseqr-tool', '/kmer-svm-tool'}
# 27646134 {'/mhap-tool', '/lqs-tool'}
# 26006009 {'/mhap-tool', '/pbcr-tool'}
# 29244003 {'/pbcr-tool', '/gmcloser-tool'}
# 25364804 {'/sga-tool', '/glimmerhmm-tool'}
# 29483539 {'/sga-tool', '/idba-ud-tool', '/gview-tool'}
# 29694397 {'/subseq-tool', '/sga-tool', '/mitos-tool', '/mapdamage-tool', '/clc-sequence-viewer-tool', '/paleomix-tool'}
# 29483511 {'/vep-tool', '/agrigo-tool'}
# 29554982 {'/agrigo-tool', '/ea-utils-tool'}
# 29748645 {'/agrigo-tool', '/cd-hit-tool'}
# 29765069 {'/trinity-tool', '/agrigo-tool'}
# 29329292 {'/sortmerna-tool', '/kraken-2-tool', '/orthovenn-tool', '/blast2go-tool', '/busco-tool', '/cd-hit-tool', '/detonate-tool'}
# 29739322 {'/interpro-tool', '/tm4-tool', '/blast2go-tool'}
# 29739966 {'/primer-premier-tool', '/blast2go-tool'}
# 29304732 {'/blastx-tool', '/trf-tool', '/circos-tool', '/mummer-tool', '/mega-tool'}
# 29330451 {'/blastx-tool', '/splitstree-tool', '/mafft-tool'}
# 29764372 {'/phangorn-tool', '/genemark-tool', '/jmodeltest-tool', '/blastx-tool', '/qiime-tool', '/gblocks-tool', '/phyml-tool', '/densitree-tool', '/mummer-tool', '/busco-tool', '/mafft-tool'}
# 29344280 {'/david-tool', '/venny-tool', '/targetscan-tool'}
# 29362391 {'/david-tool', '/regioner-tool', '/speedseq-tool', '/lumpy-tool'}
# 29363420 {'/david-tool', '/find-circ-tool'}
# 29764444 {'/david-tool', '/cbioportal-tool'}
# 29769534 {'/david-tool', '/targetscan-tool', '/ggplot2-tool', '/clusterprofiler-tool', '/cytoscape-tool'}
# 29703930 {'/vep-tool', '/varscan-tool', '/oligocalc-tool', '/genemania-tool'}
# 29743561 {'/gsea-tool', '/genemania-tool'}
# 29760565 {'/icsnpathway-tool', '/genemania-tool'}
# 29765251 {'/snpinfo-tool', '/esefinder-tool', '/merav-tool', '/rescue-ese-tool', '/genemania-tool'}
# 29337929 {'/webgestalt-tool', '/mirdeep-tool'}
# 29558872 {'/cbioportal-tool', '/webgestalt-tool'}
# 29728556 {'/gepia-tool', '/tanric-tool', '/webgestalt-tool'}
# 29739397 {'/venny-tool', '/webgestalt-tool'}
# 17683565 {'/gram-tool', '/mofa-tool'}
# 18426580 {'/gram-tool', '/clusterjudge-tool'}
# 28991892 {'/scenic-tool', '/rcistarget-tool', '/aucell-tool'}
# 25504152 {'/rnapromo-tool', '/drimust-tool', '/memeris-tool', '/rbpmotif-tool'}
# 28245811 {'/drimust-tool', '/graphprot-tool', '/matrixreduce-tool', '/cluster-buster-tool', '/ideep-tool', '/deepnet-rbp-tool'}
# 27257071 {'/genometricorr-tool', '/lola-tool', '/methylaction-tool'}
# 28082391 {'/lola-tool', '/coloweb-tool'}
# 28549158 {'/agplus-tool', '/clusterprofiler-tool'}
# 27863251 {'/sqtlseeker-tool', '/chip-center-tool'}
# 29618526 {'/scvis-tool', '/deepchem-tool', '/speid-tool', '/orphelia-tool', '/dncon-tool', '/pconsc-tool', '/fraggenescan-tool', '/deepsea-tool', '/deeppicker-tool', '/deepchrome-tool', '/deepvariant-tool', '/netmhc-tool', '/raptorx-contact-prediction-tool'}
# 26575220 {'/gat-tool', '/epigram-tool'}
# 22928635 {'/matcompare-tool', '/bamm-motif-tool'}
# 15319260 {'/matcompare-tool', '/cread-tool'}
# 19767611 {'/dme-tool', '/matcompare-tool'}
# 29659575 {'/insilicospectro-tool', '/matcompare-tool', '/cread-tool'}
# 29312363 {'/rsat-tool', '/stamp-tool'}
# 29659815 {'/rsat-tool', '/tomtom-tool'}
# 28931820 {'/praline-tool', '/stamp-tool'}
# 29365169 {'/seqprep-tool', '/trf-tool', '/tomtom-tool'}
# 17559637 {'/mofa-tool', '/alignace-tool'}
# 29330469 {'/opossum-tool', '/usearch-tool', '/meme-tool'}
# 19534778 {'/weeder-tool', '/patscan-tool'}
# 25517099 {'/weeder-tool', '/gotoolbox-tool'}
# 28859164 {'/weeder-tool', '/reclu-tool'}
# 29155860 {'/weeder-tool', '/pyicos-tool'}
# 28068916 {'/centdist-tool', '/tip-tool'}
# 28240320 {'/centdist-tool', '/contra-2-tool'}
# 22210892 {'/pscan-tool', '/clover-tool'}
# 28848689 {'/arwen-tool', '/gomo-tool'}
# 29390964 {'/selecton-tool', '/modfold-tool', '/gomo-tool'}
# 28455373 {'/meme-chip-tool', '/biovenn-tool'}
# 29523784 {'/genefu-tool', '/ngs-plot-tool'}
# 29452359 {'/kpax-2-tool', '/seer-tool', '/bigsdb-tool'}
# 29654279 {'/dendroscope-tool', '/mash-tool', '/circlator-tool', '/roary-tool', '/seer-tool'}
# 28560587 {'/cluster-buster-tool', '/mcscan-tool'}
# 22292071 {'/lagan-tool', '/p-match-tool'}
# 28537227 {'/pmatch-tool', '/p-match-tool'}
# 28881977 {'/wiggler-tool', '/coda-2-tool', '/chromimpute-tool'}
# 28112199 {'/peakseq-tool', '/i-gsea4gwas-tool'}
# 29581865 {'/seqminer-tool', '/ciri-tool'}
# 28703137 {'/wiggler-tool', '/f-seq-tool'}
# 29176792 {'/wiggler-tool', '/f-seq-tool'}
# 26690675 {'/varelect-tool', '/babelomics-tool', '/cellbase-tool'}
# 28059169 {'/babelomics-tool', '/orfpredictor-tool'}
# 29520061 {'/spaln-tool', '/babelomics-tool', '/angsd-tool', '/popoolation-tool'}
# 29522525 {'/varelect-tool', '/babelomics-tool'}
# 29588463 {'/babelomics-tool', '/esefinder-tool'}
# 29723239 {'/babelomics-tool', '/diana-mirpath-tool', '/genepattern-tool'}
# 28480311 {'/cellnet-tool', '/ease-tool'}
# 29449426 {'/g-profiler-tool', '/bumphunter-tool'}
# 29618373 {'/g-profiler-tool', '/svtyper-tool', '/lumpy-tool'}
# 29753320 {'/g-profiler-tool', '/sortmerna-tool'}
# 29163640 {'/pathvisio-tool', '/genmapp-tool'}
# 29298665 {'/abner-tool', '/genmapp-tool'}
# 29328449 {'/wikipathways-tool', '/genmapp-tool'}
# 29378511 {'/goseq-tool', '/omicade4-tool'}
# 29408927 {'/goseq-tool', '/primer3-tool'}
# 29747577 {'/cpc-tool', '/scripture-tool', '/find-circ-tool', '/primer-premier-tool', '/goseq-tool', '/cnci-tool'}
# 29747587 {'/goseq-tool', '/circlize-tool', '/biomart-tool', '/seurat-2-tool'}
# 29751742 {'/goseq-tool', '/mirdeep-tool'}
# 29760381 {'/goseq-tool', '/clusterprofiler-tool'}
# 28831170 {'/jvenn-tool', '/stem-tool'}
# 29538394 {'/stem-tool', '/feelnc-tool'}
# 29723158 {'/find-circ-tool', '/stem-tool'}
# 29368590 {'/wego-tool', '/jalview-tool'}
# 26751491 {'/cermit-tool', '/wavcluster-tool', '/mcarts-tool', '/memeris-tool', '/dclip-tool', '/rnamotifs-tool'}
# 27541140 {'/paralyzer-tool', '/cermit-tool'}
# 29387452 {'/paralyzer-tool', '/rmaps-tool', '/cermit-tool'}
# 26201343 {'/scripture-tool', '/flux-simulator-tool'}
# 26793234 {'/scripture-tool', '/cbrowse-tool'}
# 23758618 {'/trackster-tool', '/spark-tool'}
# 27460974 {'/igb-tool', '/ccat-tool'}
# 29483503 {'/novobreak-tool', '/cora-tool'}
# 25751142 {'/hisat2-tool', '/hisat-tool'}
# 29150517 {'/maxquant-tool', '/subread-tool', '/pannzer-tool', '/perseus-tool', '/gepard-tool'}
# 29540736 {'/sortmerna-tool', '/subread-tool', '/kaas-tool', '/idba-ud-tool', '/priam-tool'}
# 20709691 {'/uclust-tool', '/usearch-tool'}
# 29293587 {'/qiime-tool', '/uparse-tool', '/usearch-tool'}
# 29321528 {'/pear-tool', '/usearch-tool'}
# 29354109 {'/qiime-tool', '/usearch-tool'}
# 29354144 {'/qiime-tool', '/usearch-tool', '/clustal-omega-tool'}
# 29742123 {'/mothur-tool', '/uclust-tool', '/usearch-tool', '/galaxy-tool'}
# 29760543 {'/uparse-tool', '/usearch-tool'}
# 29769378 {'/qiime-tool', '/picrust-tool', '/unifrac-tool', '/usearch-tool'}
# 28379492 {'/rbns-tool', '/clusterprofiler-tool'}
# 29463655 {'/genometricorr-tool', '/genomescope-tool', '/complex-heatmaps-tool', '/clusterprofiler-tool', '/assemblytics-tool', '/circos-tool', '/genemark-et-tool'}
# 29441236 {'/kallisto-tool', '/gosemsim-tool'}
# 29665773 {'/tscan-tool', '/hotnet-tool', '/gosemsim-tool'}
# 28336965 {'/gossto-tool', '/sml-tool'}
# 29481322 {'/seqplots-tool', '/gotoolbox-tool'}
# 27338101 {'/acs-tool', '/gs2-tool'}
# 24108186 {'/sml-toolkit-tool', '/sml-tool'}
# 24269894 {'/sml-toolkit-tool', '/sml-tool'}
# 27809788 {'/atrm-tool', '/quickngs-tool'}
# 29449575 {'/dexseq-tool', '/msisensor-tool', '/telseq-tool', '/biobeam-tool', '/synergyfinder-tool', '/oncofuse-tool', '/pyclone-tool', '/quickngs-tool'}
# 25728682 {'/repitools-tool', '/calmate-tool'}
# 28524227 {'/dpt-tool', '/gpfates-tool', '/switchde-tool', '/raceid-tool', '/impulsede-tool'}
# 28751729 {'/masigpro-tool', '/genecycle-tool'}
# 28994389 {'/masigpro-tool', '/ddrtree-tool'}
# 29703138 {'/masigpro-tool', '/toppgene-suite-tool', '/dcluster-tool'}
# 28344541 {'/stepminer-tool', '/cytomine-tool'}
# 28155638 {'/ganpa-tool', '/giga-tool'}
# 29304754 {'/activedriver-tool', '/dendrix-tool', '/memo-2-tool', '/ganpa-tool', '/starbiotrek-tool', '/drivernet-tool'}
# 29203636 {'/geoquery-tool', '/genecodis-tool'}
# 27294188 {'/noa-tool', '/clust-tool'}
# 29695739 {'/ontologizer-tool', '/lastz-tool', '/cafe-2-tool', '/dbcan-tool'}
# 29706976 {'/ontologizer-tool', '/trssp-tool'}
# 15215394 {'/phylo-vista-tool', '/rvista-tool', '/gvista-tool', '/mvista-tool'}
# 17488840 {'/wgvista-tool', '/gvista-tool', '/phylo-vista-tool', '/mvista-tool', '/rvista-tool'}
# 26313368 {'/lagan-tool', '/rvista-tool'}
# 26447474 {'/lagan-tool', '/rvista-tool'}
# 29696133 {'/rvista-tool', '/genepattern-tool'}
# 29765516 {'/t-coffee-tool', '/rvista-tool'}
# 29051481 {'/centipede-tool', '/piq-tool', '/chromimpute-tool'}
# 27900322 {'/tetoolkit-tool', '/repenrich-tool'}
# 29584757 {'/junctionseq-tool', '/repenrich-tool'}
# 27273980 {'/focicounter-tool', '/incromap-tool'}
# 28912750 {'/3omics-tool', '/incromap-tool'}
# 28163793 {'/teqc-tool', '/marmal-aid-tool'}
# 29242640 {'/bmiq-tool', '/methlab-tool', '/cpgassoc-tool'}
# 29601581 {'/bumphunter-tool', '/methylaid-tool'}
# 29740534 {'/bumphunter-tool', '/missmethyl-tool'}
# 29249830 {'/bmiq-tool', '/shinymethyl-tool', '/comb-p-tool'}
# 29682088 {'/swan-tool', '/comb-p-tool'}
# 22703947 {'/swan-tool', '/missmethyl-tool'}
# 29058119 {'/missmethyl-tool', '/conumee-tool'}
# 26763932 {'/altanalyze-tool', '/firma-tool'}
# 27350239 {'/rbpmap-tool', '/altanalyze-tool', '/sfmap-tool'}
# 29463544 {'/altanalyze-tool', '/kallisto-tool'}
# 29467494 {'/anosva-tool', '/altanalyze-tool'}
# 25111155 {'/pride-converter-tool', '/amen-tool'}
# 29620157 {'/genefilter-tool', '/biocat-tool'}
# 29740265 {'/genefilter-tool', '/carmaweb-tool', '/interactivenn-tool'}
# 29507679 {'/jetset-tool', '/cghcall-tool', '/fpclass-tool'}
# 29476056 {'/penncnv-tool', '/genomestudio-tool', '/ascat-tool', '/copynumber-tool'}
# 29543773 {'/arraytrack-tool', '/de-noise-tool'}
# 29436647 {'/mev-tool', '/tm4-tool'}
# 29483524 {'/mapman-tool', '/tm4-tool'}
# 29769636 {'/gromacs-tool', '/tm4-tool'}
# 27708664 {'/oscope-tool', '/sclvm-tool', '/waterfall-tool', '/scde-2-tool', '/basics-tool', '/ccremover-tool', '/sinqc-tool', '/oefinder-tool'}
# 27052890 {'/raceid-tool', '/oscope-tool', '/snn-cliq-tool', '/oefinder-tool'}
# 29240790 {'/oscope-tool', '/scnorm-tool', '/wavecrest-tool'}
# 29404219 {'/cyclops-2-tool', '/oscope-tool'}
# 29456488 {'/oscope-tool', '/singlesplice-tool', '/backspin-tool', '/waterfall-tool', '/scde-2-tool', '/brie-tool', '/scuba-tool', '/monocle-tool', '/snn-cliq-tool', '/sc3-tool'}
# 28927400 {'/jigsaw-tool', '/synmap-tool', '/gmato-tool', '/dagchainer-tool', '/recat-tool'}
# 27694495 {'/seurat-2-tool', '/sclvm-tool'}
# 29216888 {'/sclvm-tool', '/scde-2-tool'}
# 29229905 {'/sailfish-tool', '/ddrtree-tool', '/sclvm-tool', '/pcamethods-tool'}
# 29285690 {'/cel-seq-tool', '/sclvm-tool', '/spade-tool', '/phenograph-tool', '/ginkgo-3-tool', '/histocat-tool', '/super-seq-tool', '/dr-seq-tool'}
# 29580379 {'/scran-tool', '/sclvm-tool', '/monocle-tool'}
# 29225342 {'/scran-tool', '/monocle-tool'}
# 29367672 {'/scran-tool', '/complex-heatmaps-tool'}
# 29373712 {'/scran-tool', '/scde-2-tool', '/basics-tool'}
# 28423671 {'/methylmix-tool', '/complex-heatmaps-tool'}
# 29213088 {'/methylmix-tool', '/birdsuite-tool'}
# 29456764 {'/methylmix-tool', '/tcga-assembler-tool'}
# 29764499 {'/lefse-tool', '/deseq2-tool'}
# 29765036 {'/tensorflow-tool', '/deseq2-tool'}
# 29321057 {'/pycogent-tool', '/edger-tool'}
# ...
# 28622290 {'/coils-pcoils-tool', '/socket-tool', '/qmean-tool'}
# 27189989 {'/cd-search-tool', '/marcoil-tool'}
# 28839119 {'/paircoil-tool', '/wormnet-tool'}
# 15585524 {'/distill-tool', '/porter-tool'}
# 24267415 {'/phdcleav-tool', '/dncon-tool'}
# 26763289 {'/multicom-tool', '/nncon-tool'}
# 26601946 {'/galaxyrefine-tool', '/sam-t08-tool'}
# 19151096 {'/hpview-tool', '/hpstruct-tool', '/latfit-tool'}
# 26151847 {'/hpview-tool', '/latfit-tool'}
# 23028322 {'/rci-tool', '/cs-rosetta-tool'}
# 26426014 {'/mfdp-tool', '/foldunfold-tool'}
# 27588752 {'/mfdp-tool', '/spot-disorder-tool'}
# 27530967 {'/multicom-tool', '/3drobot-tool', '/pcons-net-tool'}
# 28166275 {'/dianna-tool', '/cyspred-tool', '/edbcp-tool'}
# 28255315 {'/dipro-tool', '/cyspred-tool'}
# 28742131 {'/dipro-tool', '/qmean-tool'}
# 29327267 {'/swiss-model-tool', '/disulfind-tool'}
# 26366880 {'/wordom-tool', '/dyndom-tool'}
# 29208936 {'/rci-tool', '/foldindex-tool'}
# 29315236 {'/foldindex-tool', '/modfold-tool'}
# 29351565 {'/foldindex-tool', '/gps-sumo-tool'}
# 29643398 {'/foldindex-tool', '/psipred-tool'}
# 27489951 {'/coth-tool', '/raptorx-tool'}
# 28475612 {'/robetta-tool', '/raptorx-tool'}
# 28273846 {'/galaxygemini-tool', '/deconstruct-tool'}
# 28446174 {'/robetta-tool', '/procheck-tool'}
# 28963468 {'/robetta-tool', '/dalilite-tool'}
# 29759072 {'/robetta-tool', '/pymol-tool'}
# 26488894 {'/pknot-tool', '/rnapdbee-tool'}
# 23365638 {'/protein-knot-server-tool', '/dhcl-tool'}
# 27493547 {'/archpred-tool', '/cryson-tool'}
# 29674686 {'/rnacompete-tool', '/consurf-tool', '/eppic-tool'}
# 26072473 {'/opus-psp-tool', '/apollo-2-tool'}
# 26493701 {'/opus-psp-tool', '/apollo-2-tool'}
# 29518000 {'/verify3d-tool', '/qmean-tool'}
# 25969444 {'/mmm-tool', '/rpf-tool'}
# 29497074 {'/irecs-tool', '/cellnet-tool'}
# 29533999 {'/scwrl-tool', '/orion-tool'}
# 29294020 {'/popmusic-tool', '/encom-tool'}
# 28747718 {'/eris-tool', '/consurf-tool'}
# 17570143 {'/annolyze-tool', '/annolite-tool'}
# 17570147 {'/annolyze-tool', '/annolite-tool'}
# 25161240 {'/openstructure-tool', '/lddt-tool'}
# 26323716 {'/bioplib-tool', '/bioptools-tool'}
# 28472157 {'/esypred3d-tool', '/3drefine-tool'}
# 29739976 {'/refold-tool', '/cns-tool'}
# 29581866 {'/proteindbs-tool', '/kinasephos-tool'}
# 29681910 {'/probecheck-tool', '/rapido-tool'}
# 29773800 {'/xds-tool', '/phenix-tool', '/coot-tool', '/pymol-tool'}
# 29608608 {'/eom-tool', '/psipred-tool', '/procheck-tool', '/swiss-model-tool', '/sasref-tool'}
# 29593446 {'/psipred-tool', '/expasy-translate-tool-tool'}
# 28097215 {'/dhcl-tool', '/domainparser-tool'}
# 15215404 {'/cd-search-tool', '/batch-cd-search-tool'}
# 29684093 {'/consurf-tool', '/pdb2pqr-tool'}
# 27923997 {'/xtail-tool', '/ribomap-tool', '/ribotools-tool', '/ribohmm-tool', '/ribogalaxy-tool', '/riboseqr-tool', '/rfoot-tool', '/proteoformer-tool', '/ribodiff-tool', '/riboprofiling-tool', '/babel-tool', '/anota-tool'}
# 29483630 {'/ptm-x-tool', '/motif-x-tool'}
# 26641247 {'/netphos-tool', '/netglycate-tool'}
# 28558017 {'/arraypipe-tool', '/big-pi-predictor-tool'}
# 29568220 {'/gpi-som-tool', '/big-pi-predictor-tool'}
# 28473666 {'/gps-sno-tool', '/gps-sumo-tool', '/gps-lipid-tool', '/css-palm-tool'}
# 29018364 {'/gps-lipid-tool', '/netphos-tool'}
# 29588502 {'/nmt-tool', '/palmpred-tool', '/seqpalm-tool', '/gps-lipid-tool', '/wap-palm-tool', '/cksaap-palm-tool', '/myristoylator-tool'}
# 28814803 {'/nmt-tool', '/myristoylator-tool'}
# 29134119 {'/preps-tool', '/myristoylator-tool'}
# 27148305 {'/preps-tool', '/plant-specific-myristoylation-predictor-tool'}
# 25849564 {'/modls-tool', '/methylquant-tool'}
# 25333472 {'/gps-sumo-tool', '/gps-yno2-tool', '/gps-sno-tool', '/css-palm-tool', '/isno-pseaac-tool', '/isno-aapair-tool'}
# 29150669 {'/netacet-tool', '/css-palm-tool'}
# 29312925 {'/netacet-tool', '/css-palm-tool'}
# 28004021 {'/pail-tool', '/disphos-tool'}
# 29445193 {'/disphos-tool', '/kinasephos-tool'}
# 24564522 {'/predikin-tool', '/metapredps-tool', '/masa-tool'}
# 26941719 {'/ubpred-tool', '/netphos-tool', '/sumoplot-tool'}
# 28955362 {'/ubpred-tool', '/netphos-tool', '/sumoplot-tool'}
# 26680990 {'/aseb-tool', '/masa-tool'}
# 17045240 {'/gps-pail-tool', '/pail-tool'}
# 26202727 {'/masa-tool', '/imethyl-pseaac-tool'}
# 25184139 {'/isno-pseaac-tool', '/gps-sno-tool', '/isno-aapair-tool'}
# 29062872 {'/gps-yno2-tool', '/gps-sno-tool', '/isno-aapair-tool'}
# 28894368 {'/sucstruct-tool', '/succinsite-tool', '/psuc-lys-tool', '/isuc-pseaac-tool', '/isuc-pseopt-tool'}
# 29474435 {'/gps-sumo-tool', '/sumoamvr-tool', '/jassa-tool'}
# 25521314 {'/seesumo-tool', '/sumohydro-tool'}
# 29236778 {'/seesumo-tool', '/sumoplot-tool'}
# 24983760 {'/ubpred-tool', '/sumoplot-tool'}
# 26940649 {'/ubipred-tool', '/hcksaap-ubsite-tool'}
# 29371697 {'/ubpred-tool', '/iubiq-lys-tool', '/ubiprober-tool'}
# 25484842 {'/cryson-tool', '/bunch-tool', '/monsa-tool', '/gasbor-tool', '/atsas-tool', '/eom-tool', '/dammin-tool', '/sasref-tool'}
# 29632331 {'/atsas-tool', '/monsa-tool'}
# 15923225 {'/sasref-tool', '/bunch-tool'}
# 28808438 {'/cryson-tool', '/bunch-tool', '/monsa-tool', '/gasbor-tool', '/eom-tool', '/dammin-tool', '/sasref-tool'}
# 10354416 {'/dammin-tool', '/monsa-tool'}
# 29440720 {'/gasbor-tool', '/dammin-tool'}
# 29346611 {'/eom-tool', '/sasref-tool', '/mc-sym-tool', '/monsa-tool'}
# 29550990 {'/ligandtracer-tool', '/tracedrawer-tool'}
# 29643993 {'/ligandtracer-tool', '/tracedrawer-tool'}
# 29658563 {'/ligandtracer-tool', '/tracedrawer-tool'}
# 25707620 {'/mirsynergy-tool', '/snmnmf-tool'}
# 28155675 {'/mirsynergy-tool', '/snmnmf-tool'}
# 28384097 {'/pipipes-tool', '/genecycle-tool'}
# 29540207 {'/rme-tool', '/shapefinder-tool'}
# 25816203 {'/tssar-tool', '/ribex-tool'}
# 29991676 {'/barcodeswapping2017-tool', '/dropletutils-tool'}
# 26609224 {'/alexa-seq-tool', '/glimmps-tool'}
# 28882000 {'/majiq-tool', '/avispa-tool'}
# 28961236 {'/majiq-tool', '/avispa-tool'}
# 29712909 {'/irfinder-tool', '/dexseq-tool', '/cpat-tool', '/stringtie-tool'}
# 28219335 {'/tetoolkit-tool', '/splicer-tool', '/junctionseq-tool'}
# 29741478 {'/junctionseq-tool', '/majiq-tool'}
# 29528287 {'/majiq-tool', '/taco-tool'}
# 28794490 {'/feelnc-tool', '/splicegrapher-tool'}
# 29346292 {'/astalavista-tool', '/tapis-tool', '/tofu-tool', '/splicegrapher-tool'}
# 29206165 {'/circrna-finder-tool', '/deanniso-tool', '/uroborus-tool', '/tdrmapper-tool', '/circview-tool', '/seqbuster-tool', '/nclscan-tool'}
# 29720189 {'/regrna-tool', '/cpat-tool'}
# 28594327 {'/oligo-package-tool', '/arrayqualitymetrics-tool'}
# 28098242 {'/rockhopper-tool', '/annocript-tool'}
# 29511172 {'/heatmapper-tool', '/geo2r-tool'}
# 29590628 {'/lunggens-tool', '/cell-ranger-tool'}
# 29743016 {'/estscan-tool', '/primer-premier-tool'}
# 28518075 {'/rnaquast-tool', '/genemarks-t-tool'}
# 28868132 {'/idp-ase-tool', '/genemarks-t-tool'}
# 29092957 {'/complex-heatmaps-tool', '/trans-abyss-tool'}
# 29616846 {'/brb-arraytools-tool', '/cibersort-tool', '/arrayqualitymetrics-tool'}
# 29130882 {'/epic-3-tool', '/mcp-counter-tool', '/isopure-tool', '/deconrnaseq-tool', '/bseq-sc-tool'}
# 29273356 {'/timer-tool', '/forna-tool'}
# 27475403 {'/diana-mirpath-tool', '/mieaa-tool'}
# 29523845 {'/refgenes-tool', '/reditools-tool', '/diana-mirpath-tool'}
# 29716593 {'/tophat-fusion-tool', '/diana-mirpath-tool', '/intarna-tool'}
# 26521232 {'/mirnacon-tool', '/genetrail-tool', '/mieaa-tool'}
# 27895807 {'/mirmaster-tool', '/novomirank-tool', '/genetrail-tool'}
# 29273769 {'/mitea-tool', '/mirnapath-tool'}
# 29386110 {'/metacycle-tool', '/arser-tool'}
# 29444635 {'/metacycle-tool', '/arser-tool'}
# 29658882 {'/metacycle-tool', '/arser-tool'}
# 29666379 {'/metacycle-tool', '/arser-tool'}
# 27307647 {'/bio-cycle-tool', '/bio-clock-tool'}
# 29098954 {'/circadiomics-tool', '/metacycle-tool', '/lomb-scargle-tool'}
# 29581274 {'/rbpmap-tool', '/rmaps-tool'}
# 29439142 {'/cpc-tool', '/cnci-tool', '/cpat-tool', '/lnctar-tool'}
# 29634734 {'/cpc-tool', '/cnci-tool'}
# 29690875 {'/kallisto-tool', '/cnci-tool', '/cpat-tool', '/stringtie-tool'}
# 29765519 {'/cnci-tool', '/feelnc-tool'}
# 28341852 {'/tanric-tool', '/cpat-tool'}
# 29739971 {'/cpc-tool', '/rnahybrid-tool'}
# 29087317 {'/rrs-tool', '/systempiper-tool', '/ribotaper-tool'}
# 28873470 {'/ribosw-tool', '/riboswitch-scanner-tool'}
# 21609949 {'/mirumir-tool', '/p53mutagene-tool'}
# 28595592 {'/roku-tool', '/intarna-tool'}
# 28687784 {'/rmats-tool', '/annocript-tool'}
# 29564081 {'/annocript-tool', '/homeosplitter-tool'}
# 28703416 {'/ribopicker-tool', '/trapid-tool'}
# 19573244 {'/tishunter-tool', '/startscan-tool'}
# 28152994 {'/dnafsminer-tool', '/tishunter-tool'}
# 29657274 {'/tdrmapper-tool', '/trf2cancer-tool'}
# 27663494 {'/fstitch-tool', '/tfit-tool'}
# 28545391 {'/anosva-tool', '/plata-tool'}
# 26944083 {'/mmbgx-tool', '/meap-tool'}
# 29361568 {'/scde-2-tool', '/deconrnaseq-tool'}
# 29285252 {'/isopure-tool', '/affyrnadegradation-tool'}
# 26462087 {'/farms-tool', '/rmaexpress-tool'}
# 28878380 {'/gene-expression-barcode-tool', '/ataris-tool'}
# 28676069 {'/sam-tool', '/gpca-tool'}
# 29535388 {'/sam-tool', '/mapsplice-tool', '/trup-tool'}
# 29328377 {'/metaomics-tool', '/metaqc-tool'}
# 29078207 {'/rmaexpress-tool', '/spell-tool'}
# 26301253 {'/drme-tool', '/exomepeak-tool'}
# 28281539 {'/tophat-fusion-tool', '/circexplorer-tool'}
# 29523209 {'/tophat-fusion-tool', '/circexplorer-tool'}
# 29556495 {'/circrna-finder-tool', '/mapsplice-tool', '/circexplorer-tool', '/uroborus-tool', '/ciri-tool'}
# 27067391 {'/mrsnp-tool', '/crac-tool', '/snpfold-tool'}
# 29507755 {'/dapars-tool', '/hisat-tool'}
# 29716542 {'/hisat-tool', '/stringtie-tool'}
# 29716547 {'/hisat-tool', '/stringtie-tool'}
# 29739325 {'/hisat-tool', '/stringtie-tool'}
# 29093448 {'/raser-tool', '/giremi-tool'}
# 29534430 {'/kallisto-tool', '/stringtie-tool'}
# 27763814 {'/sailfish-tool', '/suppa-tool'}
# 28784092 {'/flux-simulator-tool', '/sailfish-tool', '/ireckon-tool'}
# 28250805 {'/kissplice-tool', '/flux-simulator-tool', '/transrate-tool'}
# 29611322 {'/ruvseq-tool', '/unitas-tool'}
# 26338770 {'/isoem-tool', '/beers-tool', '/ireckon-tool'}
# 28673540 {'/bonvoyage-tool', '/outrigger-tool'}
# 29070840 {'/ribopicker-tool', '/4sale-tool'}
# 28346137 {'/dapars-tool', '/miso-tool'}
# 29541089 {'/astalavista-tool', '/miso-tool'}
# 28900269 {'/lvsmirna-tool', '/agimicrorna-tool'}
# 29455644 {'/nanostride-tool', '/nanostringnorm-tool', '/nanostringdiff-tool'}
# 29500443 {'/nanostringdiff-tool', '/nanostringnorm-tool'}
# 24755880 {'/srnatarget-tool', '/petcofold-tool', '/starpicker-tool', '/gotohscan-tool', '/napp-tool'}
# 27014636 {'/srnatarget-tool', '/starpicker-tool'}
# 28468647 {'/srnatarget-tool', '/starpicker-tool'}
# 26679185 {'/coprarna-tool', '/targetrna-tool'}
# 28717590 {'/intarna-tool', '/targetrna-tool'}
# 22558167 {'/maturebayes-tool', '/mireval-tool', '/microprocessor-svm-tool'}
# 28569207 {'/gesper-tool', '/ataris-tool'}
# 29566768 {'/demeter-tool', '/ataris-tool'}
# 16869968 {'/web-cellhts-tool', '/cellhts-tool'}
# 28860459 {'/rnahybrid-tool', '/mrsnp-tool', '/mirnasnp-tool'}
# 29317647 {'/targetscan-tool', '/microsniper-tool', '/mirnasnp-tool'}
# 29017967 {'/iseerna-tool', '/spongescan-tool', '/mtide-tool'}
# 26590255 {'/lncfunction-tool', '/lncseeker-tool'}
# 28379566 {'/lncfuntk-tool', '/lncfunnet-tool'}
# 28842680 {'/seqtar-tool', '/mircheck-tool'}
# 28852064 {'/astalavista-tool', '/mircheck-tool'}
# 29096602 {'/psrna-tool', '/mircheck-tool'}
# 29764387 {'/seqtar-tool', '/mircheck-tool'}
# 28813447 {'/srnabench-tool', '/srnatoolbox-tool'}
# 28925938 {'/dario-tool', '/srnatoolbox-tool'}
# 29643765 {'/srnabench-tool', '/srnatoolbox-tool'}
# 24838564 {'/intarna-tool', '/coprarna-tool'}
# 29615727 {'/rnacomposer-tool', '/rnastructure-tool', '/intarna-tool', '/rme-tool'}
# 29740411 {'/intarna-tool', '/coprarna-tool', '/varna-tool'}
# 29739921 {'/pictar-tool', '/ym500-tool'}
# 29507325 {'/mirdeep-tool', '/psrnatarget-tool'}
# 15652477 {'/targetscans-tool', '/targetscan-tool'}
# 26267216 {'/mirza-tool', '/targetscan-tool'}
# 28717203 {'/uroborus-tool', '/targetscans-tool'}
# 27441640 {'/rnaxs-tool', '/sivirus-tool'}
# 15215366 {'/sirna-tool', '/sfold-tool'}
# 23516022 {'/srnascanner-tool', '/napp-tool'}
# 28663744 {'/srnascanner-tool', '/napp-tool'}
# 29440670 {'/psrna-tool', '/cleaveland-tool'}
# 29739311 {'/cleaveland-tool', '/paresnip-tool', '/mirdeep-tool'}
# 27920994 {'/qpcrnorm-tool', '/chippcr-tool'}
# 28597408 {'/raceid-tool', '/waterfall-tool', '/backspin-tool', '/monocle-tool'}
# 29529054 {'/refgenes-tool', '/normqpcr-tool'}
# 28333958 {'/mpprimer-tool', '/multiplx-tool'}
# 18440976 {'/resuspension-calculator-tool', '/oligoanalyzer-tool', '/dilution-calculator-tool'}
# 28351759 {'/resuspension-calculator-tool', '/sramp-tool'}
# 29129909 {'/ribogalaxy-tool', '/r-chie-tool'}
# 28622766 {'/rust-tool', '/babel-tool'}
# 29228904 {'/ribodiff-tool', '/riboprofiling-tool', '/ribotaper-tool'}
# 26764022 {'/floss-tool', '/orfscore-tool'}
# 25958398 {'/mcarts-tool', '/parma-tool', '/wavcluster-tool', '/dclip-tool'}
# 29084942 {'/dapars-tool', '/omiras-tool', '/dclip-tool'}
# 26042150 {'/blockclust-tool', '/mirdba-tool', '/parma-tool'}
# 28886744 {'/piranha-tool', '/paralyzer-tool', '/clipper-2-tool'}
# 29322451 {'/circtools-tool', '/clipsearch-tool'}
# 26041786 {'/rbpmotif-tool', '/rnapromo-tool', '/wavcluster-tool', '/memeris-tool', '/ripseeker-tool'}
# 24217996 {'/rnapromo-tool', '/memeris-tool', '/teiser-tool', '/rbpmotif-tool'}
# 28959008 {'/structurefold-tool', '/pycrac-tool'}
# 24217913 {'/rnapromo-tool', '/rnamotifs-tool'}
# 28467899 {'/apa-2-tool', '/expressrna-tool'}
# 29657273 {'/m6apred-tool', '/sramp-tool', '/ppus-tool', '/rampred-tool', '/m6ath-tool', '/irna-pseu-tool'}
# 29529991 {'/rnacompete-tool', '/rnashapes-tool'}
# 29662087 {'/rnaeditor-tool', '/deepred-tool', '/irna-ai-tool', '/giremi-tool'}
# 29126398 {'/mbased-tool', '/scale-tool'}
# 28594838 {'/circrna-finder-tool', '/nclscan-tool'}
# 29182528 {'/uroborus-tool', '/nclscan-tool'}
# 28881849 {'/waterfall-tool', '/scuba-tool', '/super-seq-tool'}
# 29089539 {'/super-seq-tool', '/uroborus-tool'}
# 29028961 {'/compcoder-tool', '/splatter-tool'}
# 27105842 {'/fusionseq-tool', '/trup-tool', '/pegasus-tool'}
# 22962361 {'/flux-simulator-tool', '/the-flux-capacitor-tool'}
# 28541529 {'/ericscript-tool', '/soapfuse-tool'}
# 29215024 {'/r-coffee-tool', '/srnascanner-tool', '/coprarna-tool'}
# 28729732 {'/sqtlseeker-tool', '/altrans-tool'}
# 28786034 {'/rnashapes-tool', '/natpipe-tool'}
# 27927225 {'/diceseq-tool', '/jar3d-tool'}
# 18322526 {'/mc-fold-tool', '/mc-sym-tool', '/mc-cons-tool', '/mc-fold-dp-tool'}
# 26329823 {'/rnapdbee-tool', '/mc-fold-dp-tool'}
# 28158755 {'/rag-3d-tool', '/dssr-tool', '/mc-fold-tool', '/jar3d-tool', '/ragtop-tool'}
# 28393861 {'/ragtop-tool', '/mc-sym-tool', '/mc-fold-tool'}
# 28550310 {'/mc-sym-tool', '/mc-fold-tool'}
# 29415133 {'/rnacomposer-tool', '/mc-fold-tool'}
# 29394378 {'/r-scape-tool', '/rnastructure-tool'}
# 29506466 {'/rnashapes-tool', '/rnastructure-tool'}
# 19061486 {'/foldalign-tool', '/rnaz-tool'}
# 29197323 {'/rnascclust-tool', '/foldalign-tool', '/rnaz-tool'}
# 29510672 {'/qgrs-mapper-tool', '/pqsfinder-tool'}
# 22958879 {'/rnamute-tool', '/rdmas-tool', '/rnamutants-tool'}
# 27755571 {'/rnamute-tool', '/nanofolder-tool', '/rnamutants-tool'}
# 29653577 {'/sfold-tool', '/nanofolder-tool'}
# 29067018 {'/dotknot-tool', '/pseudoviewer-tool'}
# 28558664 {'/pseudoviewer-tool', '/r-chie-tool'}
# 25923724 {'/coprarna-tool', '/varna-tool'}
# 25114714 {'/pairfold-tool', '/petcofold-tool'}
# 26673718 {'/gotohscan-tool', '/pairfold-tool', '/petcofold-tool'}
# 27993777 {'/pairfold-tool', '/petcofold-tool'}
# 28555645 {'/ym500-tool', '/rnaup-tool'}
# 27339130 {'/rnamotif-tool', '/rnaviz-tool'}
# 23902564 {'/rnapromo-tool', '/rnaprofile-tool'}
# 27662342 {'/r-coffee-tool', '/sara-coffee-tool'}
# 29294088 {'/r-coffee-tool', '/sequalyzer-tool'}
# 29649303 {'/4sale-tool', '/varna-tool'}
# 29622030 {'/cel-seq-tool', '/seurat-2-tool'}
# 29630593 {'/celltree-tool', '/seurat-2-tool', '/sc3-tool', '/snn-cliq-tool'}
# 29666373 {'/tscan-tool', '/seurat-2-tool', '/action-tool'}
# 29511234 {'/celltree-tool', '/sc3-tool'}
# 27534536 {'/scpattern-tool', '/wavecrest-tool'}
# 24056876 {'/single-cell-normalization-tool', '/brenneckeetal2013-tool'}
# 27693023 {'/stemid-tool', '/cel-seq-tool'}
# 26090362 {'/dario-tool', '/mirspring-tool', '/cpss-tool'}
# 29467169 {'/mirdeep-tool', '/seqbuster-tool'}
# 29505615 {'/srnabench-tool', '/seqbuster-tool'}
# 29155959 {'/dario-tool', '/blockclust-tool'}

# %%
dir_leng = len(os.listdir('../../category'))
category_train_dict = {}
i = 0
for file in os.listdir('../../category'):
    i += 1
    print(str((i/dir_leng)*100),end="\r")
#     print(file,len(file))
    pmid_set = set()
    read_file = open('../../category/'+file).read().splitlines()
    for r in read_file:
        pmid_set.add(r.strip())
    category_train_dict[file[:len(file)-13]] = list(pmid_set)
# Out:
# 100.08120300751886
